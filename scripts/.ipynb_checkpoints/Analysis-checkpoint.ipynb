# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import os,sys
from scipy import stats
from collections import Counter
plt.style.use('seaborn-white')

# %%
plt.style.use('seaborn-white')
plt.rcParams['figure.figsize']=3,2
plt.rcParams['figure.dpi']=300
plt.rcParams['axes.linewidth'] =1
plt.rcParams['lines.linewidth'] =1
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# set font size
SMALL_SIZE = 7
MEDIUM_SIZE = 8
LARGE_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=LARGE_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('axes', linewidth=1) 
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

# %%
print(sys.version)
# Out:
# 3.8.15 | packaged by conda-forge | (default, Nov 22 2022, 08:51:59)
# [Clang 14.0.6 ]

# %%
# %pip list | grep -e "numpy" -e "pandas" -e "matplotlib" -e "scipy" -e 'seaborn' -e 'jupyterlab'
# Out:
# jupyterlab                    3.6.3
# jupyterlab-code-snippets      2.1.0
# jupyterlab-pygments           0.1.2
# jupyterlab_server             2.22.1
# jupyterlab-widgets            1.0.2
# matplotlib                    3.4.3
# matplotlib-inline             0.1.3
# matplotlib-venn               0.11.6
# numpy                         1.20.3
# pandas                        1.3.4
# scipy                         1.7.2
# seaborn                       0.11.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Broad

# %% [markdown]
# ## data integration

# %%
df=pd.read_csv('../processed_data/CCLE_broad.txt',sep='\t',index_col=0)

# %%
gdsc1=pd.read_csv('../processed_data/GDSC1_AUC.txt',sep='\t',index_col=0)
gdsc2=pd.read_csv('../processed_data/GDSC2_AUC.txt',sep='\t',index_col=0)
ctrp1=pd.read_csv('../processed_data/CTRP1_AUC.txt',sep='\t',index_col=0)
ctrp2=pd.read_csv('../processed_data/CTRP2_AUC.txt',sep='\t',index_col=0)
prism=pd.read_csv('../processed_data/PRISM_AUC.txt',sep='\t',index_col=0)
gcsi=pd.read_csv('../processed_data/gCSI_AOC.txt',sep='\t',index_col=0)

# %%
df=df.merge(prism,left_index=True,right_index=True,how='left')
df['COSMICID']=df['COSMICID'].fillna(-1).astype(int)
df=df.merge(gdsc1,left_on='COSMICID',right_index=True,how='left')
df=df.merge(gdsc2,left_on='COSMICID',right_index=True,how='left')
df=df.merge(ctrp1,left_on='stripped_cell_line_name',right_index=True,how='left')
df=df.merge(ctrp2,left_on='stripped_cell_line_name',right_index=True,how='left')
df=df.merge(gcsi,left_on='stripped_cell_line_name',right_index=True,how='left')

# %%
df['HRD_score_broad']=df['HRD_score']

# %%
brca1_met=[]
for idx in df.index:
    if df.loc[idx,'BRCA1_methylation_broad']==1:
        brca1_met.append(1)
    elif df.loc[idx,'BRCA1_methylation_cosmic_likely']==1:
        brca1_met.append(1)
    elif df.loc[idx,'BRCA1_methylation_broad']==0:
        brca1_met.append(0)
    elif df.loc[idx,'BRCA1_methylation_cosmic_likely']==0:
        brca1_met.append(0)
    else:
        brca1_met.append(np.nan)
df['BRCA1_methylation']=brca1_met

# %%
brca_status=[]
for idx in df.index:
    if df.loc[idx,'BRCA1']=='LOH':
        brca_status.append('BRCA1_LOH')
    elif df.loc[idx,'BRCA2']=='LOH':
        brca_status.append('BRCA2_LOH')
    elif df.loc[idx,'BRCA2']=='LOH':
        brca_status.append('BRCA2_LOH')
    elif df.loc[idx,'BRCA1_methylation']==1:
        brca_status.append('BRCA1_methylation')
    elif df.loc[idx,'otherHRR_LOH']==1:
        brca_status.append('HRR_LOH')
    elif df.loc[idx,'BRCA1']=='unknown':
        brca_status.append('BRCA1_unknown')
    elif df.loc[idx,'otherHRR_unknown']==1:
        brca_status.append('HRR_unknown')
    elif df.loc[idx,'BRCA1']=='nonLOH':
        brca_status.append('BRCA1_nonLOH')
    elif df.loc[idx,'BRCA2']=='nonLOH':
        brca_status.append('BRCA2_nonLOH')
    elif df.loc[idx,'otherHRR_nonLOH']==1:
        brca_status.append('HRR_nonLOH')
    elif (df.loc[idx,'BRCA1']=='wt')&(df.loc[idx,'BRCA2']=='wt')&(df.loc[idx,'BRCA1_methylation']==0):
        brca_status.append('wt')
    else:
        brca_status.append(np.nan)
df['BRCA_status']=brca_status

# %%
Counter(df['BRCA_status']).most_common()
# Out:
# [('wt', 904),
#  (nan, 559),
#  ('HRR_nonLOH', 180),
#  ('HRR_LOH', 60),
#  ('HRR_unknown', 48),
#  ('BRCA2_nonLOH', 47),
#  ('BRCA1_nonLOH', 12),
#  ('BRCA1_LOH', 10),
#  ('BRCA2_LOH', 9),
#  ('BRCA1_methylation', 8),
#  ('BRCA1_unknown', 2)]

# %%
df=df[(df['BRCA_status'].isna()==False)]
#df=df[~df['BRCA_status'].isin(['HRR_unknown','BRCA1_unknown'])]
df.shape
# Out:
# (1280, 1034)

# %%
df['BRCA_alteration']=((df['BRCA1_LOH']==1)|(df['BRCA1_methylation']==1)|(df['BRCA2_LOH']==1)).astype(int)
df['BRCA_alteration'].sum()
# Out:
# 27

# %%
(~df['HRD_score_broad'].isna()).sum()
# Out:
# 914

# %%
(~df['SigMA_broad'].isna()).sum()
# Out:
# 1280

# %%
df0=df.copy()

# %%
drug_gdsc1=set(df.columns[df.columns.str.startswith('GDSC1')])
drug_gdsc2=set(df.columns[df.columns.str.contains('GDSC2')])
drug_ctrp1=set(df.columns[df.columns.str.contains('CTRP1')])
drug_ctrp2=set(df.columns[df.columns.str.contains('CTRP2')])
drug_prism=set(df.columns[df.columns.str.startswith("PRISM")])
drug_gcsi=set(df.columns[df.columns.str.contains('gCSI')])
drug_all=drug_gdsc1|drug_gdsc2|drug_ctrp1|drug_ctrp2|drug_prism|drug_gcsi
len(drug_all)
# Out:
# 882

# %%
drug_anno=pd.read_csv('../processed_data/Drug_annotaion_integrated.txt'
                      ,sep='\t',index_col=0)
drug_anno['cid']=drug_anno['cid'].astype(int)

# %%
df_drug=df[~df[drug_all].isna().all(axis=1)]
df_drug.shape
# Out:
# (1182, 1035)

# %% [markdown]
# ## BRCA status vs Drug sensitivity

# %%
from statsmodels.stats.multitest import multipletests

# %%
platinums=set(df_drug.columns[(df_drug.columns.str.contains('platin'))])
platinums
# Out:
# {'CTRP2_carboplatin_26979',
#  'CTRP2_oxaliplatin_375582',
#  'GDSC1_Cisplatin_1005',
#  'GDSC2_Cisplatin_1005',
#  'GDSC2_Oxaliplatin_1089',
#  'GDSC2_Oxaliplatin_1806',
#  'PRISM_carboplatin_BRD-K90947825-001-02-7',
#  'PRISM_cisplatin_BRD-K69172251-001-08-9',
#  'PRISM_oxaliplatin_BRD-K78960041-001-05-7',
#  'gCSI_Cisplatin_CID24191118'}

# %%
parpis=set(df_drug.columns[(df_drug.columns.str.contains('parib'))])
parpis
# Out:
# {'CTRP1_olaparib_411867',
#  'CTRP1_rucaparib_628605',
#  'CTRP1_veliparib_606034',
#  'CTRP2_olaparib_411867',
#  'CTRP2_veliparib_606034',
#  'GDSC1_Olaparib_1017',
#  'GDSC1_Olaparib_1495',
#  'GDSC1_Rucaparib_1175',
#  'GDSC1_Talazoparib_1259',
#  'GDSC1_Veliparib_1018',
#  'GDSC2_Niraparib_1177',
#  'GDSC2_Olaparib_1017',
#  'GDSC2_Talazoparib_1259',
#  'PRISM_niraparib_BRD-K54955827-001-02-2',
#  'PRISM_olaparib_BRD-K02113016-001-15-4',
#  'PRISM_olaparib_BRD-K02113016-001-19-6',
#  'PRISM_talazoparib_BRD-K95142244-001-01-5'}

# %% [markdown]
# ### BRCA12 altaration

# %%
df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH']).sum()
# Out:
# 25

# %%
df_drug[df_drug['BRCA_status'].isin(['wt'])].shape
# Out:
# (872, 1035)

# %%
df=df_drug.copy()

# %%
ns,rs,ps,ms,ms2=[],[],[],[],[]
n_limit=10
for drug in drug_all:
    a=df[df['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH'])][drug].dropna().values
    b=df[df['BRCA_status'].isin(['wt'])][drug].dropna().values
    n=len(a)
    if n>= n_limit:
        r,p=stats.mannwhitneyu(a,b)
        m=np.median(a)-np.median(b)
        m2=np.mean(a)-np.mean(b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
        ms.append(m)
        ms2.append(m2)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)
        ms.append(np.nan)
        ms2.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['med_dif']=ms
df_cor['mean_dif']=ms2
df_cor['pvalues']=ps
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor
# Out:
#                                           Number   med_dif  mean_dif  \
# PRISM_dacarbazine_BRD-K35520305-001-16-9    12.0  0.027111  0.021730
# GDSC2_Olaparib_1017                         17.0 -0.002356  0.003897
# CTRP2_GMX-1778_411843                       18.0  0.031500  0.140672
# PRISM_niraparib_BRD-K54955827-001-02-2      12.0  0.013989  0.027824
# GDSC1_Temsirolimus_1016                     19.0  0.052752  0.065950
# ...                                          ...       ...       ...
# PRISM_abiraterone_BRD-K50071428-001-03-3    12.0  0.013242  0.024645
# PRISM_carmofur_BRD-K11630072-001-13-2       12.0  0.085285  0.044049
# GDSC2_Osimertinib_1919                      16.0 -0.000204  0.001629
# PRISM_vindesine_BRD-K59753975-001-02-6      12.0  0.054386  0.041739
# GDSC2_LCL161_1557                           15.0 -0.003812  0.001130
#
#                                            pvalues   mlog10p  significant  \
# PRISM_dacarbazine_BRD-K35520305-001-16-9  0.220753  0.656093            0
# GDSC2_Olaparib_1017                       0.728996  0.137275            0
# CTRP2_GMX-1778_411843                     0.802656  0.095470            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.410650  0.386528            0
# GDSC1_Temsirolimus_1016                   0.223243  0.651222            0
# ...                                            ...       ...          ...
# PRISM_abiraterone_BRD-K50071428-001-03-3  0.730021  0.136665            0
# PRISM_carmofur_BRD-K11630072-001-13-2     0.082349  1.084341            0
# GDSC2_Osimertinib_1919                    0.791538  0.101528            0
# PRISM_vindesine_BRD-K59753975-001-02-6    0.154242  0.811799            0
# GDSC2_LCL161_1557                         0.551129  0.258746            0
#
#                                                      drug_anno       cid
# PRISM_dacarbazine_BRD-K35520305-001-16-9         DNA alkylator   5353562
# GDSC2_Olaparib_1017                             PARP inhibitor  23725625
# CTRP2_GMX-1778_411843                                   Others        -1
# PRISM_niraparib_BRD-K54955827-001-02-2          PARP inhibitor  24958200
# GDSC1_Temsirolimus_1016                    PI3K/MTOR signaling   6918289
# ...                                                        ...       ...
# PRISM_abiraterone_BRD-K50071428-001-03-3       Hormone-related    132971
# PRISM_carmofur_BRD-K11630072-001-13-2           Antimetabolite      2577
# GDSC2_Osimertinib_1919                          EGFR signaling  71496458
# PRISM_vindesine_BRD-K59753975-001-02-6         Antimicrotubule     40839
# GDSC2_LCL161_1557                         Apoptosis regulation  24737642
#
# [684 rows x 8 columns]

# %%
df_cor_p=df_cor[df_cor['med_dif']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['med_dif']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                                Number   med_dif  mean_dif   pvalues   mlog10p  \
# GDSC2_Foretinib_2040             17.0  0.088439  0.106701  0.000118  3.926293
# GDSC1_Vorinostat_1012            20.0  0.095145  0.095242  0.000427  3.369581
# GDSC2_Luminespib_1559            17.0  0.148574  0.110782  0.002511  2.600183
# CTRP2_MGCD-265_628622            18.0  0.477500  0.947430  0.003304  2.480915
# CTRP2_barasertib_601923          18.0  0.781500  2.112513  0.003751  2.425845
# ...                               ...       ...       ...       ...       ...
# GDSC1_Afatinib_1032              20.0 -0.022091 -0.024512  0.009918  2.003569
# GDSC1_WHI-P97_288                20.0 -0.015036 -0.019245  0.009127  2.039667
# GDSC1_Afatinib_1377              20.0 -0.049040 -0.048723  0.003309  2.480291
# GDSC1_IOX2_1230                  19.0 -0.006299 -0.001379  0.002341  2.630586
# gCSI_JQ1 compound_CID71300862    12.0 -0.055889 -0.074094  0.001909  2.719162
#
#                                significant                          drug_anno  \
# GDSC2_Foretinib_2040                     1                      RTK signaling
# GDSC1_Vorinostat_1012                    1                  Chromatin-related
# GDSC2_Luminespib_1559                    1  Protein stability and degradation
# CTRP2_MGCD-265_628622                    1                             Others
# CTRP2_barasertib_601923                  1                             Others
# ...                                    ...                                ...
# GDSC1_Afatinib_1032                      1                     EGFR signaling
# GDSC1_WHI-P97_288                        1                             Others
# GDSC1_Afatinib_1377                      1                     EGFR signaling
# GDSC1_IOX2_1230                          1                             Others
# gCSI_JQ1 compound_CID71300862            1                             Others
#
#                                     cid
# GDSC2_Foretinib_2040           42642645
# GDSC1_Vorinostat_1012              5311
# GDSC2_Luminespib_1559          10096043
# CTRP2_MGCD-265_628622          24901704
# CTRP2_barasertib_601923        11497983
# ...                                 ...
# GDSC1_Afatinib_1032            10184653
# GDSC1_WHI-P97_288                  3796
# GDSC1_Afatinib_1377            10184653
# GDSC1_IOX2_1230                54685215
# gCSI_JQ1 compound_CID71300862  71300862
#
# [684 rows x 8 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
counter=Counter(df_cor_pn['drug_anno']).most_common()

# %%
a=[x[0] for x in counter]
a
# Out:
# ['Others',
#  'PI3K/MTOR signaling',
#  'RTK signaling',
#  'Chromatin-related',
#  'ERK MAPK signaling',
#  'DNA inhibitor',
#  'Antimetabolite',
#  'EGFR signaling',
#  'Antimicrotubule',
#  'Cell cycle',
#  'Apoptosis regulation',
#  'Hormone-related',
#  'Protein stability and degradation',
#  'DNA alkylator',
#  'PARP inhibitor',
#  'Topoisomerase inhibitor',
#  'WNT signaling',
#  'Platinum',
#  'Metabolism',
#  'Genome integrity',
#  'p53 pathway',
#  'IGF1R signaling',
#  'Cytoskeleton',
#  'JNK and p38 signaling']

# %%
drug_order=[ 'Platinum',  'PARP inhibitor',
 'PI3K/MTOR signaling',
 'RTK signaling',
 'Chromatin-related',
 'ERK MAPK signaling',
 'DNA inhibitor',
 'Antimetabolite',
 'EGFR signaling',
 'Antimicrotubule',
 'Cell cycle',
 'Apoptosis regulation',
 'Hormone-related',
 'Protein stability and degradation',
 'DNA alkylator',
 'Topoisomerase inhibitor',
 'WNT signaling',
 'Metabolism',
 'Genome integrity',
 'p53 pathway',
 'IGF1R signaling',
 'Cytoskeleton',
 'JNK and p38 signaling']

# %%
anno_platinum=[]
for index in df_cor_pn.index:
    if 'isplatin' in index:
        anno_platinum.append(1)
    elif 'arboplatin' in index:
        anno_platinum.append(3)
    elif 'xaliplatin' in index:
        anno_platinum.append(2)
    else:
        anno_platinum.append(0)
df_cor_pn['platinum_color']=anno_platinum

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[drug_order[2:]]
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')   
#ax.set_yticklabels(sns_df.columns,fontsize=12)
# Out:
# PI3K/MTOR signaling
# RTK signaling
# Chromatin-related
# ERK MAPK signaling
# DNA inhibitor
# Antimetabolite
# EGFR signaling
# Antimicrotubule
# Cell cycle
# Apoptosis regulation
# Hormone-related
# Protein stability and degradation
# DNA alkylator
# Topoisomerase inhibitor
# WNT signaling
# Metabolism
# Genome integrity
# p53 pathway
# IGF1R signaling
# Cytoskeleton
# JNK and p38 signaling

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')

# %%
sns_df=in_df.reindex(columns=drug_order[2:]).fillna(0)
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# GDSC2_Oxaliplatin_1089                      16.0  0.017722  0.043411
# GDSC2_Cisplatin_1005                        17.0  0.031376  0.039406
# GDSC2_Oxaliplatin_1806                      15.0  0.009080  0.028683
# GDSC1_Cisplatin_1005                        20.0  0.009872  0.028787
# CTRP2_carboplatin_26979                     18.0  0.166000  0.256969
# CTRP2_oxaliplatin_375582                    18.0  0.163000  0.464937
# gCSI_Cisplatin_CID24191118                  10.0  0.052556  0.020534
# PRISM_carboplatin_BRD-K90947825-001-02-7    10.0  0.148143  0.076457
# PRISM_oxaliplatin_BRD-K78960041-001-05-7    11.0  0.018087  0.012186
# PRISM_cisplatin_BRD-K69172251-001-08-9      11.0 -0.013422 -0.091784
#
#                                            pvalues   mlog10p  significant  \
# GDSC2_Oxaliplatin_1089                    0.011562  1.936967            1
# GDSC2_Cisplatin_1005                      0.039501  1.403389            1
# GDSC2_Oxaliplatin_1806                    0.101070  0.995380            0
# GDSC1_Cisplatin_1005                      0.146806  0.833255            0
# CTRP2_carboplatin_26979                   0.177170  0.751610            0
# CTRP2_oxaliplatin_375582                  0.245012  0.610813            0
# gCSI_Cisplatin_CID24191118                0.384477  0.415130            0
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.514545  0.288576            0
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.642571  0.192079            0
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.146546  0.834026            0
#
#                                          drug_anno       cid  platinum_color  \
# GDSC2_Oxaliplatin_1089                    Platinum   5310940               2
# GDSC2_Cisplatin_1005                      Platinum     84691               1
# GDSC2_Oxaliplatin_1806                    Platinum   5310940               2
# GDSC1_Cisplatin_1005                      Platinum     84691               1
# CTRP2_carboplatin_26979                   Platinum     38904               3
# CTRP2_oxaliplatin_375582                  Platinum  24197464               2
# gCSI_Cisplatin_CID24191118                Platinum  24191118               1
# PRISM_carboplatin_BRD-K90947825-001-02-7  Platinum    426756               3
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  Platinum  24197464               2
# PRISM_cisplatin_BRD-K69172251-001-08-9    Platinum  24191118               1
#
#                                                FDR
# GDSC2_Oxaliplatin_1089                    0.115620
# GDSC2_Cisplatin_1005                      0.197506
# GDSC2_Oxaliplatin_1806                    0.293613
# GDSC1_Cisplatin_1005                      0.293613
# CTRP2_carboplatin_26979                   0.295283
# CTRP2_oxaliplatin_375582                  0.350017
# gCSI_Cisplatin_CID24191118                0.480596
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.571717
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.642571
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.293613

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# PRISM_olaparib_BRD-K02113016-001-19-6       11.0  0.059524  0.043416
# GDSC2_Niraparib_1177                        15.0  0.005434  0.028097
# PRISM_talazoparib_BRD-K95142244-001-01-5    12.0  0.095889  0.043518
# CTRP2_olaparib_411867                       18.0  0.339500  0.242052
# PRISM_niraparib_BRD-K54955827-001-02-2      12.0  0.013989  0.027824
# GDSC2_Talazoparib_1259                      16.0  0.001030  0.065922
# GDSC1_Rucaparib_1175                        20.0  0.001260  0.000517
# GDSC1_Talazoparib_1259                      20.0  0.004271  0.040311
# GDSC2_Olaparib_1017                         17.0 -0.002356  0.003897
# GDSC1_Veliparib_1018                        20.0 -0.001277  0.001672
# CTRP2_veliparib_606034                      18.0 -0.155500  0.111047
# PRISM_olaparib_BRD-K02113016-001-15-4       12.0 -0.125062 -0.036365
# GDSC1_Olaparib_1017                         20.0 -0.002712  0.002687
# GDSC1_Olaparib_1495                         19.0 -0.012046 -0.005304
#
#                                            pvalues   mlog10p  significant  \
# PRISM_olaparib_BRD-K02113016-001-19-6     0.062463  1.204377            0
# GDSC2_Niraparib_1177                      0.080489  1.094266            0
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.209066  0.679716            0
# CTRP2_olaparib_411867                     0.323061  0.490716            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.410650  0.386528            0
# GDSC2_Talazoparib_1259                    0.413839  0.383168            0
# GDSC1_Rucaparib_1175                      0.424401  0.372224            0
# GDSC1_Talazoparib_1259                    0.814607  0.089052            0
# GDSC2_Olaparib_1017                       0.728996  0.137275            0
# GDSC1_Veliparib_1018                      0.702937  0.153084            0
# CTRP2_veliparib_606034                    0.699233  0.155378            0
# PRISM_olaparib_BRD-K02113016-001-15-4     0.618710  0.208513            0
# GDSC1_Olaparib_1017                       0.584281  0.233378            0
# GDSC1_Olaparib_1495                       0.138085  0.859853            0
#
#                                                drug_anno        cid  \
# PRISM_olaparib_BRD-K02113016-001-19-6     PARP inhibitor   23725625
# GDSC2_Niraparib_1177                      PARP inhibitor   24958200
# PRISM_talazoparib_BRD-K95142244-001-01-5  PARP inhibitor  135565082
# CTRP2_olaparib_411867                     PARP inhibitor   23725625
# PRISM_niraparib_BRD-K54955827-001-02-2    PARP inhibitor   24958200
# GDSC2_Talazoparib_1259                    PARP inhibitor   44819241
# GDSC1_Rucaparib_1175                      PARP inhibitor    9931953
# GDSC1_Talazoparib_1259                    PARP inhibitor   44819241
# GDSC2_Olaparib_1017                       PARP inhibitor   23725625
# GDSC1_Veliparib_1018                      PARP inhibitor   11960529
# CTRP2_veliparib_606034                    PARP inhibitor   11960529
# PRISM_olaparib_BRD-K02113016-001-15-4     PARP inhibitor   23725625
# GDSC1_Olaparib_1017                       PARP inhibitor   23725625
# GDSC1_Olaparib_1495                       PARP inhibitor   23725625
#
#                                           platinum_color       FDR
# PRISM_olaparib_BRD-K02113016-001-19-6                  0  0.563420
# GDSC2_Niraparib_1177                                   0  0.563420
# PRISM_talazoparib_BRD-K95142244-001-01-5               0  0.731732
# CTRP2_olaparib_411867                                  0  0.742701
# PRISM_niraparib_BRD-K54955827-001-02-2                 0  0.742701
# GDSC2_Talazoparib_1259                                 0  0.742701
# GDSC1_Rucaparib_1175                                   0  0.742701
# GDSC1_Talazoparib_1259                                 0  0.814607
# GDSC2_Olaparib_1017                                    0  0.785073
# GDSC1_Veliparib_1018                                   0  0.785073
# CTRP2_veliparib_606034                                 0  0.785073
# PRISM_olaparib_BRD-K02113016-001-15-4                  0  0.785073
# GDSC1_Olaparib_1017                                    0  0.785073
# GDSC1_Olaparib_1495                                    0  0.644397

# %% [markdown]
# ### HRR alteration

# %%
df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH']).sum()
# Out:
# 82

# %%
df_drug[~df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH'])].shape
# Out:
# (1100, 1035)

# %%
ns,rs,ps,ms,ms2=[],[],[],[],[]
n_limit=10
for drug in drug_all:
    a=df[df['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH'])][drug].dropna().values
    b=df[df['BRCA_status'].isin(['wt'])][drug].dropna().values
    n=len(a)
    if n>= n_limit:
        r,p=stats.mannwhitneyu(a,b)
        m=np.median(a)-np.median(b)
        m2=np.mean(a)-np.mean(b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
        ms.append(m)
        ms2.append(m2)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)
        ms.append(np.nan)
        ms2.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['med_dif']=ms
df_cor['mean_dif']=ms2
df_cor['pvalues']=ps

# %%
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor
# Out:
#                                           Number   med_dif  mean_dif  \
# PRISM_dacarbazine_BRD-K35520305-001-16-9    35.0  0.003514  0.012924
# GDSC2_Olaparib_1017                         57.0  0.003092  0.008316
# GDSC1_PHA-665752_6                          23.0 -0.014597 -0.000699
# CTRP2_GMX-1778_411843                       58.0 -0.006000  0.031127
# PRISM_niraparib_BRD-K54955827-001-02-2      40.0  0.020144  0.000672
# ...                                          ...       ...       ...
# PRISM_carmofur_BRD-K11630072-001-13-2       41.0  0.028820  0.020860
# GDSC2_Osimertinib_1919                      56.0 -0.000763 -0.003772
# PRISM_vindesine_BRD-K59753975-001-02-6      40.0  0.034776  0.047607
# GDSC1_A-443654_86                           21.0 -0.037178 -0.019316
# GDSC2_LCL161_1557                           53.0 -0.000159 -0.001892
#
#                                            pvalues   mlog10p  significant  \
# PRISM_dacarbazine_BRD-K35520305-001-16-9  0.279409  0.553760            0
# GDSC2_Olaparib_1017                       0.326239  0.486464            0
# GDSC1_PHA-665752_6                        0.004664  2.331231            1
# CTRP2_GMX-1778_411843                     0.742581  0.129256            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.492405  0.307677            0
# ...                                            ...       ...          ...
# PRISM_carmofur_BRD-K11630072-001-13-2     0.223083  0.651534            0
# GDSC2_Osimertinib_1919                    0.506665  0.295279            0
# PRISM_vindesine_BRD-K59753975-001-02-6    0.122368  0.912332            0
# GDSC1_A-443654_86                         0.380297  0.419877            0
# GDSC2_LCL161_1557                         0.758385  0.120110            0
#
#                                                      drug_anno       cid
# PRISM_dacarbazine_BRD-K35520305-001-16-9         DNA alkylator   5353562
# GDSC2_Olaparib_1017                             PARP inhibitor  23725625
# GDSC1_PHA-665752_6                               RTK signaling  10461815
# CTRP2_GMX-1778_411843                                   Others        -1
# PRISM_niraparib_BRD-K54955827-001-02-2          PARP inhibitor  24958200
# ...                                                        ...       ...
# PRISM_carmofur_BRD-K11630072-001-13-2           Antimetabolite      2577
# GDSC2_Osimertinib_1919                          EGFR signaling  71496458
# PRISM_vindesine_BRD-K59753975-001-02-6         Antimicrotubule     40839
# GDSC1_A-443654_86                          PI3K/MTOR signaling  10172943
# GDSC2_LCL161_1557                         Apoptosis regulation  24737642
#
# [800 rows x 8 columns]

# %%
df_cor_p=df_cor[df_cor['med_dif']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['med_dif']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                         Number   med_dif  mean_dif   pvalues   mlog10p  \
# GDSC2_Buparlisib_1873     56.0  0.032389  0.030116  0.000450  3.346926
# GDSC1_Vorinostat_1012     64.0  0.050680  0.056461  0.000873  3.059176
# GDSC2_BMS-536924_1091     56.0  0.030580  0.048086  0.000883  3.053816
# CTRP2_COL-3_665914        45.0  0.683000  0.670939  0.001235  2.908296
# GDSC2_MG-132_1862         57.0  0.037413  0.047152  0.001311  2.882503
# ...                        ...       ...       ...       ...       ...
# GDSC1_Cetuximab_1114      56.0 -0.008850 -0.002537  0.018021  1.744215
# GDSC1_CGP-082996_54       21.0 -0.042919 -0.029612  0.016716  1.776858
# GDSC1_Sorafenib_30        23.0 -0.050612 -0.025775  0.012357  1.908071
# GDSC1_Doramapimod_1042    64.0 -0.010748 -0.005039  0.004896  2.310169
# GDSC1_PHA-665752_6        23.0 -0.014597 -0.000699  0.004664  2.331231
#
#                         significant                          drug_anno  \
# GDSC2_Buparlisib_1873             1                PI3K/MTOR signaling
# GDSC1_Vorinostat_1012             1                  Chromatin-related
# GDSC2_BMS-536924_1091             1                    IGF1R signaling
# CTRP2_COL-3_665914                1                             Others
# GDSC2_MG-132_1862                 1  Protein stability and degradation
# ...                             ...                                ...
# GDSC1_Cetuximab_1114              1                     EGFR signaling
# GDSC1_CGP-082996_54               1                         Cell cycle
# GDSC1_Sorafenib_30                1                      RTK signaling
# GDSC1_Doramapimod_1042            1              JNK and p38 signaling
# GDSC1_PHA-665752_6                1                      RTK signaling
#
#                              cid
# GDSC2_Buparlisib_1873   16654980
# GDSC1_Vorinostat_1012       5311
# GDSC2_BMS-536924_1091   10390396
# CTRP2_COL-3_665914      54678924
# GDSC2_MG-132_1862         462382
# ...                          ...
# GDSC1_Cetuximab_1114    85668777
# GDSC1_CGP-082996_54     24825971
# GDSC1_Sorafenib_30        216239
# GDSC1_Doramapimod_1042    156422
# GDSC1_PHA-665752_6      10461815
#
# [800 rows x 8 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
anno_platinum=[]
for index in df_cor_pn.index:
    if 'isplatin' in index:
        anno_platinum.append(1)
    elif 'arboplatin' in index:
        anno_platinum.append(3)
    elif 'xaliplatin' in index:
        anno_platinum.append(2)
    else:
        anno_platinum.append(0)
df_cor_pn['platinum_color']=anno_platinum

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[drug_order[2:]]
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')   
#ax.set_yticklabels(sns_df.columns,fontsize=12)
# Out:
# PI3K/MTOR signaling
# RTK signaling
# Chromatin-related
# ERK MAPK signaling
# DNA inhibitor
# Antimetabolite
# EGFR signaling
# Antimicrotubule
# Cell cycle
# Apoptosis regulation
# Hormone-related
# Protein stability and degradation
# DNA alkylator
# Topoisomerase inhibitor
# WNT signaling
# Metabolism
# Genome integrity
# p53 pathway
# IGF1R signaling
# Cytoskeleton
# JNK and p38 signaling

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[drug_order[2:]]
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')   
#ax.set_yticklabels(sns_df.columns,fontsize=12)

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# GDSC2_Cisplatin_1005                        57.0  0.018483  0.026100
# CTRP2_oxaliplatin_375582                    55.0  0.266000  0.434020
# GDSC2_Oxaliplatin_1089                      58.0  0.006920  0.019415
# PRISM_carboplatin_BRD-K90947825-001-02-7    38.0  0.176583  0.047341
# CTRP2_carboplatin_26979                     59.0  0.007000  0.113893
# GDSC1_Cisplatin_1005                        64.0  0.005509  0.010835
# gCSI_Cisplatin_CID24191118                  22.0  0.032722  0.015302
# PRISM_oxaliplatin_BRD-K78960041-001-05-7    39.0 -0.005493 -0.005011
# GDSC2_Oxaliplatin_1806                      53.0 -0.000440  0.012289
# PRISM_cisplatin_BRD-K69172251-001-08-9      40.0 -0.011916 -0.019781
#
#                                            pvalues   mlog10p  significant  \
# GDSC2_Cisplatin_1005                      0.016176  1.791137            1
# CTRP2_oxaliplatin_375582                  0.034474  1.462503            1
# GDSC2_Oxaliplatin_1089                    0.157080  0.803879            0
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.274666  0.561196            0
# CTRP2_carboplatin_26979                   0.422557  0.374115            0
# GDSC1_Cisplatin_1005                      0.451014  0.345810            0
# gCSI_Cisplatin_CID24191118                0.472460  0.325635            0
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.996620  0.001470            0
# GDSC2_Oxaliplatin_1806                    0.566322  0.246937            0
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.090395  1.043854            0
#
#                                          drug_anno       cid  platinum_color  \
# GDSC2_Cisplatin_1005                      Platinum     84691               1
# CTRP2_oxaliplatin_375582                  Platinum  24197464               2
# GDSC2_Oxaliplatin_1089                    Platinum   5310940               2
# PRISM_carboplatin_BRD-K90947825-001-02-7  Platinum    426756               3
# CTRP2_carboplatin_26979                   Platinum     38904               3
# GDSC1_Cisplatin_1005                      Platinum     84691               1
# gCSI_Cisplatin_CID24191118                Platinum  24191118               1
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  Platinum  24197464               2
# GDSC2_Oxaliplatin_1806                    Platinum   5310940               2
# PRISM_cisplatin_BRD-K69172251-001-08-9    Platinum  24191118               1
#
#                                                FDR
# GDSC2_Cisplatin_1005                      0.161757
# CTRP2_oxaliplatin_375582                  0.172372
# GDSC2_Oxaliplatin_1089                    0.392700
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.549331
# CTRP2_carboplatin_26979                   0.590576
# GDSC1_Cisplatin_1005                      0.590576
# gCSI_Cisplatin_CID24191118                0.590576
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.996620
# GDSC2_Oxaliplatin_1806                    0.629247
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.301317

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# GDSC2_Niraparib_1177                        53.0  0.006844  0.019611
# GDSC2_Talazoparib_1259                      55.0  0.014545  0.046702
# CTRP2_olaparib_411867                       59.0  0.243000  0.076579
# GDSC2_Olaparib_1017                         57.0  0.003092  0.008316
# PRISM_olaparib_BRD-K02113016-001-19-6       38.0  0.028760  0.004135
# CTRP2_veliparib_606034                      59.0  0.009000  0.145919
# PRISM_niraparib_BRD-K54955827-001-02-2      40.0  0.020144  0.000672
# PRISM_talazoparib_BRD-K95142244-001-01-5    41.0  0.034146 -0.011490
# GDSC1_Olaparib_1017                         64.0  0.000315  0.004148
# GDSC1_Veliparib_1018                        64.0 -0.001262  0.001761
# GDSC1_Rucaparib_1175                        63.0 -0.002709 -0.001898
# GDSC1_Talazoparib_1259                      62.0 -0.000891 -0.019967
# PRISM_olaparib_BRD-K02113016-001-15-4       38.0 -0.120727 -0.061220
# GDSC1_Olaparib_1495                         60.0 -0.010195 -0.008666
#
#                                            pvalues   mlog10p  significant  \
# GDSC2_Niraparib_1177                      0.016287  1.788167            1
# GDSC2_Talazoparib_1259                    0.096331  1.016234            0
# CTRP2_olaparib_411867                     0.276868  0.557727            0
# GDSC2_Olaparib_1017                       0.326239  0.486464            0
# PRISM_olaparib_BRD-K02113016-001-19-6     0.396206  0.402079            0
# CTRP2_veliparib_606034                    0.462486  0.334901            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.492405  0.307677            0
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.897895  0.046774            0
# GDSC1_Olaparib_1017                       0.948613  0.022911            0
# GDSC1_Veliparib_1018                      0.560090  0.251742            0
# GDSC1_Rucaparib_1175                      0.461916  0.335437            0
# GDSC1_Talazoparib_1259                    0.387853  0.411333            0
# PRISM_olaparib_BRD-K02113016-001-15-4     0.086624  1.062360            0
# GDSC1_Olaparib_1495                       0.058996  1.229174            0
#
#                                                drug_anno        cid  \
# GDSC2_Niraparib_1177                      PARP inhibitor   24958200
# GDSC2_Talazoparib_1259                    PARP inhibitor   44819241
# CTRP2_olaparib_411867                     PARP inhibitor   23725625
# GDSC2_Olaparib_1017                       PARP inhibitor   23725625
# PRISM_olaparib_BRD-K02113016-001-19-6     PARP inhibitor   23725625
# CTRP2_veliparib_606034                    PARP inhibitor   11960529
# PRISM_niraparib_BRD-K54955827-001-02-2    PARP inhibitor   24958200
# PRISM_talazoparib_BRD-K95142244-001-01-5  PARP inhibitor  135565082
# GDSC1_Olaparib_1017                       PARP inhibitor   23725625
# GDSC1_Veliparib_1018                      PARP inhibitor   11960529
# GDSC1_Rucaparib_1175                      PARP inhibitor    9931953
# GDSC1_Talazoparib_1259                    PARP inhibitor   44819241
# PRISM_olaparib_BRD-K02113016-001-15-4     PARP inhibitor   23725625
# GDSC1_Olaparib_1495                       PARP inhibitor   23725625
#
#                                           platinum_color       FDR
# GDSC2_Niraparib_1177                                   0  0.228014
# GDSC2_Talazoparib_1259                                 0  0.337159
# CTRP2_olaparib_411867                                  0  0.626698
# GDSC2_Olaparib_1017                                    0  0.626698
# PRISM_olaparib_BRD-K02113016-001-19-6                  0  0.626698
# CTRP2_veliparib_606034                                 0  0.626698
# PRISM_niraparib_BRD-K54955827-001-02-2                 0  0.626698
# PRISM_talazoparib_BRD-K95142244-001-01-5               0  0.948613
# GDSC1_Olaparib_1017                                    0  0.948613
# GDSC1_Veliparib_1018                                   0  0.653438
# GDSC1_Rucaparib_1175                                   0  0.626698
# GDSC1_Talazoparib_1259                                 0  0.626698
# PRISM_olaparib_BRD-K02113016-001-15-4                  0  0.337159
# GDSC1_Olaparib_1495                                    0  0.337159

# %%
# colorbar
from matplotlib.colors import Normalize, TwoSlopeNorm
from matplotlib.colorbar import ColorbarBase
cmap=plt.get_cmap("coolwarm")
vmin=-0.3
vmax=0.3
bounds=[-0.3,0,0.3]
fontsize=10
label=""
orientation='vertical'
norm = Normalize(vmin=vmin, vmax=vmax)

fig=plt.figure(figsize=(0.2,0.8))
ax=fig.add_subplot(111)
cbar = ColorbarBase(ax, cmap=cmap, norm=norm,
ticks=bounds, orientation=orientation,label=label,)
ax.tick_params(labelsize=fontsize)#,labelleft=True,labelright=False)

# %%
# colorbar
from matplotlib.colors import Normalize, TwoSlopeNorm
from matplotlib.colorbar import ColorbarBase
cmap=plt.get_cmap("Greens")
vmin=0
vmax=3
bounds=[0,1,2,3]
fontsize=10
label=''
orientation='vertical'
norm = Normalize(vmin=vmin, vmax=vmax)

fig=plt.figure(figsize=(0.2,0.8))
ax=fig.add_subplot(111)
cbar = ColorbarBase(ax, cmap=cmap, norm=norm,
ticks=bounds, orientation=orientation,label=label)
ax.tick_params(labelsize=fontsize)#,labelleft=True,labelright=False)

# %% [markdown]
# ## Correlations with HRD score and Signature 3

# %%
df=df0.copy()

# %%
in_df=df.copy()
#plt_df=plt_df[plt_df[cat]=='']
val1,val2,val3='HRD_score_broad','SigMA_broad','BRCA_status'
plt_df=in_df[[val1,val2]].dropna()
print(plt_df.shape)
x,y=plt_df[val1],plt_df[val2]

fig=plt.figure(figsize=(3,3))
ax=fig.add_subplot(111)
ax.scatter(x,y,s=3,c='grey')
ax.set_xlabel(val1)
ax.set_ylabel(val2)
# linear regression, Pearson correlation
lr=stats.linregress(x,y)
a,b,r,p=lr.slope,lr.intercept, lr.rvalue,lr.pvalue
ax.plot(x,a*x+b,lw=1,c='k')

plt_df2=in_df[[val1,val2,val3]].dropna()
plt_df3=plt_df2[plt_df2[val3]=='BRCA1_methylation']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='lime')

plt_df3=plt_df2[plt_df2[val3]=='BRCA1_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='red')

plt_df3=plt_df2[plt_df2[val3]=='BRCA2_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='blue')

ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)

print('r = {:.3f}, p = {:.2e}'.format(r,p))
# Out:
# (914, 2)
# r = 0.475, p = 1.25e-52

# %%
plt_df=df
cat='BRCA_status'
val='HRD_score_broad'
order=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','wt']#'BRCA1_unknown' ]
order2=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','']#'BRCA1_unknown' ]
order3=['$BRCA1$ LOH +','$BRCA1$ methylation','$BRCA2$ LOH +','HRR LOH +','$BRCA1$ LOH -','$BRCA2$ LOH -','HRR LOH -','WT']#'BRCA1_unknown' ]

#hue=
palette=['r','r','r','r','b','b','b','dimgrey']
fig=plt.figure(figsize=(4,3))
ax=fig.add_subplot(1,1,1)
#sns.violinplot(x=cat,y=val,data=plt_df,inner="stick",order=order,cut=0,palette=palette)
sns.swarmplot(x=cat,y=val,data=plt_df,s=3,order=order2,palette=palette)
sns.boxplot(x=cat,y=val,data=plt_df,boxprops={'alpha':0.5},sym='',order=order,palette=palette)
ax.set_xlabel('')
ax.set_ylabel('')
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)
ax.set_xticklabels(order3,rotation=45,fontsize=10,ha='right')
ax.tick_params('y',labelsize=8)

# %%
plt_df=df
cat='BRCA_status'
val='SigMA_broad'
order=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','wt']#'BRCA1_unknown' ]
order2=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','']#'BRCA1_unknown' ]
order3=['$BRCA1$ LOH +','$BRCA1$ methylation','$BRCA2$ LOH +','HRR LOH +','$BRCA1$ LOH -','$BRCA2$ LOH -','HRR LOH -','WT']#'BRCA1_unknown' ]

#hue=
palette=['r','r','r','r','b','b','b','dimgrey']
fig=plt.figure(figsize=(4,3))
ax=fig.add_subplot(1,1,1)
#sns.violinplot(x=cat,y=val,data=plt_df,inner="stick",order=order,cut=0,palette=palette)
sns.swarmplot(x=cat,y=val,data=plt_df,s=3,order=order2,palette=palette)
sns.boxplot(x=cat,y=val,data=plt_df,boxprops={'alpha':0.5},sym='',order=order,palette=palette)
ax.set_xlabel('')
ax.set_ylabel('')
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)
ax.set_xticklabels(order3,rotation=45,fontsize=10,ha='right')
ax.tick_params('y',labelsize=8)
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Genomic scar and Drug sensitivity

# %%
df=df0.copy()

# %%
len(drug_all)
# Out:
# 882

# %% [markdown]
# ### HRD score

# %%
ns,rs,ps=[],[],[]
for drug in drug_all:
    plt_df=df[['HRD_score_broad',drug]].dropna()
    a=plt_df['HRD_score_broad'].values
    b=plt_df[drug].values
    n=len(a)
    if n>= 50:
        r,p=stats.spearmanr(a,b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['pvalues']=ps
df_cor['rS']=rs
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['FDR']=multipletests(df_cor['pvalues'],method='fdr_bh')[1]
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor.shape
# Out:
# (866, 8)

# %%
df_cor_p=df_cor[df_cor['rS']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['rS']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                             Number       pvalues        rS    mlog10p  \
# GDSC2_Cytarabine_1006        520.0  2.013454e-20  0.390824  19.696058
# GDSC2_Oxaliplatin_1089       547.0  3.934597e-17  0.349203  16.405100
# GDSC2_Gemcitabine_1190       524.0  2.529287e-15  0.336328  14.597002
# GDSC2_Palbociclib_1054       533.0  8.500994e-15  0.327569  14.070530
# GDSC1_Lestaurtinib_1024      611.0  1.343798e-14  0.304755  13.871666
# ...                            ...           ...       ...        ...
# gCSI_Gemcitabine_CID356653   266.0  3.259199e-05 -0.251802   4.486889
# GDSC2_AZD3759_1915           525.0  2.225128e-05 -0.183950   4.652645
# GDSC2_Gefitinib_1010         520.0  6.620194e-06 -0.196131   5.179129
# GDSC2_GDC0810_1925           520.0  4.165356e-06 -0.200286   5.380348
# GDSC2_OSI-027_1594           188.0  3.376015e-07 -0.361773   6.471596
#
#                                      FDR  significant            drug_anno  \
# GDSC2_Cytarabine_1006       1.743651e-17            1       Antimetabolite
# GDSC2_Oxaliplatin_1089      1.703680e-14            1             Platinum
# GDSC2_Gemcitabine_1190      7.301209e-13            1       Antimetabolite
# GDSC2_Palbociclib_1054      1.840465e-12            1           Cell cycle
# GDSC1_Lestaurtinib_1024     2.041348e-12            1               Others
# ...                                  ...          ...                  ...
# gCSI_Gemcitabine_CID356653  1.920045e-04            1       Antimetabolite
# GDSC2_AZD3759_1915          1.396349e-04            1       EGFR signaling
# GDSC2_Gefitinib_1010        4.900075e-05            1       EGFR signaling
# GDSC2_GDC0810_1925          3.380977e-05            1      Hormone-related
# GDSC2_OSI-027_1594          3.846881e-06            1  PI3K/MTOR signaling
#
#                                  cid
# GDSC2_Cytarabine_1006           6253
# GDSC2_Oxaliplatin_1089       5310940
# GDSC2_Gemcitabine_1190         60750
# GDSC2_Palbociclib_1054       5330286
# GDSC1_Lestaurtinib_1024       126565
# ...                              ...
# gCSI_Gemcitabine_CID356653    356653
# GDSC2_AZD3759_1915          78209992
# GDSC2_Gefitinib_1010          123631
# GDSC2_GDC0810_1925          56941241
# GDSC2_OSI-027_1594          44224160
#
# [866 rows x 8 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[drug_order[2:]]
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')
# Out:
# PI3K/MTOR signaling
# RTK signaling
# Chromatin-related
# ERK MAPK signaling
# DNA inhibitor
# Antimetabolite
# EGFR signaling
# Antimicrotubule
# Cell cycle
# Apoptosis regulation
# Hormone-related
# Protein stability and degradation
# DNA alkylator
# Topoisomerase inhibitor
# WNT signaling
# Metabolism
# Genome integrity
# p53 pathway
# IGF1R signaling
# Cytoskeleton
# JNK and p38 signaling

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df.reindex(columns=drug_order[2:]).fillna(0)
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number       pvalues        rS  \
# GDSC2_Oxaliplatin_1089                     547.0  3.934597e-17  0.349203
# GDSC2_Cisplatin_1005                       530.0  2.019840e-12  0.299180
# CTRP2_oxaliplatin_375582                   729.0  3.122994e-11  0.242681
# GDSC2_Oxaliplatin_1806                     495.0  4.752044e-10  0.275161
# CTRP2_carboplatin_26979                    744.0  5.273959e-06  0.166061
# PRISM_oxaliplatin_BRD-K78960041-001-05-7   431.0  2.524657e-03  0.145137
# GDSC1_Cisplatin_1005                       612.0  4.585888e-02  0.080745
# gCSI_Cisplatin_CID24191118                 263.0  1.971092e-01  0.079788
# PRISM_carboplatin_BRD-K90947825-001-02-7   426.0  2.524674e-01  0.055566
# PRISM_cisplatin_BRD-K69172251-001-08-9     429.0  1.643623e-02 -0.115777
#
#                                             mlog10p           FDR  \
# GDSC2_Oxaliplatin_1089                    16.405100  3.934597e-16
# GDSC2_Cisplatin_1005                      11.694683  1.009920e-11
# CTRP2_oxaliplatin_375582                  10.505429  1.040998e-10
# GDSC2_Oxaliplatin_1806                     9.323120  1.188011e-09
# CTRP2_carboplatin_26979                    5.277863  1.054792e-05
# PRISM_oxaliplatin_BRD-K78960041-001-05-7   2.597798  4.207762e-03
# GDSC1_Cisplatin_1005                       1.338577  5.732360e-02
# gCSI_Cisplatin_CID24191118                 0.705293  2.190103e-01
# PRISM_carboplatin_BRD-K90947825-001-02-7   0.597795  2.524674e-01
# PRISM_cisplatin_BRD-K69172251-001-08-9     1.784198  2.348032e-02
#
#                                           significant drug_anno       cid
# GDSC2_Oxaliplatin_1089                              1  Platinum   5310940
# GDSC2_Cisplatin_1005                                1  Platinum     84691
# CTRP2_oxaliplatin_375582                            1  Platinum  24197464
# GDSC2_Oxaliplatin_1806                              1  Platinum   5310940
# CTRP2_carboplatin_26979                             1  Platinum     38904
# PRISM_oxaliplatin_BRD-K78960041-001-05-7            1  Platinum  24197464
# GDSC1_Cisplatin_1005                                1  Platinum     84691
# gCSI_Cisplatin_CID24191118                          0  Platinum  24191118
# PRISM_carboplatin_BRD-K90947825-001-02-7            0  Platinum    426756
# PRISM_cisplatin_BRD-K69172251-001-08-9              1  Platinum  24191118

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number       pvalues        rS  \
# GDSC2_Talazoparib_1259                     516.0  2.138063e-10  0.274855
# GDSC2_Niraparib_1177                       498.0  1.607727e-09  0.266131
# GDSC1_Olaparib_1017                        611.0  2.994965e-06  0.187678
# CTRP2_olaparib_411867                      741.0  9.918360e-05  0.142508
# GDSC1_Talazoparib_1259                     588.0  9.937452e-03  0.106240
# GDSC2_Olaparib_1017                        528.0  1.561959e-02  0.105174
# CTRP1_rucaparib_628605                      51.0  3.468023e-02  0.296416
# GDSC1_Veliparib_1018                       612.0  6.365140e-02  0.075016
# CTRP1_veliparib_606034                      51.0  2.126428e-01  0.177532
# CTRP1_olaparib_411867                      109.0  2.345472e-01  0.114806
# CTRP2_veliparib_606034                     758.0  3.245377e-01  0.035831
# GDSC1_Rucaparib_1175                       606.0  6.784816e-01  0.016873
# GDSC1_Olaparib_1495                        582.0  9.714994e-01  0.001484
# PRISM_talazoparib_BRD-K95142244-001-01-5   459.0  8.400368e-01 -0.009447
# PRISM_olaparib_BRD-K02113016-001-19-6      415.0  7.970237e-01 -0.012663
# PRISM_niraparib_BRD-K54955827-001-02-2     451.0  2.918701e-01 -0.049740
# PRISM_olaparib_BRD-K02113016-001-15-4      423.0  1.847147e-01 -0.064614
#
#                                            mlog10p           FDR  significant  \
# GDSC2_Talazoparib_1259                    9.669980  3.634707e-09            1
# GDSC2_Niraparib_1177                      8.793788  1.366568e-08            1
# GDSC1_Olaparib_1017                       5.523608  1.697147e-05            1
# CTRP2_olaparib_411867                     4.003560  4.215303e-04            1
# GDSC1_Talazoparib_1259                    2.002725  3.378734e-02            1
# GDSC2_Olaparib_1017                       1.806330  4.425551e-02            1
# CTRP1_rucaparib_628605                    1.459918  8.422340e-02            1
# GDSC1_Veliparib_1018                      1.196192  1.352592e-01            0
# CTRP1_veliparib_606034                    0.672349  3.614927e-01            0
# CTRP1_olaparib_411867                     0.629770  3.624821e-01            0
# CTRP2_veliparib_606034                    0.488735  4.243954e-01            0
# GDSC1_Rucaparib_1175                      0.168462  8.238705e-01            0
# GDSC1_Olaparib_1495                       0.012557  9.714994e-01            0
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.075702  8.925391e-01            0
# PRISM_olaparib_BRD-K02113016-001-19-6     0.098529  8.925391e-01            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.534810  4.134826e-01            0
# PRISM_olaparib_BRD-K02113016-001-15-4     0.733499  3.489055e-01            0
#
#                                                drug_anno        cid
# GDSC2_Talazoparib_1259                    PARP inhibitor   44819241
# GDSC2_Niraparib_1177                      PARP inhibitor   24958200
# GDSC1_Olaparib_1017                       PARP inhibitor   23725625
# CTRP2_olaparib_411867                     PARP inhibitor   23725625
# GDSC1_Talazoparib_1259                    PARP inhibitor   44819241
# GDSC2_Olaparib_1017                       PARP inhibitor   23725625
# CTRP1_rucaparib_628605                    PARP inhibitor    9931954
# GDSC1_Veliparib_1018                      PARP inhibitor   11960529
# CTRP1_veliparib_606034                    PARP inhibitor   11960529
# CTRP1_olaparib_411867                     PARP inhibitor   23725625
# CTRP2_veliparib_606034                    PARP inhibitor   11960529
# GDSC1_Rucaparib_1175                      PARP inhibitor    9931953
# GDSC1_Olaparib_1495                       PARP inhibitor   23725625
# PRISM_talazoparib_BRD-K95142244-001-01-5  PARP inhibitor  135565082
# PRISM_olaparib_BRD-K02113016-001-19-6     PARP inhibitor   23725625
# PRISM_niraparib_BRD-K54955827-001-02-2    PARP inhibitor   24958200
# PRISM_olaparib_BRD-K02113016-001-15-4     PARP inhibitor   23725625

# %%
# colorbar
from matplotlib.colors import Normalize, TwoSlopeNorm
from matplotlib.colorbar import ColorbarBase
cmap=plt.get_cmap("coolwarm")
vmin=-0.3
vmax=0.3
bounds=[-0.3,0,0.3]
fontsize=10
label=""
orientation='vertical'
norm = Normalize(vmin=vmin, vmax=vmax)

fig=plt.figure(figsize=(0.2,0.8))
ax=fig.add_subplot(111)
cbar = ColorbarBase(ax, cmap=cmap, norm=norm,
ticks=bounds, orientation=orientation,label=label,)
ax.tick_params(labelsize=fontsize)#,labelleft=True,labelright=False)

# %%
# colorbar
from matplotlib.colors import Normalize, TwoSlopeNorm
from matplotlib.colorbar import ColorbarBase
cmap=plt.get_cmap("Greens")
vmin=0
vmax=8
bounds=[0,2,4,6,8]
fontsize=10
label=''
orientation='vertical'
norm = Normalize(vmin=vmin, vmax=vmax)

fig=plt.figure(figsize=(0.2,0.8))
ax=fig.add_subplot(111)
cbar = ColorbarBase(ax, cmap=cmap, norm=norm,
ticks=bounds, orientation=orientation,label=label)
ax.tick_params(labelsize=fontsize)#,labelleft=True,labelright=False)

# %% [markdown]
# ### Signature 3

# %%
ns,rs,ps=[],[],[]
for drug in drug_all:
    plt_df=df[['SigMA_broad',drug]].dropna()
    a=plt_df['SigMA_broad'].values
    b=plt_df[drug].values
    n=len(a)
    if n>= 50:
        r,p=stats.spearmanr(a,b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['pvalues']=ps
df_cor['rS']=rs
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['FDR']=multipletests(df_cor['pvalues'],method='fdr_bh')[1]
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor.shape
# Out:
# (866, 8)

# %%
df_cor_p=df_cor[df_cor['rS']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['rS']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                                    Number       pvalues        rS   mlog10p  \
# GDSC1_VX-11e_262                    876.0  3.749505e-10  0.209589  9.426026
# GDSC1_(5Z)-7-Oxozeaenol_1242        869.0  3.496054e-09  0.198648  8.456422
# GDSC1_Refametinib_1014              882.0  9.725182e-09  0.191602  8.012102
# GDSC1_NVP-BHG712_295                876.0  1.240118e-08  0.190887  7.906537
# GDSC1_CI-1040_1015                  885.0  3.077220e-08  0.184780  7.511841
# ...                                   ...           ...       ...       ...
# gCSI_Vincaleukoblastine_CID241902   183.0  7.811361e-05 -0.287772  4.107273
# gCSI_Vincristine_CID5978            449.0  1.024263e-05 -0.206541  4.989589
# gCSI_Crizotinib_CID54613769         452.0  4.645823e-06 -0.213535  5.332937
# gCSI_Gemcitabine_CID356653          285.0  4.299256e-09 -0.338979  8.366607
# gCSI_Paclitaxel_CID36314            450.0  4.228150e-10 -0.288911  9.373850
#
#                                             FDR  significant  \
# GDSC1_VX-11e_262                   1.830789e-07            1
# GDSC1_(5Z)-7-Oxozeaenol_1242       9.307890e-07            1
# GDSC1_Refametinib_1014             1.684402e-06            1
# GDSC1_NVP-BHG712_295               1.789904e-06            1
# GDSC1_CI-1040_1015                 3.298664e-06            1
# ...                                         ...          ...
# gCSI_Vincaleukoblastine_CID241902  1.537418e-03            1
# gCSI_Vincristine_CID5978           3.365418e-04            1
# gCSI_Crizotinib_CID54613769        1.749253e-04            1
# gCSI_Gemcitabine_CID356653         9.307890e-07            1
# gCSI_Paclitaxel_CID36314           1.830789e-07            1
#
#                                             drug_anno       cid
# GDSC1_VX-11e_262                   ERK MAPK signaling  11634725
# GDSC1_(5Z)-7-Oxozeaenol_1242                   Others   9863776
# GDSC1_Refametinib_1014             ERK MAPK signaling  44182295
# GDSC1_NVP-BHG712_295                           Others  16747388
# GDSC1_CI-1040_1015                 ERK MAPK signaling   6918454
# ...                                               ...       ...
# gCSI_Vincaleukoblastine_CID241902     Antimicrotubule    241902
# gCSI_Vincristine_CID5978                       Others      5978
# gCSI_Crizotinib_CID54613769             RTK signaling  54613769
# gCSI_Gemcitabine_CID356653             Antimetabolite    356653
# gCSI_Paclitaxel_CID36314              Antimicrotubule     36314
#
# [866 rows x 8 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[drug_order[2:]]
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df.reindex(columns=drug_order[2:]).fillna(0)
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   pvalues        rS  \
# GDSC2_Oxaliplatin_1806                     701.0  0.000319  0.135572
# GDSC2_Oxaliplatin_1089                     770.0  0.002280  0.109798
# CTRP2_carboplatin_26979                    766.0  0.029960  0.078435
# GDSC2_Cisplatin_1005                       737.0  0.034544  0.077872
# GDSC1_Cisplatin_1005                       901.0  0.114076  0.052679
# CTRP2_oxaliplatin_375582                   755.0  0.314028  0.036690
# PRISM_oxaliplatin_BRD-K78960041-001-05-7   441.0  0.633329  0.022778
# gCSI_Cisplatin_CID24191118                 283.0  0.975764  0.001814
# PRISM_cisplatin_BRD-K69172251-001-08-9     438.0  0.226744 -0.057875
# PRISM_carboplatin_BRD-K90947825-001-02-7   436.0  0.216191 -0.059346
#
#                                            mlog10p       FDR  significant  \
# GDSC2_Oxaliplatin_1806                    3.496760  0.003186            1
# GDSC2_Oxaliplatin_1089                    2.641999  0.011402            1
# CTRP2_carboplatin_26979                   1.523457  0.086361            1
# GDSC2_Cisplatin_1005                      1.461621  0.086361            1
# GDSC1_Cisplatin_1005                      0.942807  0.228152            0
# CTRP2_oxaliplatin_375582                  0.503031  0.392535            0
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.198371  0.703699            0
# gCSI_Cisplatin_CID24191118                0.010655  0.975764            0
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.644465  0.323920            0
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.665162  0.323920            0
#
#                                          drug_anno       cid
# GDSC2_Oxaliplatin_1806                    Platinum   5310940
# GDSC2_Oxaliplatin_1089                    Platinum   5310940
# CTRP2_carboplatin_26979                   Platinum     38904
# GDSC2_Cisplatin_1005                      Platinum     84691
# GDSC1_Cisplatin_1005                      Platinum     84691
# CTRP2_oxaliplatin_375582                  Platinum  24197464
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  Platinum  24197464
# gCSI_Cisplatin_CID24191118                Platinum  24191118
# PRISM_cisplatin_BRD-K69172251-001-08-9    Platinum  24191118
# PRISM_carboplatin_BRD-K90947825-001-02-7  Platinum    426756

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   pvalues        rS  \
# GDSC2_Talazoparib_1259                     719.0  0.011784  0.093882
# GDSC2_Niraparib_1177                       701.0  0.049834  0.074111
# GDSC1_Talazoparib_1259                     867.0  0.057129  0.064632
# GDSC1_Olaparib_1017                        899.0  0.062683  0.062109
# GDSC1_Veliparib_1018                       900.0  0.253318  0.038117
# CTRP1_veliparib_606034                      51.0  0.661965  0.062715
# GDSC1_Olaparib_1495                        864.0  0.692911  0.013454
# PRISM_olaparib_BRD-K02113016-001-19-6      425.0  0.772159  0.014086
# CTRP1_olaparib_411867                      111.0  0.812412  0.022780
# CTRP2_veliparib_606034                     783.0  0.984998 -0.000673
# CTRP1_rucaparib_628605                      51.0  0.969834 -0.005430
# GDSC2_Olaparib_1017                        732.0  0.841268 -0.007415
# PRISM_niraparib_BRD-K54955827-001-02-2     461.0  0.683858 -0.019015
# GDSC1_Rucaparib_1175                       894.0  0.528302 -0.021118
# PRISM_olaparib_BRD-K02113016-001-15-4      433.0  0.425623 -0.038384
# PRISM_talazoparib_BRD-K95142244-001-01-5   469.0  0.154203 -0.065897
# CTRP2_olaparib_411867                      767.0  0.084610 -0.062311
#
#                                            mlog10p       FDR  significant  \
# GDSC2_Talazoparib_1259                    1.928723  0.200321            1
# GDSC2_Niraparib_1177                      1.302474  0.266403            1
# GDSC1_Talazoparib_1259                    1.243146  0.266403            0
# GDSC1_Olaparib_1017                       1.202850  0.266403            0
# GDSC1_Veliparib_1018                      0.596333  0.615202            0
# CTRP1_veliparib_606034                    0.179165  0.953437            0
# GDSC1_Olaparib_1495                       0.159322  0.953437            0
# PRISM_olaparib_BRD-K02113016-001-19-6     0.112293  0.953437            0
# CTRP1_olaparib_411867                     0.090224  0.953437            0
# CTRP2_veliparib_606034                    0.006565  0.984998            0
# CTRP1_rucaparib_628605                    0.013302  0.984998            0
# GDSC2_Olaparib_1017                       0.075066  0.953437            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.165034  0.953437            0
# GDSC1_Rucaparib_1175                      0.277118  0.953437            0
# PRISM_olaparib_BRD-K02113016-001-15-4     0.370975  0.904449            0
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.811908  0.436908            0
# CTRP2_olaparib_411867                     1.072578  0.287674            0
#
#                                                drug_anno        cid
# GDSC2_Talazoparib_1259                    PARP inhibitor   44819241
# GDSC2_Niraparib_1177                      PARP inhibitor   24958200
# GDSC1_Talazoparib_1259                    PARP inhibitor   44819241
# GDSC1_Olaparib_1017                       PARP inhibitor   23725625
# GDSC1_Veliparib_1018                      PARP inhibitor   11960529
# CTRP1_veliparib_606034                    PARP inhibitor   11960529
# GDSC1_Olaparib_1495                       PARP inhibitor   23725625
# PRISM_olaparib_BRD-K02113016-001-19-6     PARP inhibitor   23725625
# CTRP1_olaparib_411867                     PARP inhibitor   23725625
# CTRP2_veliparib_606034                    PARP inhibitor   11960529
# CTRP1_rucaparib_628605                    PARP inhibitor    9931954
# GDSC2_Olaparib_1017                       PARP inhibitor   23725625
# PRISM_niraparib_BRD-K54955827-001-02-2    PARP inhibitor   24958200
# GDSC1_Rucaparib_1175                      PARP inhibitor    9931953
# PRISM_olaparib_BRD-K02113016-001-15-4     PARP inhibitor   23725625
# PRISM_talazoparib_BRD-K95142244-001-01-5  PARP inhibitor  135565082
# CTRP2_olaparib_411867                     PARP inhibitor   23725625

# %% [markdown]
# # Exclusively in Breast and Ovarysel_cancer

# %%
df_sel=df0[df0['primary_disease'].isin(['Ovarian Cancer','Breast Cancer'])]
df_sel
# Out:
#            cell_line_name stripped_cell_line_name      CCLE_Name  \
# DepMap_ID
# ACH-000288         BT-549                   BT549   BT549_BREAST
# ACH-000333        JHOM-2B                  JHOM2B   JHOM2B_OVARY
# ACH-000635        SNU-119                  SNU119   SNU119_OVARY
# ACH-001719        OCI-C4P                  OCIC4P   OCIC4P_OVARY
# ACH-001991          NZOV9                   NZOV9    NZOV9_OVARY
# ...                   ...                     ...            ...
# ACH-002149            KGN                     KGN      KGN_OVARY
# ACH-002163       MRK-nu-1                  MRKNU1  MRKNU1_BREAST
# ACH-002179         OCUB-M                   OCUBM   OCUBM_BREAST
# ACH-002181        OVCA420                 OVCA420  OVCA420_OVARY
# ACH-002183          OVMIU                   OVMIU    OVMIU_OVARY
#
#                      alias  COSMICID     sex              source       RRID  \
# DepMap_ID
# ACH-000288             NaN    905951  Female                ATCC  CVCL_1092
# ACH-000333             NaN        -1  Female               RIKEN  CVCL_4645
# ACH-000635             NaN        -1  Female                KCLB  CVCL_5014
# ACH-001719             NaN        -1  Female        Academic lab  CVCL_DH05
# ACH-001991  NZOV 9, NZOV-9        -1  Female  CellBank Australia  CVCL_LJ73
# ...                    ...       ...     ...                 ...        ...
# ACH-002149             NaN    924186  Female              Sanger  CVCL_0375
# ACH-002163             NaN    908151  Female              Sanger  CVCL_1428
# ACH-002179             NaN    909256  Female              Sanger  CVCL_1621
# ACH-002181             NaN   1480364  Female              Sanger  CVCL_3935
# ACH-002183             NaN   1240200     NaN              Sanger  CVCL_3112
#
#             WTSI_Master_Cell_ID sample_collection_site primary_or_metastasis  \
# DepMap_ID
# ACH-000288               1835.0                 breast               Primary
# ACH-000333                  NaN                  ovary               Primary
# ACH-000635                  NaN                ascites            Metastasis
# ACH-001719                  NaN                  ovary               Primary
# ACH-001991                  NaN                  ovary               Primary
# ...                         ...                    ...                   ...
# ACH-002149                 11.0                abdomen                   NaN
# ACH-002163                385.0                 breast                   NaN
# ACH-002179               1002.0       pleural_effusion            Metastasis
# ACH-002181               1949.0                  ovary                   NaN
# ACH-002183                373.0                  ovary                   NaN
#
#            primary_disease                                Subtype  age  \
# DepMap_ID
# ACH-000288   Breast Cancer                Breast Ductal Carcinoma   72
# ACH-000333  Ovarian Cancer               Adenocarcinoma, mucinous   56
# ACH-000635  Ovarian Cancer  Cystadenocarcinoma, high grade serous   50
# ACH-001719  Ovarian Cancer             Adenocarcinoma, clear cell  NaN
# ACH-001991  Ovarian Cancer           Adenocarcinoma, endometrioid   47
# ...                    ...                                    ...  ...
# ACH-002149  Ovarian Cancer                   Granulosa Cell Tumor   63
# ACH-002163   Breast Cancer                              Carcinoma   46
# ACH-002179   Breast Cancer                              Carcinoma   53
# ACH-002181  Ovarian Cancer                 Adenocarcinoma, serous  NaN
# ACH-002183  Ovarian Cancer      Adenocarcinoma, high grade serous  NaN
#
#            Sanger_Model_ID                             depmap_public_comments  \
# DepMap_ID
# ACH-000288       SIDM00122                                                NaN
# ACH-000333             NaN                                                NaN
# ACH-000635             NaN                                                NaN
# ACH-001719             NaN                                                NaN
# ACH-001991             NaN                                                NaN
# ...                    ...                                                ...
# ACH-002149       SIDM00302                                                NaN
# ACH-002163       SIDM00562                                                NaN
# ACH-002179       SIDM00241                                                NaN
# ACH-002181       SIDM00967                                                NaN
# ACH-002183       SIDM00465  This line is a OVSAYO derivative (ICLAC). DepM...
#
#            lineage          lineage_subtype lineage_sub_subtype  \
# DepMap_ID
# ACH-000288  breast  breast_ductal_carcinoma       ERneg_HER2neg
# ACH-000333   ovary     ovary_adenocarcinoma            mucinous
# ACH-000635   ovary     ovary_adenocarcinoma   high_grade_serous
# ACH-001719   ovary     ovary_adenocarcinoma          clear_cell
# ACH-001991   ovary     ovary_adenocarcinoma        endometrioid
# ...            ...                      ...                 ...
# ACH-002149   ovary     granulosa_cell_tumor                 NaN
# ACH-002163  breast         breast_carcinoma                 NaN
# ACH-002179  breast         breast_carcinoma                 NaN
# ACH-002181   ovary     ovary_adenocarcinoma              serous
# ACH-002183   ovary     ovary_adenocarcinoma   high_grade_serous
#
#            lineage_molecular_subtype default_growth_pattern  \
# DepMap_ID
# ACH-000288                   basal_B           2D: adherent
# ACH-000333                       NaN                    NaN
# ACH-000635                       NaN                    NaN
# ACH-001719                       NaN           2D: adherent
# ACH-001991                       NaN           2D: adherent
# ...                              ...                    ...
# ACH-002149                       NaN                    NaN
# ACH-002163                       NaN                    NaN
# ACH-002179                       NaN                    NaN
# ACH-002181                       NaN                    NaN
# ACH-002183                       NaN                    NaN
#
#            model_manipulation model_manipulation_details patient_id  \
# DepMap_ID
# ACH-000288                NaN                        NaN  PT-hgWgpg
# ACH-000333                NaN                        NaN  PT-60XjJv
# ACH-000635                NaN                        NaN  PT-vHYCC2
# ACH-001719                NaN                        NaN  PT-l7kiMr
# ACH-001991                NaN                        NaN  PT-WTNLuu
# ...                       ...                        ...        ...
# ACH-002149                NaN                        NaN  PT-yB2Czj
# ACH-002163                NaN                        NaN  PT-IF9xYA
# ACH-002179                NaN                        NaN  PT-yqZ59K
# ACH-002181                NaN                        NaN  PT-B4cHwN
# ACH-002183                NaN                        NaN  PT-P1CUUK
#
#            parent_depmap_id                      Cellosaurus_NCIt_disease  \
# DepMap_ID
# ACH-000288              NaN  Invasive breast carcinoma of no special type
# ACH-000333              NaN               Ovarian mucinous adenocarcinoma
# ACH-000635              NaN      High grade ovarian serous adenocarcinoma
# ACH-001719              NaN             Ovarian clear cell adenocarcinoma
# ACH-001991              NaN           Ovarian endometrioid adenocarcinoma
# ...                     ...                                           ...
# ACH-002149              NaN                  Ovarian granulosa cell tumor
# ACH-002163              NaN                              Breast carcinoma
# ACH-002179              NaN                              Breast carcinoma
# ACH-002181              NaN                 Ovarian serous adenocarcinoma
# ACH-002183              NaN      High grade ovarian serous adenocarcinoma
#
#            Cellosaurus_NCIt_id  \
# DepMap_ID
# ACH-000288               C4194
# ACH-000333               C5243
# ACH-000635             C105555
# ACH-001719              C40078
# ACH-001991               C7979
# ...                        ...
# ACH-002149               C6261
# ACH-002163               C4872
# ACH-002179               C4872
# ACH-002181               C7550
# ACH-002183             C105555
#
#                                            Cellosaurus_issues  PLOIDY  PURITY  \
# DepMap_ID
# ACH-000288                                                NaN    1.34    1.00
# ACH-000333                                                NaN    2.05    1.00
# ACH-000635                                                NaN    3.12    0.99
# ACH-001719                                                NaN     NaN     NaN
# ACH-001991                                                NaN     NaN     NaN
# ...                                                       ...     ...     ...
# ACH-002149                                                NaN     NaN     NaN
# ACH-002163                                                NaN     NaN     NaN
# ACH-002179                                                NaN     NaN     NaN
# ACH-002181                                                NaN     NaN     NaN
# ACH-002183  Contaminated. Shown to be a OVSAYO derivative ...     NaN     NaN
#
#             MUTATION_RATE DOUBLING_TIME_FROM_VENDOR  DOUBLING_TIME  \
# DepMap_ID
# ACH-000288     100.467969                       NaN           98.4
# ACH-000333     142.741222                       NaN            NaN
# ACH-000635     171.736406                    53 hrs            NaN
# ACH-001719            NaN                       NaN            NaN
# ACH-001991            NaN                       NaN            NaN
# ...                   ...                       ...            ...
# ACH-002149            NaN                       NaN            NaN
# ACH-002163            NaN                       NaN            NaN
# ACH-002179            NaN                       NaN            NaN
# ACH-002181            NaN                       NaN            NaN
# ACH-002183            NaN                       NaN            NaN
#
#             GENOME_DOUBLINGS  SigMA_broad BRCA1    BRCA2      ATM ATR  \
# DepMap_ID
# ACH-000288               0.0     0.585270    wt       wt       wt  wt
# ACH-000333               0.0     0.476021    wt       wt       wt  wt
# ACH-000635               1.0     0.678921    wt       wt       wt  wt
# ACH-001719               NaN     0.388043    wt       wt       wt  wt
# ACH-001991               NaN     0.281871    wt  unknown  unknown  wt
# ...                      ...          ...   ...      ...      ...  ..
# ACH-002149               NaN     0.576882    wt       wt       wt  wt
# ACH-002163               NaN     0.506565    wt   nonLOH       wt  wt
# ACH-002179               NaN     0.601634    wt       wt       wt  wt
# ACH-002181               NaN     0.631446    wt       wt       wt  wt
# ACH-002183               NaN     0.686801    wt       wt       wt  wt
#
#               BARD1 BLM BRIP1 CDK12 CHEK1    CHEK2 FANCA FANCC FANCD2 FANCE  \
# DepMap_ID
# ACH-000288       wt  wt    wt    wt    wt       wt    wt    wt     wt    wt
# ACH-000333       wt  wt    wt    wt    wt       wt    wt    wt     wt    wt
# ACH-000635       wt  wt    wt    wt    wt       wt    wt    wt     wt    wt
# ACH-001719  unknown  wt    wt    wt    wt       wt    wt    wt     wt    wt
# ACH-001991       wt  wt    wt    wt    wt  unknown    wt    wt     wt    wt
# ...             ...  ..   ...   ...   ...      ...   ...   ...    ...   ...
# ACH-002149       wt  wt    wt    wt    wt       wt    wt    wt     wt    wt
# ACH-002163       wt  wt    wt    wt    wt       wt    wt    wt     wt    wt
# ACH-002179       wt  wt    wt    wt    wt       wt    wt    wt     wt    wt
# ACH-002181       wt  wt    wt    wt    wt       wt    wt    wt     wt    wt
# ACH-002183       wt  wt    wt    wt    wt       wt    wt    wt     wt    wt
#
#            FANCF  ... CTRP2_vandetanib_349002 CTRP2_veliparib_606034  \
# DepMap_ID         ...
# ACH-000288    wt  ...                  13.512                 14.589
# ACH-000333    wt  ...                     NaN                    NaN
# ACH-000635    wt  ...                  10.976                 14.526
# ACH-001719    wt  ...                     NaN                    NaN
# ACH-001991    wt  ...                     NaN                    NaN
# ...          ...  ...                     ...                    ...
# ACH-002149    wt  ...                     NaN                    NaN
# ACH-002163    wt  ...                     NaN                    NaN
# ACH-002179    wt  ...                     NaN                    NaN
# ACH-002181    wt  ...                     NaN                    NaN
# ACH-002183    wt  ...                     NaN                    NaN
#
#            CTRP2_vincristine_62602 CTRP2_vorapaxar_660136  \
# DepMap_ID
# ACH-000288                  9.5835                 13.323
# ACH-000333                     NaN                    NaN
# ACH-000635                  7.6589                 14.809
# ACH-001719                     NaN                    NaN
# ACH-001991                     NaN                    NaN
# ...                            ...                    ...
# ACH-002149                     NaN                    NaN
# ACH-002163                     NaN                    NaN
# ACH-002179                     NaN                    NaN
# ACH-002181                     NaN                    NaN
# ACH-002183                     NaN                    NaN
#
#            CTRP2_vorinostat_56554 gCSI_Tanespimycin_CID6505803  \
# DepMap_ID
# ACH-000288                 13.623                          NaN
# ACH-000333                    NaN                          NaN
# ACH-000635                 13.133                          NaN
# ACH-001719                    NaN                          NaN
# ACH-001991                    NaN                          NaN
# ...                           ...                          ...
# ACH-002149                    NaN                          NaN
# ACH-002163                    NaN                          NaN
# ACH-002179                    NaN                          NaN
# ACH-002181                    NaN                          NaN
# ACH-002183                    NaN                          NaN
#
#            gCSI_5-Fluorouracil_CID3385 gCSI_AZ-628_CID11676786  \
# DepMap_ID
# ACH-000288                         NaN               -0.065000
# ACH-000333                         NaN                     NaN
# ACH-000635                         NaN                     NaN
# ACH-001719                         NaN                     NaN
# ACH-001991                         NaN                     NaN
# ...                                ...                     ...
# ACH-002149                         NaN                     NaN
# ACH-002163                         NaN                     NaN
# ACH-002179                         NaN                     NaN
# ACH-002181                         NaN                0.150444
# ACH-002183                         NaN                     NaN
#
#            gCSI_AZD7762_CID11152667 gCSI_AZD8055_CID25262965  \
# DepMap_ID
# ACH-000288                      NaN                      NaN
# ACH-000333                      NaN                      NaN
# ACH-000635                      NaN                      NaN
# ACH-001719                      NaN                      NaN
# ACH-001991                      NaN                      NaN
# ...                             ...                      ...
# ACH-002149                      NaN                      NaN
# ACH-002163                      NaN                      NaN
# ACH-002179                      NaN                      NaN
# ACH-002181                      NaN                      NaN
# ACH-002183                      NaN                      NaN
#
#            gCSI_Azacitidine_CID9444 gCSI_Bortezomib_CID387447  \
# DepMap_ID
# ACH-000288                 0.506444                       NaN
# ACH-000333                      NaN                       NaN
# ACH-000635                      NaN                       NaN
# ACH-001719                      NaN                       NaN
# ACH-001991                      NaN                       NaN
# ...                             ...                       ...
# ACH-002149                      NaN                       NaN
# ACH-002163                      NaN                       NaN
# ACH-002179                      NaN                       NaN
# ACH-002181                 0.323333                       NaN
# ACH-002183                      NaN                       NaN
#
#            gCSI_Bosutinib_CID5328940 gCSI_Chir-99021_CID9956119  \
# DepMap_ID
# ACH-000288                       NaN                        NaN
# ACH-000333                       NaN                        NaN
# ACH-000635                       NaN                        NaN
# ACH-001719                       NaN                        NaN
# ACH-001991                       NaN                        NaN
# ...                              ...                        ...
# ACH-002149                       NaN                        NaN
# ACH-002163                       NaN                        NaN
# ACH-002179                       NaN                        NaN
# ACH-002181                       NaN                        NaN
# ACH-002183                       NaN                        NaN
#
#             gCSI_Cisplatin_CID24191118  gCSI_Crizotinib_CID54613769  \
# DepMap_ID
# ACH-000288                    0.353556                     0.001889
# ACH-000333                         NaN                          NaN
# ACH-000635                         NaN                          NaN
# ACH-001719                         NaN                          NaN
# ACH-001991                         NaN                          NaN
# ...                                ...                          ...
# ACH-002149                         NaN                          NaN
# ACH-002163                         NaN                          NaN
# ACH-002179                         NaN                          NaN
# ACH-002181                    0.226111                    -0.020889
# ACH-002183                         NaN                          NaN
#
#             gCSI_Dabrafenib_CID44462760  gCSI_Dasatinib_CID3062316  \
# DepMap_ID
# ACH-000288                     0.111111                      0.139
# ACH-000333                          NaN                        NaN
# ACH-000635                          NaN                        NaN
# ACH-001719                          NaN                        NaN
# ACH-001991                          NaN                        NaN
# ...                                 ...                        ...
# ACH-002149                          NaN                        NaN
# ACH-002163                          NaN                        NaN
# ACH-002179                          NaN                        NaN
# ACH-002181                    -0.006222                        NaN
# ACH-002183                          NaN                        NaN
#
#             gCSI_Docetaxel_CID148124  gCSI_Erastin_CID11214940  \
# DepMap_ID
# ACH-000288                  0.641000                  0.199222
# ACH-000333                       NaN                       NaN
# ACH-000635                       NaN                       NaN
# ACH-001719                       NaN                       NaN
# ACH-001991                       NaN                       NaN
# ...                              ...                       ...
# ACH-002149                       NaN                       NaN
# ACH-002163                       NaN                       NaN
# ACH-002179                       NaN                       NaN
# ACH-002181                  0.276222                       NaN
# ACH-002183                       NaN                       NaN
#
#             gCSI_Erlotinib_CID176871  gCSI_Etoposide_CID36462  \
# DepMap_ID
# ACH-000288                  0.079778                      NaN
# ACH-000333                       NaN                      NaN
# ACH-000635                       NaN                      NaN
# ACH-001719                       NaN                      NaN
# ACH-001991                       NaN                      NaN
# ...                              ...                      ...
# ACH-002149                       NaN                      NaN
# ACH-002163                       NaN                      NaN
# ACH-002179                       NaN                      NaN
# ACH-002181                  0.445444                      NaN
# ACH-002183                       NaN                      NaN
#
#             gCSI_GSK2636771_CID56949517  gCSI_Gefitinib_CID123631  \
# DepMap_ID
# ACH-000288                     0.228111                       NaN
# ACH-000333                          NaN                       NaN
# ACH-000635                          NaN                       NaN
# ACH-001719                          NaN                       NaN
# ACH-001991                          NaN                       NaN
# ...                                 ...                       ...
# ACH-002149                          NaN                       NaN
# ACH-002163                          NaN                       NaN
# ACH-002179                          NaN                       NaN
# ACH-002181                          NaN                       NaN
# ACH-002183                          NaN                       NaN
#
#             gCSI_Gemcitabine_CID356653  gCSI_Ibrutinib_CID24821094  \
# DepMap_ID
# ACH-000288                    0.620889                    0.032000
# ACH-000333                         NaN                         NaN
# ACH-000635                         NaN                         NaN
# ACH-001719                         NaN                         NaN
# ACH-001991                         NaN                         NaN
# ...                                ...                         ...
# ACH-002149                         NaN                         NaN
# ACH-002163                         NaN                         NaN
# ACH-002179                         NaN                         NaN
# ACH-002181                         NaN                    0.547889
# ACH-002183                         NaN                         NaN
#
#             gCSI_JQ1 compound_CID71300862  gCSI_Lapatinib_CID208908  \
# DepMap_ID
# ACH-000288                       0.041000                  0.152778
# ACH-000333                            NaN                       NaN
# ACH-000635                            NaN                       NaN
# ACH-001719                            NaN                       NaN
# ACH-001991                            NaN                       NaN
# ...                                   ...                       ...
# ACH-002149                            NaN                       NaN
# ACH-002163                            NaN                       NaN
# ACH-002179                            NaN                       NaN
# ACH-002181                       0.093111                  0.520333
# ACH-002183                            NaN                       NaN
#
#             gCSI_Lenalidomide_CID216326  gCSI_MI-2_CID54765302  \
# DepMap_ID
# ACH-000288                     0.011444               0.207667
# ACH-000333                          NaN                    NaN
# ACH-000635                          NaN                    NaN
# ACH-001719                          NaN                    NaN
# ACH-001991                          NaN                    NaN
# ...                                 ...                    ...
# ACH-002149                          NaN                    NaN
# ACH-002163                          NaN                    NaN
# ACH-002179                          NaN                    NaN
# ACH-002181                          NaN               0.116000
# ACH-002183                          NaN                    NaN
#
#             gCSI_MK-2206_CID46930998  gCSI_MLN2480_CID25161177  \
# DepMap_ID
# ACH-000288                       NaN                  0.037333
# ACH-000333                       NaN                       NaN
# ACH-000635                       NaN                       NaN
# ACH-001719                       NaN                       NaN
# ACH-001991                       NaN                       NaN
# ...                              ...                       ...
# ACH-002149                       NaN                       NaN
# ACH-002163                       NaN                       NaN
# ACH-002179                       NaN                       NaN
# ACH-002181                       NaN                 -0.054000
# ACH-002183                       NaN                       NaN
#
#             gCSI_Methotrexate_CID126941  gCSI_NU-7441_CID11327430  \
# DepMap_ID
# ACH-000288                     0.860333                  0.199222
# ACH-000333                          NaN                       NaN
# ACH-000635                          NaN                       NaN
# ACH-001719                          NaN                       NaN
# ACH-001991                          NaN                       NaN
# ...                                 ...                       ...
# ACH-002149                          NaN                       NaN
# ACH-002163                          NaN                       NaN
# ACH-002179                          NaN                       NaN
# ACH-002181                     0.850889                  0.040667
# ACH-002183                          NaN                       NaN
#
#             gCSI_Narciclasine_CID72376  gCSI_Nilotinib_CID644241  \
# DepMap_ID
# ACH-000288                    0.908222                       NaN
# ACH-000333                         NaN                       NaN
# ACH-000635                         NaN                       NaN
# ACH-001719                         NaN                       NaN
# ACH-001991                         NaN                       NaN
# ...                                ...                       ...
# ACH-002149                         NaN                       NaN
# ACH-002163                         NaN                       NaN
# ACH-002179                         NaN                       NaN
# ACH-002181                         NaN                       NaN
# ACH-002183                         NaN                       NaN
#
#             gCSI_Oligomycin A_CID5472285  gCSI_PF-4708671_CID51371303  \
# DepMap_ID
# ACH-000288                      0.530444                     0.051333
# ACH-000333                           NaN                          NaN
# ACH-000635                           NaN                          NaN
# ACH-001719                           NaN                          NaN
# ACH-001991                           NaN                          NaN
# ...                                  ...                          ...
# ACH-002149                           NaN                          NaN
# ACH-002163                           NaN                          NaN
# ACH-002179                           NaN                          NaN
# ACH-002181                      0.354111                     0.051778
# ACH-002183                           NaN                          NaN
#
#             gCSI_PLX4720_CID24180719  gCSI_Paclitaxel_CID36314  \
# DepMap_ID
# ACH-000288                       NaN                  0.796556
# ACH-000333                       NaN                       NaN
# ACH-000635                       NaN                       NaN
# ACH-001719                       NaN                       NaN
# ACH-001991                       NaN                       NaN
# ...                              ...                       ...
# ACH-002149                       NaN                       NaN
# ACH-002163                       NaN                       NaN
# ACH-002179                       NaN                       NaN
# ACH-002181                       NaN                  0.381333
# ACH-002183                       NaN                       NaN
#
#             gCSI_Palbociclib_CID5330286  gCSI_TGX221_CID9907093  \
# DepMap_ID
# ACH-000288                     0.014333                0.211778
# ACH-000333                          NaN                     NaN
# ACH-000635                          NaN                     NaN
# ACH-001719                          NaN                     NaN
# ACH-001991                          NaN                     NaN
# ...                                 ...                     ...
# ACH-002149                          NaN                     NaN
# ACH-002163                          NaN                     NaN
# ACH-002179                          NaN                     NaN
# ACH-002181                          NaN                     NaN
# ACH-002183                          NaN                     NaN
#
#             gCSI_Tivantinib_CID11494412  gCSI_Vincaleukoblastine_CID241902  \
# DepMap_ID
# ACH-000288                     0.516778                           0.343222
# ACH-000333                          NaN                                NaN
# ACH-000635                          NaN                                NaN
# ACH-001719                          NaN                                NaN
# ACH-001991                          NaN                                NaN
# ...                                 ...                                ...
# ACH-002149                          NaN                                NaN
# ACH-002163                          NaN                                NaN
# ACH-002179                          NaN                                NaN
# ACH-002181                     0.280444                                NaN
# ACH-002183                          NaN                                NaN
#
#             gCSI_Vincristine_CID5978  gCSI_Vorinostat_CID5311  \
# DepMap_ID
# ACH-000288                  0.384444                 0.212000
# ACH-000333                       NaN                      NaN
# ACH-000635                       NaN                      NaN
# ACH-001719                       NaN                      NaN
# ACH-001991                       NaN                      NaN
# ...                              ...                      ...
# ACH-002149                       NaN                      NaN
# ACH-002163                       NaN                      NaN
# ACH-002179                       NaN                      NaN
# ACH-002181                  0.059667                 0.343556
# ACH-002183                       NaN                      NaN
#
#             HRD_score_broad  BRCA1_methylation        BRCA_status  \
# DepMap_ID
# ACH-000288             19.0                0.0                 wt
# ACH-000333             19.0                0.0                 wt
# ACH-000635             87.0                1.0  BRCA1_methylation
# ACH-001719              NaN                NaN        HRR_unknown
# ACH-001991              NaN                NaN        HRR_unknown
# ...                     ...                ...                ...
# ACH-002149              NaN                0.0                 wt
# ACH-002163              NaN                0.0       BRCA2_nonLOH
# ACH-002179              NaN                0.0                 wt
# ACH-002181              NaN                0.0                 wt
# ACH-002183              NaN                0.0                 wt
#
#             BRCA_alteration
# DepMap_ID
# ACH-000288                0
# ACH-000333                0
# ACH-000635                1
# ACH-001719                0
# ACH-001991                0
# ...                     ...
# ACH-002149                0
# ACH-002163                0
# ACH-002179                0
# ACH-002181                0
# ACH-002183                0
#
# [116 rows x 1035 columns]

# %%
Counter(df_sel['BRCA_alteration'])
# Out:
# Counter({0: 99, 1: 17})

# %%
df_drug=df_sel[~df_sel[drug_all].isna().all(axis=1)]

# %%
df_drug.shape
# Out:
# (108, 1035)

# %% [markdown]
# ## BRCA status vs Drug sensitivity

# %% [markdown]
# ### BRCA12 altaration

# %%
df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH']).sum()
# Out:
# 16

# %%
df_drug[~df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH'])].shape
# Out:
# (92, 1035)

# %%
df_drug[df_drug['BRCA_status'].isin(['wt'])].shape
# Out:
# (68, 1035)

# %%
df=df_drug.copy()

# %%
ns,rs,ps,ms,ms2=[],[],[],[],[]
n_limit=5 # limited five
for drug in drug_all:
    a=df[df['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH'])][drug].dropna().values
    b=df[df['BRCA_status'].isin(['wt'])][drug].dropna().values
    n=len(a)
    if n>= n_limit:
        r,p=stats.mannwhitneyu(a,b)
        m=np.median(a)-np.median(b)
        m2=np.mean(a)-np.mean(b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
        ms.append(m)
        ms2.append(m2)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)
        ms.append(np.nan)
        ms2.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['med_dif']=ms
df_cor['mean_dif']=ms2
df_cor['pvalues']=ps
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor
# Out:
#                                           Number   med_dif  mean_dif  \
# PRISM_dacarbazine_BRD-K35520305-001-16-9     7.0  0.004411  0.024056
# GDSC2_Olaparib_1017                         10.0 -0.001650 -0.004114
# CTRP2_GMX-1778_411843                       11.0 -1.256000 -0.339703
# PRISM_niraparib_BRD-K54955827-001-02-2       7.0  0.000882 -0.006946
# GDSC1_Temsirolimus_1016                     13.0  0.058304  0.080075
# ...                                          ...       ...       ...
# PRISM_abiraterone_BRD-K50071428-001-03-3     7.0  0.100718  0.116897
# PRISM_carmofur_BRD-K11630072-001-13-2        7.0  0.055878  0.030695
# GDSC2_Osimertinib_1919                       9.0  0.017505  0.021600
# PRISM_vindesine_BRD-K59753975-001-02-6       7.0  0.012200 -0.001914
# GDSC2_LCL161_1557                            8.0 -0.001769  0.019304
#
#                                            pvalues   mlog10p  significant  \
# PRISM_dacarbazine_BRD-K35520305-001-16-9  0.366663  0.435733            0
# GDSC2_Olaparib_1017                       0.543686  0.264652            0
# CTRP2_GMX-1778_411843                     0.244950  0.610923            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.574478  0.240727            0
# GDSC1_Temsirolimus_1016                   0.091043  1.040755            0
# ...                                            ...       ...          ...
# PRISM_abiraterone_BRD-K50071428-001-03-3  0.182382  0.739017            0
# PRISM_carmofur_BRD-K11630072-001-13-2     0.511725  0.290963            0
# GDSC2_Osimertinib_1919                    0.279847  0.553079            0
# PRISM_vindesine_BRD-K59753975-001-02-6    0.762310  0.117868            0
# GDSC2_LCL161_1557                         0.866047  0.062458            0
#
#                                                      drug_anno       cid
# PRISM_dacarbazine_BRD-K35520305-001-16-9         DNA alkylator   5353562
# GDSC2_Olaparib_1017                             PARP inhibitor  23725625
# CTRP2_GMX-1778_411843                                   Others        -1
# PRISM_niraparib_BRD-K54955827-001-02-2          PARP inhibitor  24958200
# GDSC1_Temsirolimus_1016                    PI3K/MTOR signaling   6918289
# ...                                                        ...       ...
# PRISM_abiraterone_BRD-K50071428-001-03-3       Hormone-related    132971
# PRISM_carmofur_BRD-K11630072-001-13-2           Antimetabolite      2577
# GDSC2_Osimertinib_1919                          EGFR signaling  71496458
# PRISM_vindesine_BRD-K59753975-001-02-6         Antimicrotubule     40839
# GDSC2_LCL161_1557                         Apoptosis regulation  24737642
#
# [744 rows x 8 columns]

# %%
df_cor_p=df_cor[df_cor['med_dif']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['med_dif']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                                           Number   med_dif  mean_dif  \
# GDSC1_Vorinostat_1012                       13.0  0.111457  0.121888
# GDSC1_AZD8055_1059                          13.0  0.081386  0.071590
# GDSC2_Navitoclax_1011                       10.0  0.077244  0.090903
# GDSC1_Dactolisib_1057                       13.0  0.112065  0.092064
# PRISM_abemaciclib_BRD-K33622447-066-01-9     7.0  0.060837  0.096869
# ...                                          ...       ...       ...
# CTRP2_cyanoquinoline 11_417415               5.0 -0.654000 -0.661560
# GDSC1_Vinorelbine_140                       10.0 -0.171084 -0.137701
# GDSC2_AZD5582_1617                           8.0 -0.262659 -0.173516
# CTRP2_birinapant_660778                     11.0 -1.352000 -1.458120
# PRISM_anagrelide_BRD-K62200014-003-10-5      7.0 -0.123953 -0.097101
#
#                                            pvalues   mlog10p  significant  \
# GDSC1_Vorinostat_1012                     0.002021  2.694373            1
# GDSC1_AZD8055_1059                        0.006866  2.163313            1
# GDSC2_Navitoclax_1011                     0.017603  1.754406            1
# GDSC1_Dactolisib_1057                     0.017810  1.749340            1
# PRISM_abemaciclib_BRD-K33622447-066-01-9  0.019117  1.718581            1
# ...                                            ...       ...          ...
# CTRP2_cyanoquinoline 11_417415            0.026553  1.575882            1
# GDSC1_Vinorelbine_140                     0.013642  1.865112            1
# GDSC2_AZD5582_1617                        0.011261  1.948442            1
# CTRP2_birinapant_660778                   0.010527  1.977710            1
# PRISM_anagrelide_BRD-K62200014-003-10-5   0.006277  2.202232            1
#
#                                                      drug_anno        cid
# GDSC1_Vorinostat_1012                        Chromatin-related       5311
# GDSC1_AZD8055_1059                         PI3K/MTOR signaling   25262965
# GDSC2_Navitoclax_1011                     Apoptosis regulation   24978538
# GDSC1_Dactolisib_1057                      PI3K/MTOR signaling   11977753
# PRISM_abemaciclib_BRD-K33622447-066-01-9            Cell cycle   46220502
# ...                                                        ...        ...
# CTRP2_cyanoquinoline 11_417415                          Others         -1
# GDSC1_Vinorelbine_140                          Antimicrotubule    5311497
# GDSC2_AZD5582_1617                        Apoptosis regulation   49847690
# CTRP2_birinapant_660778                                 Others   49836020
# PRISM_anagrelide_BRD-K62200014-003-10-5                 Others  135409400
#
# [744 rows x 8 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=2,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=2,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# GDSC2_Oxaliplatin_1089                       9.0  0.010165  0.023036
# PRISM_oxaliplatin_BRD-K78960041-001-05-7     6.0  0.052101  0.070142
# GDSC1_Cisplatin_1005                        13.0  0.007052  0.016001
# CTRP2_oxaliplatin_375582                    11.0  0.002000  0.365505
# PRISM_carboplatin_BRD-K90947825-001-02-7     5.0  0.125770  0.166115
# GDSC2_Oxaliplatin_1806                       8.0  0.003053  0.015113
# GDSC2_Cisplatin_1005                        10.0  0.009957  0.011970
# CTRP2_carboplatin_26979                     11.0  0.047000 -0.192754
# gCSI_Cisplatin_CID24191118                   9.0 -0.025444  0.002227
# PRISM_cisplatin_BRD-K69172251-001-08-9       6.0 -0.021881 -0.108718
#
#                                            pvalues   mlog10p  significant  \
# GDSC2_Oxaliplatin_1089                    0.158084  0.801111            0
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.318137  0.497386            0
# GDSC1_Cisplatin_1005                      0.452705  0.344185            0
# CTRP2_oxaliplatin_375582                  0.457829  0.339296            0
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.478318  0.320284            0
# GDSC2_Oxaliplatin_1806                    0.499709  0.301282            0
# GDSC2_Cisplatin_1005                      0.606429  0.217220            0
# CTRP2_carboplatin_26979                   0.695130  0.157934            0
# gCSI_Cisplatin_CID24191118                0.911468  0.040259            0
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.347861  0.458594            0
#
#                                          drug_anno       cid       FDR
# GDSC2_Oxaliplatin_1089                    Platinum   5310940  0.713871
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  Platinum  24197464  0.713871
# GDSC1_Cisplatin_1005                      Platinum     84691  0.713871
# CTRP2_oxaliplatin_375582                  Platinum  24197464  0.713871
# PRISM_carboplatin_BRD-K90947825-001-02-7  Platinum    426756  0.713871
# GDSC2_Oxaliplatin_1806                    Platinum   5310940  0.713871
# GDSC2_Cisplatin_1005                      Platinum     84691  0.758036
# CTRP2_carboplatin_26979                   Platinum     38904  0.772367
# gCSI_Cisplatin_CID24191118                Platinum  24191118  0.911468
# PRISM_cisplatin_BRD-K69172251-001-08-9    Platinum  24191118  0.713871

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# PRISM_niraparib_BRD-K54955827-001-02-2       7.0  0.000882 -0.006946
# CTRP2_veliparib_606034                      11.0  0.100500  0.004351
# CTRP2_olaparib_411867                       11.0  0.116000 -0.143277
# GDSC1_Veliparib_1018                        13.0  0.000513  0.002802
# GDSC2_Niraparib_1177                         8.0  0.001367  0.007262
# GDSC1_Rucaparib_1175                        13.0  0.005778  0.003404
# PRISM_olaparib_BRD-K02113016-001-19-6        6.0  0.033195 -0.016343
# PRISM_talazoparib_BRD-K95142244-001-01-5     7.0 -0.142761 -0.019207
# GDSC2_Talazoparib_1259                       9.0 -0.006032  0.014635
# GDSC1_Olaparib_1017                         13.0 -0.004335  0.004226
# GDSC2_Olaparib_1017                         10.0 -0.001650 -0.004114
# PRISM_olaparib_BRD-K02113016-001-15-4        7.0 -0.041518 -0.076727
# GDSC1_Olaparib_1495                         13.0 -0.018807 -0.016076
# GDSC1_Talazoparib_1259                      13.0 -0.076877 -0.059348
#
#                                            pvalues   mlog10p  significant  \
# PRISM_niraparib_BRD-K54955827-001-02-2    0.574478  0.240727            0
# CTRP2_veliparib_606034                    0.649024  0.187739            0
# CTRP2_olaparib_411867                     0.740745  0.130331            0
# GDSC1_Veliparib_1018                      0.751204  0.124242            0
# GDSC2_Niraparib_1177                      0.765283  0.116178            0
# GDSC1_Rucaparib_1175                      0.795340  0.099447            0
# PRISM_olaparib_BRD-K02113016-001-19-6     0.938846  0.027406            0
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.852933  0.069085            0
# GDSC2_Talazoparib_1259                    0.710365  0.148518            0
# GDSC1_Olaparib_1017                       0.688798  0.161908            0
# GDSC2_Olaparib_1017                       0.543686  0.264652            0
# PRISM_olaparib_BRD-K02113016-001-15-4     0.531496  0.274500            0
# GDSC1_Olaparib_1495                       0.205757  0.686646            0
# GDSC1_Talazoparib_1259                    0.090144  1.045062            0
#
#                                                drug_anno        cid       FDR
# PRISM_niraparib_BRD-K54955827-001-02-2    PARP inhibitor   24958200  0.918543
# CTRP2_veliparib_606034                    PARP inhibitor   11960529  0.918543
# CTRP2_olaparib_411867                     PARP inhibitor   23725625  0.918543
# GDSC1_Veliparib_1018                      PARP inhibitor   11960529  0.918543
# GDSC2_Niraparib_1177                      PARP inhibitor   24958200  0.918543
# GDSC1_Rucaparib_1175                      PARP inhibitor    9931953  0.918543
# PRISM_olaparib_BRD-K02113016-001-19-6     PARP inhibitor   23725625  0.938846
# PRISM_talazoparib_BRD-K95142244-001-01-5  PARP inhibitor  135565082  0.918543
# GDSC2_Talazoparib_1259                    PARP inhibitor   44819241  0.918543
# GDSC1_Olaparib_1017                       PARP inhibitor   23725625  0.918543
# GDSC2_Olaparib_1017                       PARP inhibitor   23725625  0.918543
# PRISM_olaparib_BRD-K02113016-001-15-4     PARP inhibitor   23725625  0.918543
# GDSC1_Olaparib_1495                       PARP inhibitor   23725625  0.918543
# GDSC1_Talazoparib_1259                    PARP inhibitor   44819241  0.918543

# %% [markdown]
# ### HRR alteration

# %%
df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH']).sum()
# Out:
# 25

# %%
df_drug[~df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH'])].shape
# Out:
# (83, 1035)

# %%
ns,rs,ps,ms,ms2=[],[],[],[],[]
n_limit=5
for drug in drug_all:
    a=df[df['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH'])][drug].dropna().values
    b=df[df['BRCA_status'].isin(['wt'])][drug].dropna().values
    n=len(a)
    if n> n_limit:
        r,p=stats.mannwhitneyu(a,b)
        m=np.median(a)-np.median(b)
        m2=np.mean(a)-np.mean(b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
        ms.append(m)
        ms2.append(m2)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)
        ms.append(np.nan)
        ms2.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['med_dif']=ms
df_cor['mean_dif']=ms2
df_cor['pvalues']=ps
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor
# Out:
#                                           Number   med_dif  mean_dif  \
# PRISM_dacarbazine_BRD-K35520305-001-16-9    10.0  0.013730  0.018640
# GDSC2_Olaparib_1017                         18.0 -0.004052 -0.002076
# GDSC1_PHA-665752_6                           6.0 -0.004309  0.001132
# CTRP2_GMX-1778_411843                       17.0 -0.449000  0.147009
# PRISM_niraparib_BRD-K54955827-001-02-2      10.0 -0.007060 -0.008838
# ...                                          ...       ...       ...
# PRISM_abiraterone_BRD-K50071428-001-03-3    10.0  0.122674  0.165819
# PRISM_carmofur_BRD-K11630072-001-13-2       11.0  0.055878  0.027275
# GDSC2_Osimertinib_1919                      17.0  0.012052  0.016636
# PRISM_vindesine_BRD-K59753975-001-02-6      11.0  0.012200  0.033777
# GDSC2_LCL161_1557                           13.0 -0.003704  0.000929
#
#                                            pvalues   mlog10p  significant  \
# PRISM_dacarbazine_BRD-K35520305-001-16-9  0.290534  0.536803            0
# GDSC2_Olaparib_1017                       0.503178  0.298278            0
# GDSC1_PHA-665752_6                        0.181019  0.742276            0
# CTRP2_GMX-1778_411843                     0.993823  0.002691            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.413613  0.383406            0
# ...                                            ...       ...          ...
# PRISM_abiraterone_BRD-K50071428-001-03-3  0.043165  1.364868            1
# PRISM_carmofur_BRD-K11630072-001-13-2     0.533219  0.273094            0
# GDSC2_Osimertinib_1919                    0.416255  0.380641            0
# PRISM_vindesine_BRD-K59753975-001-02-6    0.502219  0.299107            0
# GDSC2_LCL161_1557                         0.881885  0.054588            0
#
#                                                      drug_anno       cid
# PRISM_dacarbazine_BRD-K35520305-001-16-9         DNA alkylator   5353562
# GDSC2_Olaparib_1017                             PARP inhibitor  23725625
# GDSC1_PHA-665752_6                               RTK signaling  10461815
# CTRP2_GMX-1778_411843                                   Others        -1
# PRISM_niraparib_BRD-K54955827-001-02-2          PARP inhibitor  24958200
# ...                                                        ...       ...
# PRISM_abiraterone_BRD-K50071428-001-03-3       Hormone-related    132971
# PRISM_carmofur_BRD-K11630072-001-13-2           Antimetabolite      2577
# GDSC2_Osimertinib_1919                          EGFR signaling  71496458
# PRISM_vindesine_BRD-K59753975-001-02-6         Antimicrotubule     40839
# GDSC2_LCL161_1557                         Apoptosis regulation  24737642
#
# [776 rows x 8 columns]

# %%
df_cor_p=df_cor[df_cor['med_dif']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['med_dif']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                                           Number   med_dif  mean_dif  \
# GDSC2_Buparlisib_1873                       17.0  0.050812  0.056758
# GDSC1_TW 37_1149                            20.0  0.153210  0.108045
# GDSC1_Vorinostat_1012                       20.0  0.088250  0.096527
# GDSC1_CCT-018159_1170                       20.0  0.043502  0.034026
# PRISM_abemaciclib_BRD-K33622447-066-01-9    11.0  0.060837  0.091808
# ...                                          ...       ...       ...
# CTRP1_BMS-754807_417981                      6.0 -1.349500 -1.417009
# gCSI_Dabrafenib_CID44462760                 11.0 -0.033778 -0.107826
# CTRP2_cyanoquinoline 11_417415               8.0 -0.573000 -0.653835
# CTRP2_birinapant_660778                     16.0 -1.464500 -1.702507
# GDSC2_AZD5582_1617                          13.0 -0.199399 -0.174781
#
#                                            pvalues   mlog10p  significant  \
# GDSC2_Buparlisib_1873                     0.002875  2.541320            1
# GDSC1_TW 37_1149                          0.003116  2.506339            1
# GDSC1_Vorinostat_1012                     0.004635  2.333971            1
# GDSC1_CCT-018159_1170                     0.006062  2.217366            1
# PRISM_abemaciclib_BRD-K33622447-066-01-9  0.007618  2.118175            1
# ...                                            ...       ...          ...
# CTRP1_BMS-754807_417981                   0.016733  1.776426            1
# gCSI_Dabrafenib_CID44462760               0.012348  1.908413            1
# CTRP2_cyanoquinoline 11_417415            0.005778  2.238204            1
# CTRP2_birinapant_660778                   0.001571  2.803799            1
# GDSC2_AZD5582_1617                        0.001047  2.980135            1
#
#                                                                   drug_anno  \
# GDSC2_Buparlisib_1873                                   PI3K/MTOR signaling
# GDSC1_TW 37_1149                                       Apoptosis regulation
# GDSC1_Vorinostat_1012                                     Chromatin-related
# GDSC1_CCT-018159_1170                     Protein stability and degradation
# PRISM_abemaciclib_BRD-K33622447-066-01-9                         Cell cycle
# ...                                                                     ...
# CTRP1_BMS-754807_417981                                       RTK signaling
# gCSI_Dabrafenib_CID44462760                              ERK MAPK signaling
# CTRP2_cyanoquinoline 11_417415                                       Others
# CTRP2_birinapant_660778                                              Others
# GDSC2_AZD5582_1617                                     Apoptosis regulation
#
#                                                cid
# GDSC2_Buparlisib_1873                     16654980
# GDSC1_TW 37_1149                          11455910
# GDSC1_Vorinostat_1012                         5311
# GDSC1_CCT-018159_1170                      5327091
# PRISM_abemaciclib_BRD-K33622447-066-01-9  46220502
# ...                                            ...
# CTRP1_BMS-754807_417981                   24785538
# gCSI_Dabrafenib_CID44462760               44462760
# CTRP2_cyanoquinoline 11_417415                  -1
# CTRP2_birinapant_660778                   49836020
# GDSC2_AZD5582_1617                        49847690
#
# [776 rows x 8 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# PRISM_oxaliplatin_BRD-K78960041-001-05-7    10.0  0.082144  0.132910
# PRISM_carboplatin_BRD-K90947825-001-02-7     9.0  0.203643  0.180027
# GDSC2_Oxaliplatin_1089                      17.0  0.010165  0.019404
# CTRP2_oxaliplatin_375582                    16.0  0.191000  0.374090
# GDSC1_Cisplatin_1005                        20.0  0.013929  0.015475
# gCSI_Cisplatin_CID24191118                  12.0  0.158889  0.074390
# GDSC2_Oxaliplatin_1806                      13.0  0.004583  0.008705
# GDSC2_Cisplatin_1005                        18.0  0.007706  0.010610
# PRISM_cisplatin_BRD-K69172251-001-08-9      10.0 -0.021881 -0.064648
# CTRP2_carboplatin_26979                     17.0 -0.179000 -0.427786
#
#                                            pvalues   mlog10p  significant  \
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.041479  1.382167            1
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.107249  0.969607            0
# GDSC2_Oxaliplatin_1089                    0.186487  0.729351            0
# CTRP2_oxaliplatin_375582                  0.313295  0.504047            0
# GDSC1_Cisplatin_1005                      0.321850  0.492346            0
# gCSI_Cisplatin_CID24191118                0.333299  0.477167            0
# GDSC2_Oxaliplatin_1806                    0.496994  0.303649            0
# GDSC2_Cisplatin_1005                      0.497160  0.303504            0
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.346971  0.459706            0
# CTRP2_carboplatin_26979                   0.091295  1.039552            0
#
#                                          drug_anno       cid       FDR
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  Platinum  24197464  0.357496
# PRISM_carboplatin_BRD-K90947825-001-02-7  Platinum    426756  0.357496
# GDSC2_Oxaliplatin_1089                    Platinum   5310940  0.433714
# CTRP2_oxaliplatin_375582                  Platinum  24197464  0.433714
# GDSC1_Cisplatin_1005                      Platinum     84691  0.433714
# gCSI_Cisplatin_CID24191118                Platinum  24191118  0.433714
# GDSC2_Oxaliplatin_1806                    Platinum   5310940  0.497160
# GDSC2_Cisplatin_1005                      Platinum     84691  0.497160
# PRISM_cisplatin_BRD-K69172251-001-08-9    Platinum  24191118  0.433714
# CTRP2_carboplatin_26979                   Platinum     38904  0.357496

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# GDSC2_Talazoparib_1259                      17.0  0.021160  0.023576
# GDSC1_Rucaparib_1175                        20.0  0.006450  0.006751
# CTRP2_olaparib_411867                       16.0  0.061500 -0.194652
# GDSC2_Niraparib_1177                        13.0  0.004267  0.009930
# PRISM_olaparib_BRD-K02113016-001-19-6       10.0  0.026362 -0.031064
# PRISM_talazoparib_BRD-K95142244-001-01-5    11.0  0.015037  0.010431
# GDSC1_Veliparib_1018                        20.0 -0.000031  0.004012
# GDSC1_Olaparib_1017                         20.0 -0.002336  0.005082
# GDSC1_Olaparib_1495                         20.0 -0.010069 -0.007203
# GDSC2_Olaparib_1017                         18.0 -0.004052 -0.002076
# CTRP2_veliparib_606034                      16.0 -0.015500 -0.076268
# PRISM_olaparib_BRD-K02113016-001-15-4       11.0 -0.104524 -0.078835
# PRISM_niraparib_BRD-K54955827-001-02-2      10.0 -0.007060 -0.008838
# GDSC1_Talazoparib_1259                      19.0 -0.042265 -0.024027
#
#                                            pvalues   mlog10p  significant  \
# GDSC2_Talazoparib_1259                    0.224362  0.649051            0
# GDSC1_Rucaparib_1175                      0.393617  0.404927            0
# CTRP2_olaparib_411867                     0.456745  0.340326            0
# GDSC2_Niraparib_1177                      0.494310  0.306001            0
# PRISM_olaparib_BRD-K02113016-001-19-6     0.601834  0.220523            0
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.950374  0.022106            0
# GDSC1_Veliparib_1018                      0.903346  0.044146            0
# GDSC1_Olaparib_1017                       0.803157  0.095200            0
# GDSC1_Olaparib_1495                       0.554169  0.256358            0
# GDSC2_Olaparib_1017                       0.503178  0.298278            0
# CTRP2_veliparib_606034                    0.420983  0.375735            0
# PRISM_olaparib_BRD-K02113016-001-15-4     0.415583  0.381342            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.413613  0.383406            0
# GDSC1_Talazoparib_1259                    0.404438  0.393148            0
#
#                                                drug_anno        cid       FDR
# GDSC2_Talazoparib_1259                    PARP inhibitor   44819241  0.765971
# GDSC1_Rucaparib_1175                      PARP inhibitor    9931953  0.765971
# CTRP2_olaparib_411867                     PARP inhibitor   23725625  0.765971
# GDSC2_Niraparib_1177                      PARP inhibitor   24958200  0.765971
# PRISM_olaparib_BRD-K02113016-001-19-6     PARP inhibitor   23725625  0.765971
# PRISM_talazoparib_BRD-K95142244-001-01-5  PARP inhibitor  135565082  0.950374
# GDSC1_Veliparib_1018                      PARP inhibitor   11960529  0.950374
# GDSC1_Olaparib_1017                       PARP inhibitor   23725625  0.937016
# GDSC1_Olaparib_1495                       PARP inhibitor   23725625  0.765971
# GDSC2_Olaparib_1017                       PARP inhibitor   23725625  0.765971
# CTRP2_veliparib_606034                    PARP inhibitor   11960529  0.765971
# PRISM_olaparib_BRD-K02113016-001-15-4     PARP inhibitor   23725625  0.765971
# PRISM_niraparib_BRD-K54955827-001-02-2    PARP inhibitor   24958200  0.765971
# GDSC1_Talazoparib_1259                    PARP inhibitor   44819241  0.765971

# %% [markdown]
# ## Correlations with HRD score and Signature 3

# %%
df=df_sel.copy()

# %%
in_df=df.copy()
#plt_df=plt_df[plt_df[cat]=='']
val1,val2,val3='HRD_score_broad','SigMA_broad','BRCA_status'
plt_df=in_df[[val1,val2]].dropna()
print(plt_df.shape)
x,y=plt_df[val1],plt_df[val2]

fig=plt.figure(figsize=(3,3))
ax=fig.add_subplot(111)
ax.scatter(x,y,s=3,c='grey')
ax.set_xlabel(val1)
ax.set_ylabel(val2)
# linear regression, Pearson correlation
lr=stats.linregress(x,y)
a,b,r,p=lr.slope,lr.intercept, lr.rvalue,lr.pvalue
ax.plot(x,a*x+b,lw=1,c='k')

plt_df2=in_df[[val1,val2,val3]].dropna()
plt_df3=plt_df2[plt_df2[val3]=='BRCA1_methylation']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='lime')

plt_df3=plt_df2[plt_df2[val3]=='BRCA1_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='red')

plt_df3=plt_df2[plt_df2[val3]=='BRCA2_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='blue')

ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)

print('r = {:.3f}, p = {:.2e}'.format(r,p))
# Out:
# (99, 2)
# r = 0.634, p = 1.90e-12

# %%
plt_df=df
cat='BRCA_status'
val='HRD_score_broad'
order=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','wt']#'BRCA1_unknown' ]
order2=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','']#'BRCA1_unknown' ]
order3=['$BRCA1$ LOH +','$BRCA1$ methylation','$BRCA2$ LOH +','HRR LOH +','$BRCA1$ LOH -','$BRCA2$ LOH -','HRR LOH -','WT']#'BRCA1_unknown' ]

#hue=
palette=['r','r','r','r','b','b','b','dimgrey']
fig=plt.figure(figsize=(4,3))
ax=fig.add_subplot(1,1,1)
#sns.violinplot(x=cat,y=val,data=plt_df,inner="stick",order=order,cut=0,palette=palette)
sns.swarmplot(x=cat,y=val,data=plt_df,s=3,order=order2,palette=palette)
sns.boxplot(x=cat,y=val,data=plt_df,boxprops={'alpha':0.5},sym='',order=order,palette=palette)
ax.set_xlabel('')
ax.set_ylabel('')
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)
ax.set_xticklabels(order3,rotation=45,fontsize=10,ha='right')
ax.tick_params('y',labelsize=8)

# %%
plt_df=df
cat='BRCA_status'
val='SigMA_broad'
order=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','wt']#'BRCA1_unknown' ]
order2=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','']#'BRCA1_unknown' ]
order3=['$BRCA1$ LOH +','$BRCA1$ methylation','$BRCA2$ LOH +','HRR LOH +','$BRCA1$ LOH -','$BRCA2$ LOH -','HRR LOH -','WT']#'BRCA1_unknown' ]

#hue=
palette=['r','r','r','r','b','b','b','dimgrey']
fig=plt.figure(figsize=(4,3))
ax=fig.add_subplot(1,1,1)
#sns.violinplot(x=cat,y=val,data=plt_df,inner="stick",order=order,cut=0,palette=palette)
sns.swarmplot(x=cat,y=val,data=plt_df,s=3,order=order2,palette=palette)
sns.boxplot(x=cat,y=val,data=plt_df,boxprops={'alpha':0.5},sym='',order=order,palette=palette)
ax.set_xlabel('')
ax.set_ylabel('')
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)
ax.set_xticklabels(order3,rotation=45,fontsize=10,ha='right')
ax.tick_params('y',labelsize=8)

# %% [markdown]
# ## Genomic scar and Drug sensitivity

# %%
df=df_sel.copy()

# %%
len(drug_all)
# Out:
# 882

# %% [markdown]
# ### HRD score

# %%
ns,rs,ps=[],[],[]
for drug in drug_all:
    plt_df=df[['HRD_score_broad',drug]].dropna()
    a=plt_df['HRD_score_broad'].values
    b=plt_df[drug].values
    n=len(plt_df)
    if n>= 20: # limited 20
        r,p=stats.spearmanr(a,b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['pvalues']=ps
df_cor['rS']=rs
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['FDR']=multipletests(df_cor['pvalues'],method='fdr_bh')[1]
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor.shape
# Out:
# (803, 8)

# %%
df_cor_p=df_cor[df_cor['rS']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['rS']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                                            Number       pvalues        rS  \
# PRISM_temsirolimus_BRD-K42898655-001-01-8    51.0  3.588127e-08  0.681959
# PRISM_abemaciclib_BRD-K33622447-066-01-9     51.0  2.597013e-06  0.604783
# PRISM_palbociclib_BRD-K51313569-001-07-8     46.0  3.090147e-06  0.627248
# GDSC1_Temsirolimus_1016                      71.0  1.321755e-05  0.491887
# GDSC2_Palbociclib_1054                       69.0  3.896096e-05  0.473946
# ...                                           ...           ...       ...
# GDSC1_Avagacestat_1072                       71.0  5.244975e-02 -0.231143
# GDSC1_NG-25_260                              71.0  4.695185e-02 -0.236622
# CTRP2_cimetidine_26870                       22.0  3.988074e-02 -0.441112
# GDSC1_Navitoclax_1011                        71.0  2.238452e-02 -0.270757
# PRISM_cytarabine_BRD-K71847383-001-12-5      43.0  7.312846e-03 -0.403384
#
#                                             mlog10p       FDR  significant  \
# PRISM_temsirolimus_BRD-K42898655-001-01-8  7.445132  0.000029            1
# PRISM_abemaciclib_BRD-K33622447-066-01-9   5.585526  0.000827            1
# PRISM_palbociclib_BRD-K51313569-001-07-8   5.510021  0.000827            1
# GDSC1_Temsirolimus_1016                    4.878849  0.002653            1
# GDSC2_Palbociclib_1054                     4.409370  0.006257            1
# ...                                             ...       ...          ...
# GDSC1_Avagacestat_1072                     1.280257  0.304176            0
# GDSC1_NG-25_260                            1.328347  0.290018            1
# CTRP2_cimetidine_26870                     1.399237  0.260360            1
# GDSC1_Navitoclax_1011                      1.650052  0.203505            1
# PRISM_cytarabine_BRD-K71847383-001-12-5    2.135914  0.114266            1
#
#                                                       drug_anno       cid
# PRISM_temsirolimus_BRD-K42898655-001-01-8   PI3K/MTOR signaling   6918289
# PRISM_abemaciclib_BRD-K33622447-066-01-9             Cell cycle  46220502
# PRISM_palbociclib_BRD-K51313569-001-07-8             Cell cycle   5330286
# GDSC1_Temsirolimus_1016                     PI3K/MTOR signaling   6918289
# GDSC2_Palbociclib_1054                               Cell cycle   5330286
# ...                                                         ...       ...
# GDSC1_Avagacestat_1072                                   Others  46883536
# GDSC1_NG-25_260                                          Others  53340664
# CTRP2_cimetidine_26870                                   Others      2756
# GDSC1_Navitoclax_1011                      Apoptosis regulation  24978538
# PRISM_cytarabine_BRD-K71847383-001-12-5          Antimetabolite   5351180
#
# [803 rows x 8 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   pvalues        rS  \
# GDSC2_Oxaliplatin_1089                      67.0  0.000419  0.418854
# GDSC2_Cisplatin_1005                        68.0  0.002283  0.363919
# CTRP2_oxaliplatin_375582                    71.0  0.004257  0.335310
# GDSC1_Cisplatin_1005                        71.0  0.005416  0.326756
# PRISM_oxaliplatin_BRD-K78960041-001-05-7    49.0  0.049683  0.281945
# GDSC2_Oxaliplatin_1806                      57.0  0.058763  0.251860
# gCSI_Cisplatin_CID24191118                  58.0  0.188469  0.175158
# PRISM_carboplatin_BRD-K90947825-001-02-7    48.0  0.326072  0.144816
# CTRP2_carboplatin_26979                     72.0  0.996255  0.000563
# PRISM_cisplatin_BRD-K69172251-001-08-9      47.0  0.498919 -0.101102
#
#                                            mlog10p       FDR  significant  \
# GDSC2_Oxaliplatin_1089                    3.377486  0.004193            1
# GDSC2_Cisplatin_1005                      2.641421  0.011417            1
# CTRP2_oxaliplatin_375582                  2.370910  0.013539            1
# GDSC1_Cisplatin_1005                      2.266346  0.013539            1
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  1.303792  0.097938            1
# GDSC2_Oxaliplatin_1806                    1.230900  0.097938            0
# gCSI_Cisplatin_CID24191118                0.724760  0.269241            0
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.486686  0.407591            0
# CTRP2_carboplatin_26979                   0.001629  0.996255            0
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.301970  0.554355            0
#
#                                          drug_anno       cid
# GDSC2_Oxaliplatin_1089                    Platinum   5310940
# GDSC2_Cisplatin_1005                      Platinum     84691
# CTRP2_oxaliplatin_375582                  Platinum  24197464
# GDSC1_Cisplatin_1005                      Platinum     84691
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  Platinum  24197464
# GDSC2_Oxaliplatin_1806                    Platinum   5310940
# gCSI_Cisplatin_CID24191118                Platinum  24191118
# PRISM_carboplatin_BRD-K90947825-001-02-7  Platinum    426756
# CTRP2_carboplatin_26979                   Platinum     38904
# PRISM_cisplatin_BRD-K69172251-001-08-9    Platinum  24191118

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   pvalues        rS  \
# GDSC2_Niraparib_1177                        57.0  0.007916  0.348370
# GDSC2_Talazoparib_1259                      63.0  0.019768  0.293034
# PRISM_talazoparib_BRD-K95142244-001-01-5    51.0  0.024192  0.315348
# GDSC1_Olaparib_1017                         71.0  0.073520  0.213717
# PRISM_olaparib_BRD-K02113016-001-19-6       46.0  0.095593  0.248694
# GDSC2_Olaparib_1017                         67.0  0.120454  0.191557
# CTRP2_olaparib_411867                       74.0  0.195534  0.152181
# GDSC1_Veliparib_1018                        71.0  0.263300  0.134540
# GDSC1_Talazoparib_1259                      69.0  0.433229  0.095878
# PRISM_niraparib_BRD-K54955827-001-02-2      49.0  0.461107  0.107764
# GDSC1_Rucaparib_1175                        70.0  0.502216  0.081535
# PRISM_olaparib_BRD-K02113016-001-15-4       46.0  0.641734  0.070455
# GDSC1_Olaparib_1495                         70.0  0.981072 -0.002888
# CTRP2_veliparib_606034                      73.0  0.855500 -0.021686
# CTRP1_olaparib_411867                       21.0  0.508469 -0.152796
#
#                                            mlog10p       FDR  significant  \
# GDSC2_Niraparib_1177                      2.101478  0.118744            1
# GDSC2_Talazoparib_1259                    1.704040  0.120962            1
# PRISM_talazoparib_BRD-K95142244-001-01-5  1.616320  0.120962            1
# GDSC1_Olaparib_1017                       1.133594  0.275701            0
# PRISM_olaparib_BRD-K02113016-001-19-6     1.019575  0.286778            0
# GDSC2_Olaparib_1017                       0.919180  0.301134            0
# CTRP2_olaparib_411867                     0.708777  0.419002            0
# GDSC1_Veliparib_1018                      0.579549  0.493688            0
# GDSC1_Talazoparib_1259                    0.363282  0.635586            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.336198  0.635586            0
# GDSC1_Rucaparib_1175                      0.299110  0.635586            0
# PRISM_olaparib_BRD-K02113016-001-15-4     0.192645  0.740463            0
# GDSC1_Olaparib_1495                       0.008299  0.981072            0
# CTRP2_veliparib_606034                    0.067780  0.916607            0
# CTRP1_olaparib_411867                     0.293736  0.635586            0
#
#                                                drug_anno        cid
# GDSC2_Niraparib_1177                      PARP inhibitor   24958200
# GDSC2_Talazoparib_1259                    PARP inhibitor   44819241
# PRISM_talazoparib_BRD-K95142244-001-01-5  PARP inhibitor  135565082
# GDSC1_Olaparib_1017                       PARP inhibitor   23725625
# PRISM_olaparib_BRD-K02113016-001-19-6     PARP inhibitor   23725625
# GDSC2_Olaparib_1017                       PARP inhibitor   23725625
# CTRP2_olaparib_411867                     PARP inhibitor   23725625
# GDSC1_Veliparib_1018                      PARP inhibitor   11960529
# GDSC1_Talazoparib_1259                    PARP inhibitor   44819241
# PRISM_niraparib_BRD-K54955827-001-02-2    PARP inhibitor   24958200
# GDSC1_Rucaparib_1175                      PARP inhibitor    9931953
# PRISM_olaparib_BRD-K02113016-001-15-4     PARP inhibitor   23725625
# GDSC1_Olaparib_1495                       PARP inhibitor   23725625
# CTRP2_veliparib_606034                    PARP inhibitor   11960529
# CTRP1_olaparib_411867                     PARP inhibitor   23725625

# %% [markdown]
# ### Signature 3

# %%
ns,rs,ps=[],[],[]
for drug in drug_all:
    plt_df=df[['SigMA_broad',drug]].dropna()
    a=plt_df['SigMA_broad'].values
    b=plt_df[drug].values
    n=len(plt_df)
    if n>= 20:
        r,p=stats.spearmanr(a,b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['pvalues']=ps
df_cor['rS']=rs
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['FDR']=multipletests(df_cor['pvalues'],method='fdr_bh')[1]
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor.shape
# Out:
# (803, 8)

# %%
df_cor_p=df_cor[df_cor['rS']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['rS']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                                            Number       pvalues        rS  \
# PRISM_temsirolimus_BRD-K42898655-001-01-8    51.0  6.775541e-07  0.631386
# PRISM_everolimus_BRD-K13514097-001-05-3      46.0  1.606182e-04  0.528338
# CTRP2_vorinostat_56554                       73.0  6.975187e-04  0.387872
# CTRP2_LBH-589_54210                          75.0  8.993108e-04  0.375562
# GDSC2_Uprosertib_1553                        72.0  1.450035e-03  0.368448
# ...                                           ...           ...       ...
# CTRP2_AZD7762_660777                         73.0  3.181448e-02 -0.251543
# CTRP1_BMS-641988_411807                      27.0  3.048136e-02 -0.416972
# GDSC2_WIKI4_1940                             73.0  2.355341e-02 -0.264840
# GDSC2_SB216763_1025                          46.0  1.804950e-02 -0.347271
# CTRP1_BMS-754807_417981                      24.0  1.284542e-02 -0.500000
#
#                                             mlog10p       FDR  significant  \
# PRISM_temsirolimus_BRD-K42898655-001-01-8  6.169056  0.000544            1
# PRISM_everolimus_BRD-K13514097-001-05-3    3.794205  0.064488            1
# CTRP2_vorinostat_56554                     3.156444  0.180537            1
# CTRP2_LBH-589_54210                        3.046090  0.180537            1
# GDSC2_Uprosertib_1553                      2.838621  0.232876            1
# ...                                             ...       ...          ...
# CTRP2_AZD7762_660777                       1.497375  0.510282            1
# CTRP1_BMS-641988_411807                    1.515966  0.510282            1
# GDSC2_WIKI4_1940                           1.627946  0.472835            1
# GDSC2_SB216763_1025                        1.743535  0.424662            1
# CTRP1_BMS-754807_417981                    1.891252  0.418188            1
#
#                                                      drug_anno       cid
# PRISM_temsirolimus_BRD-K42898655-001-01-8  PI3K/MTOR signaling   6918289
# PRISM_everolimus_BRD-K13514097-001-05-3    PI3K/MTOR signaling   6442177
# CTRP2_vorinostat_56554                       Chromatin-related      5311
# CTRP2_LBH-589_54210                          Chromatin-related   6918837
# GDSC2_Uprosertib_1553                      PI3K/MTOR signaling  51042438
# ...                                                        ...       ...
# CTRP2_AZD7762_660777                                Cell cycle  11152667
# CTRP1_BMS-641988_411807                        Hormone-related  24768935
# GDSC2_WIKI4_1940                                 WNT signaling   2984337
# GDSC2_SB216763_1025                              WNT signaling    176158
# CTRP1_BMS-754807_417981                          RTK signaling  24785538
#
# [803 rows x 8 columns]

# %%
# NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(4*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(4*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   pvalues        rS  \
# gCSI_Cisplatin_CID24191118                  62.0  0.040138  0.261414
# CTRP2_oxaliplatin_375582                    72.0  0.053889  0.228171
# GDSC2_Oxaliplatin_1089                      77.0  0.124181  0.176718
# PRISM_oxaliplatin_BRD-K78960041-001-05-7    49.0  0.450118  0.110408
# GDSC1_Cisplatin_1005                        84.0  0.703646  0.042118
# GDSC2_Oxaliplatin_1806                      66.0  0.723594  0.044359
# GDSC2_Cisplatin_1005                        78.0  0.927942 -0.010407
# PRISM_cisplatin_BRD-K69172251-001-08-9      47.0  0.825943 -0.032956
# CTRP2_carboplatin_26979                     73.0  0.760439 -0.036301
# PRISM_carboplatin_BRD-K90947825-001-02-7    48.0  0.547408 -0.089014
#
#                                            mlog10p       FDR  significant  \
# gCSI_Cisplatin_CID24191118                1.396439  0.269446            1
# CTRP2_oxaliplatin_375582                  1.268498  0.269446            0
# GDSC2_Oxaliplatin_1089                    0.905944  0.413937            0
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.346674  0.917714            0
# GDSC1_Cisplatin_1005                      0.152646  0.917714            0
# GDSC2_Oxaliplatin_1806                    0.140505  0.917714            0
# GDSC2_Cisplatin_1005                      0.032479  0.927942            0
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.083050  0.917714            0
# CTRP2_carboplatin_26979                   0.118935  0.917714            0
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.261689  0.917714            0
#
#                                          drug_anno       cid
# gCSI_Cisplatin_CID24191118                Platinum  24191118
# CTRP2_oxaliplatin_375582                  Platinum  24197464
# GDSC2_Oxaliplatin_1089                    Platinum   5310940
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  Platinum  24197464
# GDSC1_Cisplatin_1005                      Platinum     84691
# GDSC2_Oxaliplatin_1806                    Platinum   5310940
# GDSC2_Cisplatin_1005                      Platinum     84691
# PRISM_cisplatin_BRD-K69172251-001-08-9    Platinum  24191118
# CTRP2_carboplatin_26979                   Platinum     38904
# PRISM_carboplatin_BRD-K90947825-001-02-7  Platinum    426756

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   pvalues        rS  \
# PRISM_talazoparib_BRD-K95142244-001-01-5    51.0  0.179022  0.191164
# GDSC1_Veliparib_1018                        84.0  0.241886  0.129088
# GDSC2_Niraparib_1177                        65.0  0.378274  0.111101
# CTRP2_olaparib_411867                       75.0  0.450553  0.088436
# PRISM_olaparib_BRD-K02113016-001-19-6       46.0  0.457656  0.112249
# PRISM_niraparib_BRD-K54955827-001-02-2      49.0  0.483596  0.102457
# GDSC2_Talazoparib_1259                      72.0  0.613376  0.060551
# GDSC1_Olaparib_1017                         84.0  0.822780  0.024805
# GDSC1_Rucaparib_1175                        82.0  0.939894 -0.008457
# PRISM_olaparib_BRD-K02113016-001-15-4       46.0  0.727821 -0.052729
# GDSC2_Olaparib_1017                         77.0  0.567320 -0.066197
# GDSC1_Talazoparib_1259                      81.0  0.506407 -0.074887
# CTRP2_veliparib_606034                      74.0  0.346916 -0.110891
# GDSC1_Olaparib_1495                         82.0  0.249995 -0.128481
# CTRP1_olaparib_411867                       21.0  0.054179 -0.425974
#
#                                            mlog10p       FDR  significant  \
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.747093  0.759611            0
# GDSC1_Veliparib_1018                      0.616389  0.759611            0
# GDSC2_Niraparib_1177                      0.422193  0.759611            0
# CTRP2_olaparib_411867                     0.346254  0.759611            0
# PRISM_olaparib_BRD-K02113016-001-19-6     0.339461  0.759611            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.315518  0.759611            0
# GDSC2_Talazoparib_1259                    0.212273  0.766720            0
# GDSC1_Olaparib_1017                       0.084716  0.881550            0
# GDSC1_Rucaparib_1175                      0.026921  0.939894            0
# PRISM_olaparib_BRD-K02113016-001-15-4     0.137975  0.839794            0
# GDSC2_Olaparib_1017                       0.246172  0.766720            0
# GDSC1_Talazoparib_1259                    0.295500  0.759611            0
# CTRP2_veliparib_606034                    0.459776  0.759611            0
# GDSC1_Olaparib_1495                       0.602069  0.759611            0
# CTRP1_olaparib_411867                     1.266173  0.759611            0
#
#                                                drug_anno        cid
# PRISM_talazoparib_BRD-K95142244-001-01-5  PARP inhibitor  135565082
# GDSC1_Veliparib_1018                      PARP inhibitor   11960529
# GDSC2_Niraparib_1177                      PARP inhibitor   24958200
# CTRP2_olaparib_411867                     PARP inhibitor   23725625
# PRISM_olaparib_BRD-K02113016-001-19-6     PARP inhibitor   23725625
# PRISM_niraparib_BRD-K54955827-001-02-2    PARP inhibitor   24958200
# GDSC2_Talazoparib_1259                    PARP inhibitor   44819241
# GDSC1_Olaparib_1017                       PARP inhibitor   23725625
# GDSC1_Rucaparib_1175                      PARP inhibitor    9931953
# PRISM_olaparib_BRD-K02113016-001-15-4     PARP inhibitor   23725625
# GDSC2_Olaparib_1017                       PARP inhibitor   23725625
# GDSC1_Talazoparib_1259                    PARP inhibitor   44819241
# CTRP2_veliparib_606034                    PARP inhibitor   11960529
# GDSC1_Olaparib_1495                       PARP inhibitor   23725625
# CTRP1_olaparib_411867                     PARP inhibitor   23725625

# %% [markdown]
# # COSMIC

# %%
df2=pd.read_csv('../processed_data/CCLE_cosmic.txt',sep='\t',index_col=0)
df2.shape
# Out:
# (1020, 94)

# %%
df2=df2.merge(prism,left_on='ACH_ID',right_index=True,how='left')
df2=df2.merge(gdsc1,left_index=True,right_index=True,how='left')
df2=df2.merge(gdsc2,left_index=True,right_index=True,how='left')
df2=df2.merge(ctrp1,left_on='stripped_cell_line_name',right_index=True,how='left')
df2=df2.merge(ctrp2,left_on='stripped_cell_line_name',right_index=True,how='left')
df2=df2.merge(gcsi,left_on='stripped_cell_line_name',right_index=True,how='left')

# %%
brca1_met=[]
for idx in df2.index:
    if df2.loc[idx,'BRCA1_methylation_cosmic_likely']==1:
        brca1_met.append(1)
    elif df2.loc[idx,'BRCA1_methylation_broad']==1:
        brca1_met.append(1)
    elif df2.loc[idx,'BRCA1_methylation_cosmic_likely']==0:
        brca1_met.append(0)
    elif df2.loc[idx,'BRCA1_methylation_broad']==0:
        brca1_met.append(0)
    else:
        brca1_met.append(np.nan)
df2['BRCA1_methylation']=brca1_met

# %%
df2=df2.rename(columns={'HRD_score':'HRD_score_cosmic'})

# %%
brca_status=[]
for idx in df2.index:
    if df2.loc[idx,'BRCA1']=='LOH':
        brca_status.append('BRCA1_LOH')
    elif df2.loc[idx,'BRCA2']=='LOH':
        brca_status.append('BRCA2_LOH')
    elif df2.loc[idx,'BRCA2']=='LOH':
        brca_status.append('BRCA2_LOH')
    elif df2.loc[idx,'BRCA1_methylation']==1:
        brca_status.append('BRCA1_methylation')
    elif df2.loc[idx,'otherHRR_LOH']==1:
        brca_status.append('HRR_LOH')
    elif df2.loc[idx,'BRCA1']=='unknown':
        brca_status.append('BRCA1_unknown')
    elif df2.loc[idx,'otherHRR_unknown']==1:
        brca_status.append('HRR_unknown')
    elif df2.loc[idx,'BRCA1']=='nonLOH':
        brca_status.append('BRCA1_nonLOH')
    elif df2.loc[idx,'BRCA2']=='nonLOH':
        brca_status.append('BRCA2_nonLOH')
    elif df2.loc[idx,'otherHRR_nonLOH']==1:
        brca_status.append('HRR_nonLOH')
    elif (df2.loc[idx,'BRCA1']=='wt')&(df2.loc[idx,'BRCA2']=='wt')&(df2.loc[idx,'BRCA1_methylation']==0):
        brca_status.append('wt')
    else:
        brca_status.append(np.nan)

# %%
df2['BRCA_status']=brca_status

# %%
Counter(df2['BRCA_status']).most_common()
# Out:
# [('wt', 777),
#  ('HRR_nonLOH', 119),
#  (nan, 38),
#  ('HRR_LOH', 32),
#  ('BRCA2_nonLOH', 27),
#  ('BRCA2_LOH', 10),
#  ('BRCA1_nonLOH', 8),
#  ('BRCA1_methylation', 5),
#  ('BRCA1_LOH', 4)]

# %%
df2=df2[(df2['BRCA_status'].isna()==False)]
df2.shape
# Out:
# (982, 978)

# %%
df2['BRCA_alteration']=((df2['BRCA1_LOH']==1)|(df2['BRCA1_methylation']==1)|(df2['BRCA2_LOH']==1)).astype(int)

# %%
(df2['BRCA_alteration']==1).sum()
# Out:
# 19

# %%
(~df2['HRD_score_cosmic'].isna()).sum()
# Out:
# 978

# %%
(~df2['SigMA_cosmic'].isna()).sum()
# Out:
# 977

# %% [markdown]
# ## BRCA status vs Drug sensitivity

# %%
drug_gdsc1=set(df.columns[df.columns.str.startswith('GDSC1')])
drug_gdsc2=set(df.columns[df.columns.str.contains('GDSC2')])
drug_ctrp1=set(df.columns[df.columns.str.contains('CTRP1')])
drug_ctrp2=set(df.columns[df.columns.str.contains('CTRP2')])
drug_prism=set(df.columns[df.columns.str.startswith("PRISM")])
drug_gcsi=set(df.columns[df.columns.str.contains('gCSI')])

# %%
drug_all_set=drug_gdsc1|drug_gdsc2|drug_ctrp1|drug_ctrp2|drug_prism|drug_gcsi
len(drug_all_set)
# Out:
# 882

# %%
drug_anno=pd.read_csv('../processed_data/Drug_annotaion_integrated.txt'
                      ,sep='\t',index_col=0)
drug_anno['cid']=drug_anno['cid'].astype(int)

# %%
from statsmodels.stats.multitest import multipletests

# %%
drug_all=sorted(drug_all)

# %%
len(drug_all)
# Out:
# 882

# %%
df_drug=df2[~df2[drug_all].isna().all(axis=1)]

# %%
df_drug.shape
# Out:
# (978, 979)

# %% [markdown]
# ### BRCA12 altaration

# %%
Counter(df_drug['BRCA_status']).most_common()
# Out:
# [('wt', 774),
#  ('HRR_nonLOH', 119),
#  ('HRR_LOH', 32),
#  ('BRCA2_nonLOH', 27),
#  ('BRCA2_LOH', 9),
#  ('BRCA1_nonLOH', 8),
#  ('BRCA1_methylation', 5),
#  ('BRCA1_LOH', 4)]

# %%
df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH']).sum()
# Out:
# 18

# %%
df_drug['BRCA_status'].isin(['wt']).sum()
# Out:
# 774

# %%
ns,rs,ps,ms,ms2=[],[],[],[],[]
n_limit=5 # set to five
for drug in drug_all:
    a=df_drug[df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH'])][drug].dropna().values
    b=df_drug[df_drug['BRCA_status'].isin(['wt']
                                )][drug].dropna().values
    n=len(a)
    if n> n_limit:
        r,p=stats.mannwhitneyu(a,b)
        m=np.median(a)-np.median(b)
        m2=np.mean(a)-np.mean(b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
        ms.append(m)
        ms2.append(m2)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)
        ms.append(np.nan)
        ms2.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['med_dif']=ms
df_cor['mean_dif']=ms2
df_cor['pvalues']=ps

# %%
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['FDR']=multipletests(df_cor['pvalues'],method='fdr_bh')[1]
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor
# Out:
#                              Number   med_dif  mean_dif   pvalues   mlog10p  \
# CTRP2_ABT-199_666541            7.0  0.549500  1.248437  0.162606  0.788864
# CTRP2_ABT-737_411738           10.0  0.195000  0.841180  0.440120  0.356428
# CTRP2_AT13387_688229            7.0 -0.030000 -0.220487  0.989806  0.004450
# CTRP2_AZD1480_660306            6.0 -0.036000 -0.010896  0.759581  0.119426
# CTRP2_AZD4547_660325           10.0  0.708500  0.934010  0.034217  1.465755
# ...                             ...       ...       ...       ...       ...
# gCSI_Paclitaxel_CID36314        9.0  0.006000 -0.035198  0.843571  0.073878
# gCSI_Palbociclib_CID5330286     7.0 -0.069667 -0.068512  0.021618  1.665179
# gCSI_Tivantinib_CID11494412     9.0 -0.121222 -0.105861  0.034943  1.456635
# gCSI_Vincristine_CID5978        9.0 -0.067333 -0.030630  0.541252  0.266601
# gCSI_Vorinostat_CID5311         9.0 -0.107667 -0.119774  0.010033  1.998575
#
#                                   FDR  significant             drug_anno  \
# CTRP2_ABT-199_666541         0.618421            0  Apoptosis regulation
# CTRP2_ABT-737_411738         0.839163            0  Apoptosis regulation
# CTRP2_AT13387_688229         0.997733            0                Others
# CTRP2_AZD1480_660306         0.981090            0                Others
# CTRP2_AZD4547_660325         0.433418            1         RTK signaling
# ...                               ...          ...                   ...
# gCSI_Paclitaxel_CID36314     0.990956            0       Antimicrotubule
# gCSI_Palbociclib_CID5330286  0.433418            1            Cell cycle
# gCSI_Tivantinib_CID11494412  0.433418            1                Others
# gCSI_Vincristine_CID5978     0.896273            0                Others
# gCSI_Vorinostat_CID5311      0.397940            1     Chromatin-related
#
#                                   cid
# CTRP2_ABT-199_666541         49846579
# CTRP2_ABT-737_411738         11228183
# CTRP2_AT13387_688229         11955716
# CTRP2_AZD1480_660306         16659841
# CTRP2_AZD4547_660325         51039095
# ...                               ...
# gCSI_Paclitaxel_CID36314        36314
# gCSI_Palbociclib_CID5330286   5330286
# gCSI_Tivantinib_CID11494412  11494412
# gCSI_Vincristine_CID5978         5978
# gCSI_Vorinostat_CID5311          5311
#
# [715 rows x 9 columns]

# %%
df_cor_p=df_cor[df_cor['med_dif']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['med_dif']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                                Number   med_dif  mean_dif   pvalues   mlog10p  \
# GDSC2_Foretinib_2040             16.0  0.102123  0.110268  0.000050  4.297930
# GDSC1_Vorinostat_1012            17.0  0.086639  0.099654  0.001536  2.813618
# GDSC2_AZ960_1250                 15.0  0.074491  0.089214  0.001553  2.808936
# GDSC2_Vorinostat_1012            16.0  0.092132  0.062154  0.001658  2.780322
# GDSC2_Dabrafenib_1373            16.0  0.013306  0.039756  0.001814  2.741287
# ...                               ...       ...       ...       ...       ...
# gCSI_JQ1 compound_CID71300862    10.0 -0.042389 -0.059813  0.012865  1.890595
# GDSC1_Afatinib_1377              17.0 -0.040271 -0.030164  0.012539  1.901752
# gCSI_Vorinostat_CID5311           9.0 -0.107667 -0.119774  0.010033  1.998575
# GDSC2_OSI-027_1594                8.0 -0.064367 -0.040667  0.004146  2.382419
# GDSC1_AKT inhibitor VIII_171     15.0 -0.068507 -0.054482  0.003077  2.511854
#
#                                     FDR  significant            drug_anno  \
# GDSC2_Foretinib_2040           0.036006            1        RTK signaling
# GDSC1_Vorinostat_1012          0.259447            1    Chromatin-related
# GDSC2_AZ960_1250               0.259447            1               Others
# GDSC2_Vorinostat_1012          0.259447            1    Chromatin-related
# GDSC2_Dabrafenib_1373          0.259447            1   ERK MAPK signaling
# ...                                 ...          ...                  ...
# gCSI_JQ1 compound_CID71300862  0.397940            1               Others
# GDSC1_Afatinib_1377            0.397940            1       EGFR signaling
# gCSI_Vorinostat_CID5311        0.397940            1    Chromatin-related
# GDSC2_OSI-027_1594             0.370508            1  PI3K/MTOR signaling
# GDSC1_AKT inhibitor VIII_171   0.314307            1  PI3K/MTOR signaling
#
#                                     cid
# GDSC2_Foretinib_2040           42642645
# GDSC1_Vorinostat_1012              5311
# GDSC2_AZ960_1250               25099184
# GDSC2_Vorinostat_1012              5311
# GDSC2_Dabrafenib_1373          44462760
# ...                                 ...
# gCSI_JQ1 compound_CID71300862  71300862
# GDSC1_Afatinib_1377            10184653
# gCSI_Vorinostat_CID5311            5311
# GDSC2_OSI-027_1594             44224160
# GDSC1_AKT inhibitor VIII_171   10196499
#
# [715 rows x 9 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[drug_order[2:]]
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')   
#ax.set_yticklabels(sns_df.columns,fontsize=12)
# Out:
# PI3K/MTOR signaling
# RTK signaling
# Chromatin-related
# ERK MAPK signaling
# DNA inhibitor
# Antimetabolite
# EGFR signaling
# Antimicrotubule
# Cell cycle
# Apoptosis regulation
# Hormone-related
# Protein stability and degradation
# DNA alkylator
# Topoisomerase inhibitor
# WNT signaling
# Metabolism
# Genome integrity
# p53 pathway
# IGF1R signaling
# Cytoskeleton
# JNK and p38 signaling

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df.reindex(columns=drug_order[2:]).fillna(0)
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')/
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')   
#ax.set_yticklabels(sns_df.columns,fontsize=12)

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# GDSC2_Oxaliplatin_1089                      15.0  0.013566  0.029292
# GDSC2_Cisplatin_1005                        16.0  0.016060  0.036034
# gCSI_Cisplatin_CID24191118                   9.0  0.184000  0.065652
# PRISM_carboplatin_BRD-K90947825-001-02-7     7.0  0.218759  0.197792
# GDSC1_Cisplatin_1005                        17.0  0.006537  0.023233
# CTRP2_carboplatin_26979                     11.0  0.011000  0.034989
# CTRP2_oxaliplatin_375582                    11.0  0.113000  0.165289
# PRISM_cisplatin_BRD-K69172251-001-08-9       8.0 -0.006259  0.080396
# GDSC2_Oxaliplatin_1806                      15.0 -0.002216  0.014826
# PRISM_oxaliplatin_BRD-K78960041-001-05-7     8.0 -0.042299 -0.050250
#
#                                            pvalues   mlog10p       FDR  \
# GDSC2_Oxaliplatin_1089                    0.066229  1.178950  0.291323
# GDSC2_Cisplatin_1005                      0.077843  1.108779  0.291323
# gCSI_Cisplatin_CID24191118                0.098129  1.008202  0.291323
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.116529  0.933565  0.291323
# GDSC1_Cisplatin_1005                      0.306221  0.513964  0.612443
# CTRP2_carboplatin_26979                   0.879898  0.055568  0.905944
# CTRP2_oxaliplatin_375582                  0.905944  0.042898  0.905944
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.794028  0.100164  0.905944
# GDSC2_Oxaliplatin_1806                    0.717220  0.144348  0.905944
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.569325  0.244639  0.905944
#
#                                           significant drug_anno       cid
# GDSC2_Oxaliplatin_1089                              0  Platinum   5310940
# GDSC2_Cisplatin_1005                                0  Platinum     84691
# gCSI_Cisplatin_CID24191118                          0  Platinum  24191118
# PRISM_carboplatin_BRD-K90947825-001-02-7            0  Platinum    426756
# GDSC1_Cisplatin_1005                                0  Platinum     84691
# CTRP2_carboplatin_26979                             0  Platinum     38904
# CTRP2_oxaliplatin_375582                            0  Platinum  24197464
# PRISM_cisplatin_BRD-K69172251-001-08-9              0  Platinum  24191118
# GDSC2_Oxaliplatin_1806                              0  Platinum   5310940
# PRISM_oxaliplatin_BRD-K78960041-001-05-7            0  Platinum  24197464

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# GDSC2_Niraparib_1177                        15.0  0.014121  0.027691
# CTRP2_olaparib_411867                       11.0  0.341000  0.361484
# PRISM_olaparib_BRD-K02113016-001-19-6        7.0  0.061260  0.026973
# GDSC2_Talazoparib_1259                      14.0  0.004896  0.059593
# PRISM_niraparib_BRD-K54955827-001-02-2       8.0  0.014443 -0.010144
# GDSC2_Olaparib_1017                         16.0  0.005442 -0.003520
# PRISM_olaparib_BRD-K02113016-001-15-4        8.0  0.071166 -0.019886
# GDSC1_Rucaparib_1175                        17.0  0.003012 -0.002023
# PRISM_talazoparib_BRD-K95142244-001-01-5     8.0 -0.043721  0.003134
# GDSC1_Olaparib_1017                         17.0 -0.001055  0.003797
# GDSC1_Veliparib_1018                        17.0 -0.000687  0.005568
# GDSC1_Talazoparib_1259                      17.0 -0.006942 -0.005047
# CTRP2_veliparib_606034                      11.0 -0.176000 -0.021613
# GDSC1_Olaparib_1495                         16.0 -0.017847 -0.020273
#
#                                            pvalues   mlog10p       FDR  \
# GDSC2_Niraparib_1177                      0.040916  1.388109  0.286411
# CTRP2_olaparib_411867                     0.309765  0.508968  0.900604
# PRISM_olaparib_BRD-K02113016-001-19-6     0.336310  0.473260  0.900604
# GDSC2_Talazoparib_1259                    0.347126  0.459512  0.900604
# PRISM_niraparib_BRD-K54955827-001-02-2    0.727413  0.138219  0.900604
# GDSC2_Olaparib_1017                       0.794255  0.100040  0.900604
# PRISM_olaparib_BRD-K02113016-001-15-4     0.807119  0.093062  0.900604
# GDSC1_Rucaparib_1175                      0.813879  0.089440  0.900604
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.948472  0.022976  0.948472
# GDSC1_Olaparib_1017                       0.836275  0.077651  0.900604
# GDSC1_Veliparib_1018                      0.827898  0.082023  0.900604
# GDSC1_Talazoparib_1259                    0.809560  0.091751  0.900604
# CTRP2_veliparib_606034                    0.555143  0.255595  0.900604
# GDSC1_Olaparib_1495                       0.036687  1.435488  0.286411
#
#                                           significant       drug_anno  \
# GDSC2_Niraparib_1177                                1  PARP inhibitor
# CTRP2_olaparib_411867                               0  PARP inhibitor
# PRISM_olaparib_BRD-K02113016-001-19-6               0  PARP inhibitor
# GDSC2_Talazoparib_1259                              0  PARP inhibitor
# PRISM_niraparib_BRD-K54955827-001-02-2              0  PARP inhibitor
# GDSC2_Olaparib_1017                                 0  PARP inhibitor
# PRISM_olaparib_BRD-K02113016-001-15-4               0  PARP inhibitor
# GDSC1_Rucaparib_1175                                0  PARP inhibitor
# PRISM_talazoparib_BRD-K95142244-001-01-5            0  PARP inhibitor
# GDSC1_Olaparib_1017                                 0  PARP inhibitor
# GDSC1_Veliparib_1018                                0  PARP inhibitor
# GDSC1_Talazoparib_1259                              0  PARP inhibitor
# CTRP2_veliparib_606034                              0  PARP inhibitor
# GDSC1_Olaparib_1495                                 1  PARP inhibitor
#
#                                                 cid
# GDSC2_Niraparib_1177                       24958200
# CTRP2_olaparib_411867                      23725625
# PRISM_olaparib_BRD-K02113016-001-19-6      23725625
# GDSC2_Talazoparib_1259                     44819241
# PRISM_niraparib_BRD-K54955827-001-02-2     24958200
# GDSC2_Olaparib_1017                        23725625
# PRISM_olaparib_BRD-K02113016-001-15-4      23725625
# GDSC1_Rucaparib_1175                        9931953
# PRISM_talazoparib_BRD-K95142244-001-01-5  135565082
# GDSC1_Olaparib_1017                        23725625
# GDSC1_Veliparib_1018                       11960529
# GDSC1_Talazoparib_1259                     44819241
# CTRP2_veliparib_606034                     11960529
# GDSC1_Olaparib_1495                        23725625

# %% [markdown]
# ### HRR alteration

# %%
df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH']).sum()
# Out:
# 50

# %%
ns,rs,ps,ms,ms2=[],[],[],[],[]
n_limit=10
for drug in drug_all:
    a=df_drug[df_drug['BRCA_status'].isin(['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH'])][drug].dropna().values
    b=df_drug[df_drug['BRCA_status'].isin(['wt']
                               )][drug].dropna().values
    n=len(a)
    if n> n_limit:
        r,p=stats.mannwhitneyu(a,b)
        m=np.median(a)-np.median(b)
        m2=np.mean(a)-np.mean(b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
        ms.append(m)
        ms2.append(m2)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)
        ms.append(np.nan)
        ms2.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['med_dif']=ms
df_cor['mean_dif']=ms2
df_cor['pvalues']=ps

# %%
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['FDR']=multipletests(df_cor['pvalues'],method='fdr_bh')[1]
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor
# Out:
#                              Number   med_dif  mean_dif   pvalues   mlog10p  \
# CTRP2_ABT-199_666541           18.0  0.315000  0.461410  0.477499  0.321027
# CTRP2_ABT-737_411738           26.0  0.573500  0.737295  0.069799  1.156149
# CTRP2_AT13387_688229           14.0 -0.334150 -0.214823  0.980503  0.008551
# CTRP2_AZD1480_660306           12.0  0.329500  0.280354  0.462044  0.335317
# CTRP2_AZD4547_660325           25.0  0.837000  0.940510  0.000562  3.250472
# ...                             ...       ...       ...       ...       ...
# gCSI_Paclitaxel_CID36314       22.0 -0.022667 -0.051301  0.581776  0.235244
# gCSI_Palbociclib_CID5330286    15.0 -0.052222 -0.040538  0.061266  1.212781
# gCSI_Tivantinib_CID11494412    22.0 -0.042556 -0.060125  0.083501  1.078307
# gCSI_Vincristine_CID5978       22.0 -0.040222 -0.041721  0.255592  0.592452
# gCSI_Vorinostat_CID5311        22.0 -0.096056 -0.088366  0.004910  2.308962
#
#                                   FDR  significant             drug_anno  \
# CTRP2_ABT-199_666541         0.848178            0  Apoptosis regulation
# CTRP2_ABT-737_411738         0.616602            0  Apoptosis regulation
# CTRP2_AT13387_688229         0.995850            0                Others
# CTRP2_AZD1480_660306         0.840585            0                Others
# CTRP2_AZD4547_660325         0.106027            1         RTK signaling
# ...                               ...          ...                   ...
# gCSI_Paclitaxel_CID36314     0.897606            0       Antimicrotubule
# gCSI_Palbociclib_CID5330286  0.588611            0            Cell cycle
# gCSI_Tivantinib_CID11494412  0.617372            0                Others
# gCSI_Vincristine_CID5978     0.743204            0                Others
# gCSI_Vorinostat_CID5311      0.236779            1     Chromatin-related
#
#                                   cid
# CTRP2_ABT-199_666541         49846579
# CTRP2_ABT-737_411738         11228183
# CTRP2_AT13387_688229         11955716
# CTRP2_AZD1480_660306         16659841
# CTRP2_AZD4547_660325         51039095
# ...                               ...
# gCSI_Paclitaxel_CID36314        36314
# gCSI_Palbociclib_CID5330286   5330286
# gCSI_Tivantinib_CID11494412  11494412
# gCSI_Vincristine_CID5978         5978
# gCSI_Vorinostat_CID5311          5311
#
# [755 rows x 9 columns]

# %%
df_cor_p=df_cor[df_cor['med_dif']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['med_dif']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                          Number   med_dif  mean_dif   pvalues   mlog10p  \
# GDSC2_Foretinib_2040       40.0  0.071592  0.067456  0.000085  4.068974
# GDSC2_BMS-536924_1091      40.0  0.043135  0.055848  0.000382  3.418310
# CTRP2_KW-2449_660413       28.0  1.002500  0.884322  0.000527  3.277894
# CTRP2_AZD4547_660325       25.0  0.837000  0.940510  0.000562  3.250472
# CTRP2_foretinib_628607     27.0  0.871000  1.034829  0.001612  2.792530
# ...                         ...       ...       ...       ...       ...
# GDSC1_Afatinib_1032        46.0 -0.019109 -0.000684  0.011441  1.941538
# GDSC1_Cetuximab_1114       42.0 -0.009229 -0.003865  0.009521  2.021334
# GDSC1_Olaparib_1495        44.0 -0.023207 -0.020568  0.007754  2.110501
# gCSI_Vorinostat_CID5311    22.0 -0.096056 -0.088366  0.004910  2.308962
# GDSC1_CP724714_255         47.0 -0.005707 -0.013157  0.002340  2.630841
#
#                               FDR  significant          drug_anno       cid
# GDSC2_Foretinib_2040     0.064413            1      RTK signaling  42642645
# GDSC2_BMS-536924_1091    0.106027            1    IGF1R signaling  10390396
# CTRP2_KW-2449_660413     0.106027            1             Others  11427553
# CTRP2_AZD4547_660325     0.106027            1      RTK signaling  51039095
# CTRP2_foretinib_628607   0.204357            1      RTK signaling  42642645
# ...                           ...          ...                ...       ...
# GDSC1_Afatinib_1032      0.277063            1     EGFR signaling  10184653
# GDSC1_Cetuximab_1114     0.277063            1     EGFR signaling  85668777
# GDSC1_Olaparib_1495      0.277063            1     PARP inhibitor  23725625
# gCSI_Vorinostat_CID5311  0.236779            1  Chromatin-related      5311
# GDSC1_CP724714_255       0.204357            1     EGFR signaling   9874913
#
# [755 rows x 9 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['med_dif']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,
           yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=3,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[drug_order[2:]]
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')   
#ax.set_yticklabels(sns_df.columns,fontsize=12)
# Out:
# PI3K/MTOR signaling
# RTK signaling
# Chromatin-related
# ERK MAPK signaling
# DNA inhibitor
# Antimetabolite
# EGFR signaling
# Antimicrotubule
# Cell cycle
# Apoptosis regulation
# Hormone-related
# Protein stability and degradation
# DNA alkylator
# Topoisomerase inhibitor
# WNT signaling
# Metabolism
# Genome integrity
# p53 pathway
# IGF1R signaling
# Cytoskeleton
# JNK and p38 signaling

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df.reindex(columns=drug_order[2:])
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')/
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')   
#ax.set_yticklabels(sns_df.columns,fontsize=12)

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# gCSI_Cisplatin_CID24191118                  16.0  0.171222  0.052806
# CTRP2_oxaliplatin_375582                    27.0  0.134000  0.267010
# GDSC1_Cisplatin_1005                        46.0  0.003748  0.008687
# PRISM_carboplatin_BRD-K90947825-001-02-7    22.0  0.102589  0.040187
# GDSC2_Oxaliplatin_1089                      41.0 -0.002895  0.007149
# GDSC2_Oxaliplatin_1806                      40.0 -0.009265  0.005315
# CTRP2_carboplatin_26979                     28.0 -0.052500 -0.080187
# GDSC2_Cisplatin_1005                        41.0 -0.000736  0.014469
# PRISM_cisplatin_BRD-K69172251-001-08-9      23.0 -0.009564  0.031854
# PRISM_oxaliplatin_BRD-K78960041-001-05-7    23.0 -0.028927 -0.061817
#
#                                            pvalues   mlog10p       FDR  \
# gCSI_Cisplatin_CID24191118                0.035846  1.445560  0.358460
# CTRP2_oxaliplatin_375582                  0.340293  0.468147  0.826243
# GDSC1_Cisplatin_1005                      0.581807  0.235221  0.826243
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.808846  0.092134  0.898717
# GDSC2_Oxaliplatin_1089                    0.998986  0.000441  0.998986
# GDSC2_Oxaliplatin_1806                    0.660995  0.179802  0.826243
# CTRP2_carboplatin_26979                   0.542173  0.265862  0.826243
# GDSC2_Cisplatin_1005                      0.450878  0.345941  0.826243
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.412680  0.384387  0.826243
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.192520  0.715525  0.826243
#
#                                           significant drug_anno       cid
# gCSI_Cisplatin_CID24191118                          1  Platinum  24191118
# CTRP2_oxaliplatin_375582                            0  Platinum  24197464
# GDSC1_Cisplatin_1005                                0  Platinum     84691
# PRISM_carboplatin_BRD-K90947825-001-02-7            0  Platinum    426756
# GDSC2_Oxaliplatin_1089                              0  Platinum   5310940
# GDSC2_Oxaliplatin_1806                              0  Platinum   5310940
# CTRP2_carboplatin_26979                             0  Platinum     38904
# GDSC2_Cisplatin_1005                                0  Platinum     84691
# PRISM_cisplatin_BRD-K69172251-001-08-9              0  Platinum  24191118
# PRISM_oxaliplatin_BRD-K78960041-001-05-7            0  Platinum  24197464

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   med_dif  mean_dif  \
# CTRP2_olaparib_411867                       27.0  0.493000  0.539656
# GDSC2_Niraparib_1177                        40.0  0.003406  0.014887
# PRISM_olaparib_BRD-K02113016-001-19-6       20.0  0.029954  0.020016
# GDSC1_Rucaparib_1175                        46.0  0.002502 -0.006129
# GDSC2_Olaparib_1017                         41.0  0.004278  0.005306
# GDSC1_Veliparib_1018                        46.0  0.001044  0.003714
# GDSC2_Talazoparib_1259                      39.0  0.002555  0.029400
# CTRP2_veliparib_606034                      27.0  0.034000  0.061764
# PRISM_niraparib_BRD-K54955827-001-02-2      23.0  0.024314 -0.004311
# GDSC1_Olaparib_1017                         46.0 -0.001048  0.005341
# PRISM_olaparib_BRD-K02113016-001-15-4       21.0 -0.010240 -0.044748
# PRISM_talazoparib_BRD-K95142244-001-01-5    23.0 -0.100328 -0.038174
# GDSC1_Talazoparib_1259                      45.0 -0.036281 -0.060857
# GDSC1_Olaparib_1495                         44.0 -0.023207 -0.020568
#
#                                            pvalues   mlog10p       FDR  \
# CTRP2_olaparib_411867                     0.004714  2.326654  0.054275
# GDSC2_Niraparib_1177                      0.226186  0.645535  0.693670
# PRISM_olaparib_BRD-K02113016-001-19-6     0.324622  0.488622  0.736667
# GDSC1_Rucaparib_1175                      0.468957  0.328867  0.736667
# GDSC2_Olaparib_1017                       0.473572  0.324614  0.736667
# GDSC1_Veliparib_1018                      0.588290  0.230409  0.823606
# GDSC2_Talazoparib_1259                    0.802560  0.095522  0.956411
# CTRP2_veliparib_606034                    0.933061  0.030090  0.956411
# PRISM_niraparib_BRD-K54955827-001-02-2    0.956411  0.019355  0.956411
# GDSC1_Olaparib_1017                       0.950986  0.021826  0.956411
# PRISM_olaparib_BRD-K02113016-001-15-4     0.431322  0.365198  0.736667
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.247739  0.606005  0.693670
# GDSC1_Talazoparib_1259                    0.073941  1.131114  0.345059
# GDSC1_Olaparib_1495                       0.007754  2.110501  0.054275
#
#                                           significant       drug_anno  \
# CTRP2_olaparib_411867                               1  PARP inhibitor
# GDSC2_Niraparib_1177                                0  PARP inhibitor
# PRISM_olaparib_BRD-K02113016-001-19-6               0  PARP inhibitor
# GDSC1_Rucaparib_1175                                0  PARP inhibitor
# GDSC2_Olaparib_1017                                 0  PARP inhibitor
# GDSC1_Veliparib_1018                                0  PARP inhibitor
# GDSC2_Talazoparib_1259                              0  PARP inhibitor
# CTRP2_veliparib_606034                              0  PARP inhibitor
# PRISM_niraparib_BRD-K54955827-001-02-2              0  PARP inhibitor
# GDSC1_Olaparib_1017                                 0  PARP inhibitor
# PRISM_olaparib_BRD-K02113016-001-15-4               0  PARP inhibitor
# PRISM_talazoparib_BRD-K95142244-001-01-5            0  PARP inhibitor
# GDSC1_Talazoparib_1259                              0  PARP inhibitor
# GDSC1_Olaparib_1495                                 1  PARP inhibitor
#
#                                                 cid
# CTRP2_olaparib_411867                      23725625
# GDSC2_Niraparib_1177                       24958200
# PRISM_olaparib_BRD-K02113016-001-19-6      23725625
# GDSC1_Rucaparib_1175                        9931953
# GDSC2_Olaparib_1017                        23725625
# GDSC1_Veliparib_1018                       11960529
# GDSC2_Talazoparib_1259                     44819241
# CTRP2_veliparib_606034                     11960529
# PRISM_niraparib_BRD-K54955827-001-02-2     24958200
# GDSC1_Olaparib_1017                        23725625
# PRISM_olaparib_BRD-K02113016-001-15-4      23725625
# PRISM_talazoparib_BRD-K95142244-001-01-5  135565082
# GDSC1_Talazoparib_1259                     44819241
# GDSC1_Olaparib_1495                        23725625

# %% [markdown]
# ## Correlations with HRD score and Signature 3

# %%
in_df=df2.copy()
#plt_df=plt_df[plt_df[cat]=='']
val1,val2,val3='HRD_score_cosmic','SigMA_cosmic','BRCA_status'
plt_df=in_df[[val1,val2]].dropna()
print(plt_df.shape)
x,y=plt_df[val1],plt_df[val2]

fig=plt.figure(figsize=(3,3))
ax=fig.add_subplot(111)
ax.scatter(x,y,s=3,c='grey')
ax.set_xlabel(val1)
ax.set_ylabel(val2)
# linear regression, Pearson correlation
lr=stats.linregress(x,y)
a,b,r,p=lr.slope,lr.intercept, lr.rvalue,lr.pvalue
ax.plot(x,a*x+b,lw=1,c='k')

plt_df2=in_df[[val1,val2,val3]].dropna()
plt_df3=plt_df2[plt_df2[val3]=='BRCA1_methylation']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='lime')

plt_df3=plt_df2[plt_df2[val3]=='BRCA1_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='red')

plt_df3=plt_df2[plt_df2[val3]=='BRCA2_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='blue')

ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)

print('r = {:.3f}, p = {:.2e}'.format(r,p))
# Out:
# (973, 2)
# r = 0.403, p = 3.42e-39

# %%
df2['BRCA2_LOH'].sum()
# Out:
# 10

# %%
df2['BRCA1_LOH'].sum()
# Out:
# 4

# %%
plt_df=df2
cat='BRCA_status'
val='HRD_score_cosmic'
order=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','wt']#'BRCA1_unknown' ]
order2=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','']#'BRCA1_unknown' ]
order3=['$BRCA1$ LOH +','$BRCA1$ methylation','$BRCA2$ LOH +','HRR LOH +','$BRCA1$ LOH -','$BRCA2$ LOH -','HRR LOH -','WT']#'BRCA1_unknown' ]

#hue=
palette=['r','r','r','r','b','b','b','dimgrey']
fig=plt.figure(figsize=(4,3))
ax=fig.add_subplot(1,1,1)
#sns.violinplot(x=cat,y=val,data=plt_df,inner="stick",order=order,cut=0,palette=palette)
sns.swarmplot(x=cat,y=val,data=plt_df,s=3,order=order2,palette=palette)
sns.boxplot(x=cat,y=val,data=plt_df,boxprops={'alpha':0.5},sym='',order=order,palette=palette)
ax.set_xlabel('')
ax.set_ylabel('')
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)
ax.set_xticklabels(order3,rotation=45,fontsize=10,ha='right')
ax.tick_params('y',labelsize=8)
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 5.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt_df=df2
cat='BRCA_status'
val='SigMA_cosmic'
order=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','wt']#'BRCA1_unknown' ]
order2=['BRCA1_LOH','BRCA1_methylation','BRCA2_LOH','HRR_LOH','BRCA1_nonLOH','BRCA2_nonLOH','HRR_nonLOH','']#'BRCA1_unknown' ]
order3=['$BRCA1$ LOH +','$BRCA1$ methylation','$BRCA2$ LOH +','HRR LOH +','$BRCA1$ LOH -','$BRCA2$ LOH -','HRR LOH -','WT']#'BRCA1_unknown' ]

#hue=
palette=['r','r','r','r','b','b','b','dimgrey']
fig=plt.figure(figsize=(4,3))
ax=fig.add_subplot(1,1,1)
#sns.violinplot(x=cat,y=val,data=plt_df,inner="stick",order=order,cut=0,palette=palette)
sns.swarmplot(x=cat,y=val,data=plt_df,s=3,order=order2,palette=palette)
sns.boxplot(x=cat,y=val,data=plt_df,boxprops={'alpha':0.5},sym='',order=order,palette=palette)
ax.set_xlabel('')
ax.set_ylabel('')
ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)
ax.set_xticklabels(order3,rotation=45,fontsize=10,ha='right')
ax.tick_params('y',labelsize=8)
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 5.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Genomic scar score and Drug sensitivity

# %% [markdown]
# ### HRD score

# %%
ns,rs,ps=[],[],[]
for drug in drug_all:
    plt_df=df2[['HRD_score_cosmic',drug]].dropna()
    a=plt_df['HRD_score_cosmic'].values
    b=plt_df[drug].values
    n=len(a)
    if n>= 50:
        r,p=stats.spearmanr(a,b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['pvalues']=ps
df_cor['rS']=rs
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['FDR']=multipletests(df_cor['pvalues'],method='fdr_bh')[1]
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor.shape
# Out:
# (861, 8)

# %%
df_cor_p=df_cor[df_cor['rS']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['rS']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                             Number       pvalues        rS    mlog10p  \
# GDSC2_Cytarabine_1006        743.0  3.496451e-26  0.374720  25.456373
# GDSC2_Oxaliplatin_1089       792.0  7.015871e-25  0.354609  24.153918
# GDSC2_Epirubicin_1511        743.0  1.593496e-22  0.347593  21.797649
# GDSC2_Nutlin-3a (-)_1047     763.0  4.063605e-22  0.340127  21.391089
# GDSC2_Palbociclib_1054       760.0  1.343404e-19  0.320355  18.871793
# ...                            ...           ...       ...        ...
# GDSC2_Picolinici-acid_1635   720.0  3.639639e-06 -0.171602   5.438942
# GDSC1_Cetuximab_1114         853.0  1.192727e-07 -0.180064   6.923459
# GDSC2_GDC0810_1925           743.0  7.100110e-08 -0.196097   7.148735
# GDSC2_AZD3759_1915           751.0  9.796967e-09 -0.207312   8.008908
# GDSC2_Gefitinib_1010         743.0  9.205329e-10 -0.222178   9.035961
#
#                                      FDR  significant        drug_anno  \
# GDSC2_Cytarabine_1006       3.010444e-23            1   Antimetabolite
# GDSC2_Oxaliplatin_1089      3.020333e-22            1         Platinum
# GDSC2_Epirubicin_1511       4.573334e-20            1    DNA inhibitor
# GDSC2_Nutlin-3a (-)_1047    8.746910e-20            1      p53 pathway
# GDSC2_Palbociclib_1054      2.313341e-17            1       Cell cycle
# ...                                  ...          ...              ...
# GDSC2_Picolinici-acid_1635  2.117384e-05            1           Others
# GDSC1_Cetuximab_1114        8.349087e-07            1   EGFR signaling
# GDSC2_GDC0810_1925          5.180673e-07            1  Hormone-related
# GDSC2_AZD3759_1915          8.435189e-08            1   EGFR signaling
# GDSC2_Gefitinib_1010        1.003264e-08            1   EGFR signaling
#
#                                  cid
# GDSC2_Cytarabine_1006           6253
# GDSC2_Oxaliplatin_1089       5310940
# GDSC2_Epirubicin_1511          41867
# GDSC2_Nutlin-3a (-)_1047    11433190
# GDSC2_Palbociclib_1054       5330286
# ...                              ...
# GDSC2_Picolinici-acid_1635      1018
# GDSC1_Cetuximab_1114        85668777
# GDSC2_GDC0810_1925          56941241
# GDSC2_AZD3759_1915          78209992
# GDSC2_Gefitinib_1010          123631
#
# [861 rows x 8 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[drug_order[2:]]
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')
# Out:
# PI3K/MTOR signaling
# RTK signaling
# Chromatin-related
# ERK MAPK signaling
# DNA inhibitor
# Antimetabolite
# EGFR signaling
# Antimicrotubule
# Cell cycle
# Apoptosis regulation
# Hormone-related
# Protein stability and degradation
# DNA alkylator
# Topoisomerase inhibitor
# WNT signaling
# Metabolism
# Genome integrity
# p53 pathway
# IGF1R signaling
# Cytoskeleton
# JNK and p38 signaling

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df.reindex(columns=['Platinum']).fillna(0)#in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df.reindex(columns=drug_order[2:]).fillna(0)
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number       pvalues        rS  \
# GDSC2_Oxaliplatin_1089                     792.0  7.015871e-25  0.354609
# GDSC2_Oxaliplatin_1806                     720.0  2.140423e-15  0.289780
# GDSC2_Cisplatin_1005                       758.0  6.159011e-15  0.278180
# CTRP2_oxaliplatin_375582                   501.0  5.732359e-10  0.272320
# CTRP2_carboplatin_26979                    514.0  2.085719e-05  0.186507
# GDSC1_Cisplatin_1005                       923.0  1.599050e-02  0.079280
# PRISM_oxaliplatin_BRD-K78960041-001-05-7   351.0  8.264786e-02  0.092767
# gCSI_Cisplatin_CID24191118                 231.0  2.623387e-01  0.074049
# PRISM_carboplatin_BRD-K90947825-001-02-7   348.0  3.282660e-01  0.052558
# PRISM_cisplatin_BRD-K69172251-001-08-9     349.0  3.810318e-02 -0.111060
#
#                                             mlog10p           FDR  \
# GDSC2_Oxaliplatin_1089                    24.153918  7.015871e-24
# GDSC2_Oxaliplatin_1806                    14.669500  1.070212e-14
# GDSC2_Cisplatin_1005                      14.210489  2.053004e-14
# CTRP2_oxaliplatin_375582                   9.241667  1.433090e-09
# CTRP2_carboplatin_26979                    4.680744  4.171438e-05
# GDSC1_Cisplatin_1005                       1.796138  2.665083e-02
# PRISM_oxaliplatin_BRD-K78960041-001-05-7   1.082768  1.033098e-01
# gCSI_Cisplatin_CID24191118                 0.581138  2.914875e-01
# PRISM_carboplatin_BRD-K90947825-001-02-7   0.483774  3.282660e-01
# PRISM_cisplatin_BRD-K69172251-001-08-9     1.419039  5.443312e-02
#
#                                           significant drug_anno       cid
# GDSC2_Oxaliplatin_1089                              1  Platinum   5310940
# GDSC2_Oxaliplatin_1806                              1  Platinum   5310940
# GDSC2_Cisplatin_1005                                1  Platinum     84691
# CTRP2_oxaliplatin_375582                            1  Platinum  24197464
# CTRP2_carboplatin_26979                             1  Platinum     38904
# GDSC1_Cisplatin_1005                                1  Platinum     84691
# PRISM_oxaliplatin_BRD-K78960041-001-05-7            0  Platinum  24197464
# gCSI_Cisplatin_CID24191118                          0  Platinum  24191118
# PRISM_carboplatin_BRD-K90947825-001-02-7            0  Platinum    426756
# PRISM_cisplatin_BRD-K69172251-001-08-9              1  Platinum  24191118

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number       pvalues        rS  \
# GDSC2_Talazoparib_1259                     739.0  3.592479e-16  0.293719
# GDSC2_Niraparib_1177                       720.0  1.777250e-14  0.280423
# GDSC1_Olaparib_1017                        921.0  8.957121e-06  0.145749
# CTRP2_olaparib_411867                      510.0  4.695854e-05  0.179213
# GDSC1_Talazoparib_1259                     888.0  9.662019e-04  0.110563
# GDSC2_Olaparib_1017                        752.0  9.788880e-04  0.119977
# CTRP2_veliparib_606034                     525.0  2.475046e-01  0.050559
# GDSC1_Veliparib_1018                       922.0  3.779559e-01  0.029070
# PRISM_talazoparib_BRD-K95142244-001-01-5   373.0  6.235314e-01  0.025497
# CTRP1_olaparib_411867                       84.0  8.466380e-01  0.021421
# GDSC1_Olaparib_1495                        884.0  8.092805e-01 -0.008129
# GDSC1_Rucaparib_1175                       916.0  8.011266e-01 -0.008334
# PRISM_niraparib_BRD-K54955827-001-02-2     367.0  7.810130e-01 -0.014560
# PRISM_olaparib_BRD-K02113016-001-19-6      339.0  7.029556e-01 -0.020786
# PRISM_olaparib_BRD-K02113016-001-15-4      347.0  2.921504e-01 -0.056709
#
#                                             mlog10p           FDR  \
# GDSC2_Talazoparib_1259                    15.444606  5.388719e-15
# GDSC2_Niraparib_1177                      13.750251  1.332938e-13
# GDSC1_Olaparib_1017                        5.047832  4.478561e-05
# CTRP2_olaparib_411867                      4.328285  1.760945e-04
# GDSC1_Talazoparib_1259                     3.014932  2.447220e-03
# GDSC2_Olaparib_1017                        3.009267  2.447220e-03
# CTRP2_veliparib_606034                     0.606417  5.303671e-01
# GDSC1_Veliparib_1018                       0.422559  6.299264e-01
# PRISM_talazoparib_BRD-K95142244-001-01-5   0.205142  8.466380e-01
# CTRP1_olaparib_411867                      0.072302  8.466380e-01
# GDSC1_Olaparib_1495                        0.091901  8.466380e-01
# GDSC1_Rucaparib_1175                       0.096299  8.466380e-01
# PRISM_niraparib_BRD-K54955827-001-02-2     0.107342  8.466380e-01
# PRISM_olaparib_BRD-K02113016-001-19-6      0.153072  8.466380e-01
# PRISM_olaparib_BRD-K02113016-001-15-4      0.534393  5.477821e-01
#
#                                           significant       drug_anno  \
# GDSC2_Talazoparib_1259                              1  PARP inhibitor
# GDSC2_Niraparib_1177                                1  PARP inhibitor
# GDSC1_Olaparib_1017                                 1  PARP inhibitor
# CTRP2_olaparib_411867                               1  PARP inhibitor
# GDSC1_Talazoparib_1259                              1  PARP inhibitor
# GDSC2_Olaparib_1017                                 1  PARP inhibitor
# CTRP2_veliparib_606034                              0  PARP inhibitor
# GDSC1_Veliparib_1018                                0  PARP inhibitor
# PRISM_talazoparib_BRD-K95142244-001-01-5            0  PARP inhibitor
# CTRP1_olaparib_411867                               0  PARP inhibitor
# GDSC1_Olaparib_1495                                 0  PARP inhibitor
# GDSC1_Rucaparib_1175                                0  PARP inhibitor
# PRISM_niraparib_BRD-K54955827-001-02-2              0  PARP inhibitor
# PRISM_olaparib_BRD-K02113016-001-19-6               0  PARP inhibitor
# PRISM_olaparib_BRD-K02113016-001-15-4               0  PARP inhibitor
#
#                                                 cid
# GDSC2_Talazoparib_1259                     44819241
# GDSC2_Niraparib_1177                       24958200
# GDSC1_Olaparib_1017                        23725625
# CTRP2_olaparib_411867                      23725625
# GDSC1_Talazoparib_1259                     44819241
# GDSC2_Olaparib_1017                        23725625
# CTRP2_veliparib_606034                     11960529
# GDSC1_Veliparib_1018                       11960529
# PRISM_talazoparib_BRD-K95142244-001-01-5  135565082
# CTRP1_olaparib_411867                      23725625
# GDSC1_Olaparib_1495                        23725625
# GDSC1_Rucaparib_1175                        9931953
# PRISM_niraparib_BRD-K54955827-001-02-2     24958200
# PRISM_olaparib_BRD-K02113016-001-19-6      23725625
# PRISM_olaparib_BRD-K02113016-001-15-4      23725625

# %% [markdown]
# ### Signature 3

# %%
ns,rs,ps=[],[],[]
for drug in drug_all:
    plt_df=df2[['SigMA_cosmic',drug]].dropna()
    a=plt_df['SigMA_cosmic'].values
    b=plt_df[drug].values
    n=len(a)
    if n>= 50:
        r,p=stats.spearmanr(a,b)
        ns.append(n)
        rs.append(r)
        ps.append(p)
    else:
        ns.append(np.nan)
        rs.append(np.nan)
        ps.append(np.nan)

# %%
df_cor=pd.DataFrame(index=drug_all)
df_cor['Number']=ns
df_cor['pvalues']=ps
df_cor['rS']=rs
df_cor=df_cor.dropna()

# %%
df_cor['mlog10p']=-np.log10(df_cor['pvalues'])
df_cor['FDR']=multipletests(df_cor['pvalues'],method='fdr_bh')[1]
df_cor['significant']=(df_cor['pvalues']<0.05).astype(int)

# %%
df_cor=df_cor.merge(drug_anno,left_index=True,right_index=True,how='inner')
df_cor.shape
# Out:
# (861, 8)

# %%
df_cor_p=df_cor[df_cor['rS']>=0].sort_values('pvalues')
df_cor_n=df_cor[df_cor['rS']<0].sort_values('pvalues',ascending=False)
df_cor_pn=pd.concat([df_cor_p,df_cor_n])
df_cor_pn
# Out:
#                               Number       pvalues        rS    mlog10p  \
# GDSC1_(5Z)-7-Oxozeaenol_1242   889.0  1.715645e-11  0.223126  10.765572
# GDSC1_VX-11e_262               897.0  5.680254e-11  0.216465  10.245632
# GDSC1_Dabrafenib_1373          847.0  5.113706e-10  0.211462   9.291264
# GDSC1_NVP-BHG712_295           897.0  1.073185e-09  0.201794   8.969326
# GDSC1_CI-1040_1015             906.0  1.343794e-09  0.199644   8.871667
# ...                              ...           ...       ...        ...
# CTRP1_lonidamine_345379         84.0  3.930225e-05 -0.432783   4.405583
# gCSI_Dabrafenib_CID44462760    348.0  2.325133e-05 -0.224714   4.633552
# gCSI_Crizotinib_CID54613769    355.0  1.454781e-06 -0.252417   5.837202
# gCSI_Paclitaxel_CID36314       354.0  4.385183e-09 -0.305523   8.358012
# gCSI_Gemcitabine_CID356653     235.0  1.016730e-10 -0.405593   9.992794
#
#                                        FDR  significant           drug_anno  \
# GDSC1_(5Z)-7-Oxozeaenol_1242  1.477171e-08            1              Others
# GDSC1_VX-11e_262              2.445349e-08            1  ERK MAPK signaling
# GDSC1_Dabrafenib_1373         1.100725e-07            1  ERK MAPK signaling
# GDSC1_NVP-BHG712_295          1.848024e-07            1              Others
# GDSC1_CI-1040_1015            1.928345e-07            1  ERK MAPK signaling
# ...                                    ...          ...                 ...
# CTRP1_lonidamine_345379       7.690735e-04            1              Others
# gCSI_Dabrafenib_CID44462760   4.766523e-04            1  ERK MAPK signaling
# gCSI_Crizotinib_CID54613769   5.010267e-05            1       RTK signaling
# gCSI_Paclitaxel_CID36314      4.719553e-07            1     Antimicrotubule
# gCSI_Gemcitabine_CID356653    2.918015e-08            1      Antimetabolite
#
#                                    cid
# GDSC1_(5Z)-7-Oxozeaenol_1242   9863776
# GDSC1_VX-11e_262              11634725
# GDSC1_Dabrafenib_1373         44462760
# GDSC1_NVP-BHG712_295          16747388
# GDSC1_CI-1040_1015             6918454
# ...                                ...
# CTRP1_lonidamine_345379          39562
# gCSI_Dabrafenib_CID44462760   44462760
# gCSI_Crizotinib_CID54613769   54613769
# gCSI_Paclitaxel_CID36314         36314
# gCSI_Gemcitabine_CID356653      356653
#
# [861 rows x 8 columns]

# %%
NP=len(df_cor_p)
NN=len(df_cor_n)

# %%
sns_df=df_cor_p[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['rS']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=0.3,cmap='coolwarm',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['mlog10p']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=0,vmax=8,cmap='Greens',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_p[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=df_cor_n[['significant']]
N=sns_df.shape[0]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.3,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_p['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[drug_order[2:]]
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NP/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')    

#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
in_df=pd.get_dummies( df_cor_n['drug_anno'] )

# %%
sns_df=in_df[['Platinum']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df[['PARP inhibitor']]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),0.25))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0,)
ax.hlines(y=0,xmin=0,xmax=sns_df.shape[0],color='k')
ax.hlines(y=1,xmin=0,xmax=sns_df.shape[0],color='k')
#ax.vlines(x=0,ymin=0,ymax=sns_df.shape[1],color='k')
#ax.vlines(x=sns_df.shape[0],ymin=0,ymax=sns_df.shape[1],color='k')

# %%
sns_df=in_df.reindex(columns=drug_order[2:]).fillna(0)
N=sns_df.shape[0]
M=sns_df.shape[1]
fig=plt.figure(figsize=(8*(NN/(NP+NN)),M/4.55))
ax=fig.add_subplot(111)
sns.heatmap(sns_df.T,vmin=-0.2,vmax=1,cmap='Greys',cbar=False,ax=ax,xticklabels=0,yticklabels=0)
for i,x in enumerate(sns_df.columns):
    #print(x)
    ax.hlines(y=i+1,xmin=0,xmax=sns_df.shape[0],color='k')
    if i==0:
        ax.hlines(y=i,xmin=0,xmax=sns_df.shape[0],color='k')

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='Platinum']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/1814905853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   pvalues        rS  \
# GDSC2_Oxaliplatin_1806                     720.0  0.000022  0.157393
# GDSC2_Oxaliplatin_1089                     791.0  0.000050  0.143759
# GDSC2_Cisplatin_1005                       757.0  0.007348  0.097359
# GDSC1_Cisplatin_1005                       922.0  0.025371  0.073629
# CTRP2_carboplatin_26979                    514.0  0.136679  0.065734
# PRISM_oxaliplatin_BRD-K78960041-001-05-7   350.0  0.491034  0.036930
# CTRP2_oxaliplatin_375582                   501.0  0.508819  0.029584
# gCSI_Cisplatin_CID24191118                 231.0  0.964023 -0.002984
# PRISM_carboplatin_BRD-K90947825-001-02-7   347.0  0.598903 -0.028333
# PRISM_cisplatin_BRD-K69172251-001-08-9     348.0  0.194960 -0.069641
#
#                                            mlog10p       FDR  significant  \
# GDSC2_Oxaliplatin_1806                    4.655382  0.000221            1
# GDSC2_Oxaliplatin_1089                    4.305224  0.000248            1
# GDSC2_Cisplatin_1005                      2.133817  0.024494            1
# GDSC1_Cisplatin_1005                      1.595667  0.063427            1
# CTRP2_carboplatin_26979                   0.864298  0.273358            0
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  0.308888  0.636023            0
# CTRP2_oxaliplatin_375582                  0.293437  0.636023            0
# gCSI_Cisplatin_CID24191118                0.015912  0.964023            0
# PRISM_carboplatin_BRD-K90947825-001-02-7  0.222644  0.665448            0
# PRISM_cisplatin_BRD-K69172251-001-08-9    0.710054  0.324934            0
#
#                                          drug_anno       cid
# GDSC2_Oxaliplatin_1806                    Platinum   5310940
# GDSC2_Oxaliplatin_1089                    Platinum   5310940
# GDSC2_Cisplatin_1005                      Platinum     84691
# GDSC1_Cisplatin_1005                      Platinum     84691
# CTRP2_carboplatin_26979                   Platinum     38904
# PRISM_oxaliplatin_BRD-K78960041-001-05-7  Platinum  24197464
# CTRP2_oxaliplatin_375582                  Platinum  24197464
# gCSI_Cisplatin_CID24191118                Platinum  24191118
# PRISM_carboplatin_BRD-K90947825-001-02-7  Platinum    426756
# PRISM_cisplatin_BRD-K69172251-001-08-9    Platinum  24191118

# %%
tmp_df=df_cor_pn[df_cor_pn['drug_anno']=='PARP inhibitor']
tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
tmp_df
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_6949/188230088.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df['FDR']=multipletests(tmp_df['pvalues'],method='fdr_bh')[1]
#                                           Number   pvalues        rS  \
# GDSC2_Talazoparib_1259                     738.0  0.001799  0.114721
# GDSC1_Olaparib_1017                        920.0  0.004032  0.094722
# GDSC2_Niraparib_1177                       720.0  0.012993  0.092534
# GDSC1_Talazoparib_1259                     887.0  0.018907  0.078805
# GDSC1_Veliparib_1018                       921.0  0.046852  0.065513
# GDSC1_Olaparib_1495                        883.0  0.340985  0.032082
# PRISM_niraparib_BRD-K54955827-001-02-2     366.0  0.601951  0.027353
# GDSC2_Olaparib_1017                        751.0  0.633154  0.017444
# PRISM_olaparib_BRD-K02113016-001-19-6      338.0  0.751050  0.017319
# PRISM_talazoparib_BRD-K95142244-001-01-5   372.0  0.952333 -0.003110
# GDSC1_Rucaparib_1175                       915.0  0.779791 -0.009255
# CTRP2_veliparib_606034                     525.0  0.669659 -0.018662
# PRISM_olaparib_BRD-K02113016-001-15-4      346.0  0.665575 -0.023318
# CTRP1_olaparib_411867                       84.0  0.556918 -0.064999
# CTRP2_olaparib_411867                      510.0  0.240591 -0.052056
#
#                                            mlog10p       FDR  significant  \
# GDSC2_Talazoparib_1259                    2.744986  0.026984            1
# GDSC1_Olaparib_1017                       2.394464  0.030241            1
# GDSC2_Niraparib_1177                      1.886296  0.064964            1
# GDSC1_Talazoparib_1259                    1.723370  0.070902            1
# GDSC1_Veliparib_1018                      1.329269  0.140557            1
# GDSC1_Olaparib_1495                       0.467265  0.730682            0
# PRISM_niraparib_BRD-K54955827-001-02-2    0.220439  0.835490            0
# GDSC2_Olaparib_1017                       0.198490  0.835490            0
# PRISM_olaparib_BRD-K02113016-001-19-6     0.124331  0.835490            0
# PRISM_talazoparib_BRD-K95142244-001-01-5  0.021211  0.952333            0
# GDSC1_Rucaparib_1175                      0.108022  0.835490            0
# CTRP2_veliparib_606034                    0.174146  0.835490            0
# PRISM_olaparib_BRD-K02113016-001-15-4     0.176803  0.835490            0
# CTRP1_olaparib_411867                     0.254209  0.835490            0
# CTRP2_olaparib_411867                     0.618720  0.601479            0
#
#                                                drug_anno        cid
# GDSC2_Talazoparib_1259                    PARP inhibitor   44819241
# GDSC1_Olaparib_1017                       PARP inhibitor   23725625
# GDSC2_Niraparib_1177                      PARP inhibitor   24958200
# GDSC1_Talazoparib_1259                    PARP inhibitor   44819241
# GDSC1_Veliparib_1018                      PARP inhibitor   11960529
# GDSC1_Olaparib_1495                       PARP inhibitor   23725625
# PRISM_niraparib_BRD-K54955827-001-02-2    PARP inhibitor   24958200
# GDSC2_Olaparib_1017                       PARP inhibitor   23725625
# PRISM_olaparib_BRD-K02113016-001-19-6     PARP inhibitor   23725625
# PRISM_talazoparib_BRD-K95142244-001-01-5  PARP inhibitor  135565082
# GDSC1_Rucaparib_1175                      PARP inhibitor    9931953
# CTRP2_veliparib_606034                    PARP inhibitor   11960529
# PRISM_olaparib_BRD-K02113016-001-15-4     PARP inhibitor   23725625
# CTRP1_olaparib_411867                     PARP inhibitor   23725625
# CTRP2_olaparib_411867                     PARP inhibitor   23725625

# %% [markdown]
# # Broad vs COSMIC

# %%
df12=df0.merge(df2[['SigMA_cosmic','HRD_score_cosmic']],left_on='COSMICID',right_index=True,how='outer')

# %%
in_df=df12.copy()
#plt_df=plt_df[plt_df[cat]=='']
val1,val2,val3='HRD_score_broad','HRD_score_cosmic','BRCA_status'
plt_df=in_df[[val1,val2]].dropna()
print(plt_df.shape)
x,y=plt_df[val1],plt_df[val2]

fig=plt.figure(figsize=(3,3))
ax=fig.add_subplot(111)
ax.scatter(x,y,s=3,c='grey')
ax.set_xlabel(val1)
ax.set_ylabel(val2)
# linear regression, Pearson correlation
lr=stats.linregress(x,y)
a,b,r,p=lr.slope,lr.intercept, lr.rvalue,lr.pvalue
ax.plot(x,a*x+b,lw=1,c='k')

plt_df2=in_df[[val1,val2,val3]].dropna()
plt_df3=plt_df2[plt_df2[val3]=='BRCA1_methylation']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='lime')

plt_df3=plt_df2[plt_df2[val3]=='BRCA1_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='red')

plt_df3=plt_df2[plt_df2[val3]=='BRCA2_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='blue')

ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)

print('r = {:.3f}, p = {:.2e}'.format(r,p))

ax.set_xlim(-5,110)
ax.set_ylim(-5,110)
ax.tick_params(labelsize=10)
# Out:
# (636, 2)
# r = 0.870, p = 9.80e-197

# %%
in_df=df12.copy()
#plt_df=plt_df[plt_df[cat]=='']
val1,val2,val3='SigMA_broad','SigMA_cosmic','BRCA_status'
plt_df=in_df[[val1,val2]].dropna()
print(plt_df.shape)
x,y=plt_df[val1],plt_df[val2]

fig=plt.figure(figsize=(3,3))
ax=fig.add_subplot(111)
ax.scatter(x,y,s=3,c='grey')
ax.set_xlabel(val1)
ax.set_ylabel(val2)
# linear regression, Pearson correlation
lr=stats.linregress(x,y)
a,b,r,p=lr.slope,lr.intercept, lr.rvalue,lr.pvalue
ax.plot(x,a*x+b,lw=1,c='k')

plt_df2=in_df[[val1,val2,val3]].dropna()
plt_df3=plt_df2[plt_df2[val3]=='BRCA1_methylation']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='lime')

plt_df3=plt_df2[plt_df2[val3]=='BRCA1_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='red')

plt_df3=plt_df2[plt_df2[val3]=='BRCA2_LOH']
x1,y1=plt_df3[val1],plt_df3[val2]
ax.scatter(x1,y1,s=5,c='blue')

ax.spines['top'   ].set_visible(False)# .set_color("w")
ax.spines['right' ].set_visible(False)

print('r = {:.3f}, p = {:.2e}'.format(r,p))

ax.set_xticks([0.2,0.4,0.6,0.8])
ax.set_yticks([0.2,0.4,0.6,0.8])
ax.tick_params(labelsize=10)
# Out:
# (941, 2)
# r = 0.959, p = 0.00e+00

# %% [markdown]
# # ROARMAP

# %%
rm=pd.read_excel('../../CellLine_HRD_DrugRes_dev/data/roadmaps_12-14-2021.xlsx')
rm['stripped_name']=[x.replace('_','').replace('-','').replace('/','').replace(' ','') for x in rm['Tumor Model']]
rm['stripped_name']=rm['stripped_name'].replace({'A549ATCC':'A549','A549(ASC)1':'A549',
                                                 '7860':'786O','HelaLUC':'HELA'})
rm['Drug_route']=[x+'_'+y for x,y in zip(rm['Generic Name'],rm['Admin Route'])]

# %%
a=set(rm['stripped_name'])
b=set(df0['stripped_cell_line_name'])
len( a&b )
# Out:
# 72

# %%
counter=Counter(rm['Drug_route']).most_common()
drugs=[x[0] for x in counter[0:10]]
drugs
# Out:
# ['Cyclophosphamide_IP',
#  'Cisplatin_IP',
#  'Paclitaxel_IV',
#  'Fluorouracil_IP',
#  'Methotrexate_IP',
#  'Dacarbazine_IP',
#  'Dactinomycin_IP',
#  'Bleomycin_IP',
#  'Vinblastine_IP',
#  'Carmustine_IP']

# %%
drug='Cisplatin_IP'
add=rm[rm['Drug_route']==drug]
df_add=df2.merge(add, left_on='stripped_cell_line_name',right_on='stripped_name',how='inner')
df_add=df_add.sort_values('Resposive?',ascending=True)
df_add=df_add[~df_add['stripped_name'].duplicated()]
plt_df=df_add#[~df_add[['stripped_name',cat]].duplicated()]
cat='Resposive?'
val='HRD_score_cosmic'
order=['Y','N']
#hue=
palette=['r','dimgrey']
fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(1,1,1)
sns.boxplot(x=cat,y=val,data=plt_df,boxprops={'alpha':0.5},sym='',order=order,palette=palette)
sns.swarmplot(x=cat,y=val,data=plt_df,s=3,order=order,dodge=True,palette=palette)
ax.set_xlabel(cat)
ax.set_title(drug)
ax.tick_params(labelsize=8)

a=plt_df[plt_df[cat]=='Y'][val].dropna().values
b=plt_df[plt_df[cat]=='N'][val].dropna().values
r,p=stats.mannwhitneyu(a,b)
print(len(plt_df), drug,len(plt_df),p)

print( np.median(a),np.median(b) )
# Out:
# 45 Cisplatin_IP 45 0.4124308909827742
# 45.0 36.0

# %%
drug='Cisplatin_IP'
add=rm[rm['Drug_route']==drug]
df_add=df0.merge(add, left_on='stripped_cell_line_name',right_on='stripped_name',how='inner')
df_add=df_add.sort_values('Resposive?',ascending=True)
df_add=df_add[~df_add['stripped_name'].duplicated()]
plt_df=df_add#[~df_add[['stripped_name',cat]].duplicated()]
cat='Resposive?'
val='SigMA_broad'
order=['Y','N']
#hue=
palette=['r','dimgrey']
fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(1,1,1)
sns.boxplot(x=cat,y=val,data=plt_df,boxprops={'alpha':0.5},sym='',order=order,palette=palette)
sns.swarmplot(x=cat,y=val,data=plt_df,s=3,order=order,dodge=True,palette=palette)
ax.set_xlabel(cat)
ax.set_title(drug)
ax.tick_params(labelsize=8)

a=plt_df[plt_df[cat]=='Y'][val].dropna().values
b=plt_df[plt_df[cat]=='N'][val].dropna().values

r,p=stats.mannwhitneyu(a,b)
print(len(plt_df), drug,len(plt_df),p)

print( np.median(a),np.median(b) )
# Out:
# 47 Cisplatin_IP 47 0.44455182146463057
# 0.625475966 0.558120322

# %% [markdown]
# # BCaPE

# %%
drug=pd.read_csv('../../CellLine_HRD_DrugRes_dev/data/DrugResponsesAUCSamples.txt',sep='\t')

# %%
dict_sid_drug_auc={}
for idx in drug.index:
    sid=drug.loc[idx,'ID']
    did=drug.loc[idx,'Drug']
    auc=drug.loc[idx,'AUC']
    if sid not in dict_sid_drug_auc:
        dict_sid_drug_auc[sid]={}
    else:
        dict_sid_drug_auc[sid][did]=auc

# %%
import re
auc=pd.DataFrame(dict_sid_drug_auc).T
auc['ModelName']=[x.split('-')[0] for x in auc.index]
auc.index=[re.sub('CR$','R',x) for x in auc.index]
auc.index=[re.sub('C$','', x) for x in auc.index]

# %%
dict_did_dname={'AZD2281':'Olaparib','AG-014699':'Rucaparib'}
auc=auc.rename(columns=dict_did_dname)

# %%
sigma=pd.read_csv('../data/Cell2016_sigMA.csv').iloc[:,96:]
sigma=sigma.set_index('tumor')
sigma.index=[x.split('//')[1].replace('.maf','') for x in sigma.index]
sigma=sigma.sort_index()
sigma['splitID']=[x.split('-')[0] for x in sigma.index]

# %%
auc_sigma=auc.merge(sigma,left_index=True,right_index=True,how='inner')

# %%
plt_df=auc_sigma.copy()
val1,val2='Signature_3_c','Olaparib'
plt_df=plt_df[[val1,val2]].dropna()
print(len(plt_df))
x,y=plt_df[val1],plt_df[val2]

fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
ax.scatter(x,y,s=5,c='dimgray')
ax.set_xlabel('Signature3',fontsize=12)
ax.set_ylabel('AUC',fontsize=12)
ax.set_title(val2,fontsize=12)
ax.tick_params(labelsize=8)

lr=stats.linregress(x,y)
a,b,r,p=lr.slope,lr.intercept, lr.rvalue,lr.pvalue
X=np.array([min(x),max(x)])
ax.plot(X,a*X+b,lw=1,c='dimgray',ls='dotted')
print('r = {:.3f}, p = {:.2e}'.format(r,p))

print( stats.spearmanr(x,y,nan_policy='omit') )
# Out:
# 19
# r = -0.430, p = 6.60e-02
# SpearmanrResult(correlation=-0.41578947368421054, pvalue=0.07664058021073578)

# %%
plt_df=auc_sigma.copy()
val1,val2='Signature_3_c','Rucaparib'
plt_df=plt_df[[val1,val2]].dropna()
print(len(plt_df))
x,y=plt_df[val1],plt_df[val2]

fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
ax.scatter(x,y,s=5,c='dimgray')
ax.set_xlabel('Signature3',fontsize=12)
ax.set_ylabel('AUC',fontsize=12)
ax.set_title(val2,fontsize=12)
ax.tick_params(labelsize=8)

lr=stats.linregress(x,y)
a,b,r,p=lr.slope,lr.intercept, lr.rvalue,lr.pvalue
X=np.array([min(x),max(x)])
ax.plot(X,a*X+b,lw=1,c='dimgray',ls='dotted')
print('r = {:.3f}, p = {:.2e}'.format(r,p))

print( stats.spearmanr(x,y,nan_policy='omit') )
# Out:
# 13
# r = -0.406, p = 1.69e-01
# SpearmanrResult(correlation=-0.2087912087912088, pvalue=0.493621819356885)
