# %% [markdown]
# # Drug integration

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import os,sys
from scipy import stats
from collections import Counter
plt.style.use('seaborn-white')

# %% [markdown]
# ## GDSC1

# %%
gdsc1=pd.read_excel('../data/GDSC1_fitted_dose_response_25Feb20.xlsx')
gdsc1_cid=pd.read_csv('../data/GDSC1_drug_cid_table_manually_curated.csv')
gdsc1_drug_sel=gdsc1_cid[~gdsc1_cid['pubchem'].isin(['-','None','none'])]

# %%
gdsc1_sel=gdsc1[gdsc1['DRUG_ID'].isin(gdsc1_drug_sel['drug_id'])]

# %%
gdsc1_sel['Drug_name_id']=['GDSC1_'+x+'_'+str(y) for x,y in zip(gdsc1_sel['DRUG_NAME'],gdsc1_sel['DRUG_ID'])]
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_13085/2643892336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdsc1_sel['Drug_name_id']=['GDSC1_'+x+'_'+str(y) for x,y in zip(gdsc1_sel['DRUG_NAME'],gdsc1_sel['DRUG_ID'])]

# %%
dict_cell_drug_val={}
val='AUC'
for idx in gdsc1_sel.index:
    cell=gdsc1_sel.loc[idx,'COSMIC_ID']
    drug=gdsc1_sel.loc[idx,'Drug_name_id']
    if cell not in dict_cell_drug_val:
        dict_cell_drug_val[cell]={}
    else:
        dict_cell_drug_val[cell][drug]=gdsc1_sel.loc[idx,val]

# %%
gdsc1_add=pd.DataFrame(dict_cell_drug_val).sort_index().sort_index(axis=1).T
gdsc1_add
# Out:
#          GDSC1_(5Z)-7-Oxozeaenol_1242  GDSC1_5-Fluorouracil_179  \
# 683665                       0.566264                  0.408888
# 683667                            NaN                  0.897167
# 684052                       0.641645                  0.963662
# 684055                       0.791229                  0.847243
# 684057                       0.748476                  0.677593
# ...                               ...                       ...
# 1660034                      0.507933                  0.589616
# 1660035                      0.978622                  0.659344
# 1660036                      0.738007                  0.617234
# 1674021                      0.632869                  0.865460
# 1789883                      0.772467                       NaN
#
#          GDSC1_A-443654_86  GDSC1_A-770041_55  GDSC1_AICA Ribonucleotide_1001  \
# 683665            0.913908           0.795985                        0.568754
# 683667                 NaN                NaN                        0.948461
# 684052                 NaN                NaN                        0.888970
# 684055            0.911974           0.966585                        0.795625
# 684057            0.972222           0.983873                        0.895263
# ...                    ...                ...                             ...
# 1660034                NaN                NaN                        0.933854
# 1660035                NaN                NaN                        0.918059
# 1660036                NaN                NaN                        0.884238
# 1674021                NaN                NaN                        0.865364
# 1789883                NaN                NaN                             NaN
#
#          GDSC1_AKT inhibitor VIII_171  GDSC1_AKT inhibitor VIII_228  \
# 683665                       0.938230                      0.505289
# 683667                       0.984378                      0.894289
# 684052                       0.974401                      0.942074
# 684055                       0.950905                      0.735332
# 684057                       0.917635                      0.497848
# ...                               ...                           ...
# 1660034                           NaN                      0.761827
# 1660035                           NaN                      0.875047
# 1660036                           NaN                      0.730505
# 1674021                           NaN                      0.928372
# 1789883                           NaN                           NaN
#
#          GDSC1_AR-42_272  GDSC1_AS601245_207  GDSC1_AS605240_224  ...  \
# 683665          0.333898            0.830618            0.554403  ...
# 683667          0.659044            0.941653            0.896050  ...
# 684052          0.687056            0.889795            0.853207  ...
# 684055          0.452680            0.870549            0.931199  ...
# 684057          0.223127            0.877500            0.729284  ...
# ...                  ...                 ...                 ...  ...
# 1660034         0.571169                 NaN            0.667013  ...
# 1660035         0.355107                 NaN            0.711258  ...
# 1660036         0.976338                 NaN            0.608856  ...
# 1674021         0.656471                 NaN            0.822525  ...
# 1789883              NaN                 NaN                 NaN  ...
#
#          GDSC1_XAV939_1268  GDSC1_XMD8-85_106  GDSC1_XMD8-92_1164  \
# 683665            0.972283           0.787667            0.841502
# 683667            0.984642                NaN            0.806652
# 684052            0.978493                NaN            0.954137
# 684055            0.983505           0.984884            0.884187
# 684057            0.973736           0.924651            0.867384
# ...                    ...                ...                 ...
# 1660034           0.856987                NaN            0.869998
# 1660035           0.965019                NaN                 NaN
# 1660036           0.979175                NaN            0.951069
# 1674021           0.941508                NaN            0.909621
# 1789883           0.977748                NaN            0.923719
#
#          GDSC1_Y-39983_309  GDSC1_YK-4-279_1239  GDSC1_YM201636_310  \
# 683665            0.849709                  NaN            0.795951
# 683667            0.897095                  NaN            0.956405
# 684052            0.980571             0.649946            0.948255
# 684055            0.916355             0.734536            0.742204
# 684057            0.879714             0.659554            0.649945
# ...                    ...                  ...                 ...
# 1660034           0.864742             0.698488            0.773071
# 1660035           0.975891             0.974920            0.910276
# 1660036           0.968024             0.861793            0.955228
# 1674021           0.961090             0.694510            0.946183
# 1789883                NaN             0.794186                 NaN
#
#          GDSC1_Z-LLNle-CHO_45  GDSC1_ZM447439_1050  GDSC1_ZSTK474_223  \
# 683665               0.749002             0.828956           0.303362
# 683667                    NaN             0.924510           0.815931
# 684052                    NaN             0.978731           0.828291
# 684055               0.967817             0.704326           0.709809
# 684057               0.974184             0.817735           0.385414
# ...                       ...                  ...                ...
# 1660034                   NaN             0.865617           0.712223
# 1660035                   NaN             0.942055           0.872693
# 1660036                   NaN             0.814820           0.432177
# 1674021                   NaN             0.955444           0.863962
# 1789883                   NaN             0.898161                NaN
#
#          GDSC1_Zibotentan_266
# 683665               0.987224
# 683667               0.985981
# 684052               0.991637
# 684055               0.983258
# 684057               0.970608
# ...                       ...
# 1660034              0.972329
# 1660035              0.967279
# 1660036              0.981412
# 1674021              0.983048
# 1789883                   NaN
#
# [987 rows x 240 columns]

# %% [markdown]
# ## GDSC2

# %%
gdsc2=pd.read_csv('../data/GDSC2_fitted_dose_response_25Feb20.csv')
gdsc2_cid=pd.read_csv('../data/GDSC2_drug_cid_table_manually_curated.csv')
gdsc2_cid['Drug_name_id']=['GDSC2_'+x+'_'+str(y) for x,y in zip(gdsc2_cid['drug_name'],gdsc2_cid['drug_id'])]
gdsc2_drug_sel=gdsc2_cid[~gdsc2_cid['pubchem'].isin(['-','None','none'])]

# %%
gdsc2_sel=gdsc2[gdsc2['DRUG_ID'].isin(gdsc2_drug_sel['drug_id'])]
gdsc2_sel['Drug_name_id']=['GDSC2_'+x+'_'+str(y) for x,y in zip(gdsc2_sel['DRUG_NAME'],gdsc2_sel['DRUG_ID'])]
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_13085/3801743546.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdsc2_sel['Drug_name_id']=['GDSC2_'+x+'_'+str(y) for x,y in zip(gdsc2_sel['DRUG_NAME'],gdsc2_sel['DRUG_ID'])]

# %%
dict_cell_drug_val={}
val='AUC'
for idx in gdsc2_sel.index:
    cell=gdsc2_sel.loc[idx,'COSMIC_ID']
    drug=gdsc2_sel.loc[idx,'Drug_name_id']
    if cell not in dict_cell_drug_val:
        dict_cell_drug_val[cell]={}
    else:
        dict_cell_drug_val[cell][drug]=gdsc2_sel.loc[idx,val]

# %%
gdsc2_add=pd.DataFrame(dict_cell_drug_val).sort_index().sort_index(axis=1).T
gdsc2_add
# Out:
#          GDSC2_5-Fluorouracil_1073  GDSC2_ABT737_1910  GDSC2_AGI-5198_1913  \
# 683665                    0.988746           0.491973             0.991472
# 683667                    0.976741           0.655735             0.972966
# 684052                    0.949240           0.646030             0.972733
# 684057                    0.959395                NaN                  NaN
# 684059                    0.858744           0.785829             0.966310
# ...                            ...                ...                  ...
# 1660034                   0.832363           0.918031             0.955663
# 1660035                   0.963426           0.938137             0.949747
# 1660036                   0.924514                NaN                  NaN
# 1674021                   0.831864           0.914564             0.971497
# 1789883                   0.919174           0.759032             0.974979
#
#          GDSC2_AGI-6780_1634  GDSC2_AMG-319_2045  GDSC2_AZ6102_2109  \
# 683665              0.921248            0.990548           0.855110
# 683667              0.972888            0.971282           0.837857
# 684052              0.958843            0.988567           0.794876
# 684057              0.948520                 NaN                NaN
# 684059              0.963419            0.955631           0.848514
# ...                      ...                 ...                ...
# 1660034             0.976561                 NaN           0.925704
# 1660035             0.941915                 NaN                NaN
# 1660036             0.983145                 NaN                NaN
# 1674021             0.971378            0.968631           0.848079
# 1789883             0.951919            0.974592           0.769645
#
#          GDSC2_AZ960_1250  GDSC2_AZD3759_1915  GDSC2_AZD4547_1786  \
# 683665           0.670322            0.990219            0.968525
# 683667           0.860038            0.989522            0.994262
# 684052           0.807361            0.984985            0.948738
# 684057           0.730258                 NaN                 NaN
# 684059           0.756592            0.986403            0.982099
# ...                   ...                 ...                 ...
# 1660034          0.951805            0.947328            0.966178
# 1660035          0.863267            0.969401            0.981937
# 1660036          0.957422                 NaN            0.971722
# 1674021          0.838834            0.970680            0.961853
# 1789883          0.979096            0.756976            0.988047
#
#          GDSC2_AZD5363_1916  ...  GDSC2_Vinorelbine_2048  \
# 683665             0.961817  ...                0.645842
# 683667             0.876508  ...                0.710986
# 684052             0.935697  ...                0.640397
# 684057                  NaN  ...                     NaN
# 684059             0.934719  ...                0.529711
# ...                     ...  ...                     ...
# 1660034            0.882164  ...                0.760526
# 1660035            0.947255  ...                     NaN
# 1660036                 NaN  ...                0.884967
# 1674021            0.829375  ...                0.627238
# 1789883            0.858905  ...                0.732401
#
#          GDSC2_Vorinostat_1012  GDSC2_WEHI-539_1997  GDSC2_WIKI4_1940  \
# 683665                0.744778             0.306364          0.841007
# 683667                0.695245             0.922247          0.948386
# 684052                0.800694             0.949760          0.949546
# 684057                     NaN                  NaN               NaN
# 684059                0.785805             0.948819          0.944875
# ...                        ...                  ...               ...
# 1660034               0.882738             0.955368          0.881543
# 1660035               0.784177             0.977847          0.934910
# 1660036                    NaN                  NaN               NaN
# 1674021               0.747011             0.949813          0.905999
# 1789883               0.703967             0.923155          0.923841
#
#          GDSC2_WZ4003_1614  GDSC2_Wee1 Inhibitor_1046  GDSC2_Wnt-C59_1622  \
# 683665            0.945011                   0.713712            0.852600
# 683667            0.882791                   0.827897            0.961412
# 684052            0.955502                   0.837360            0.969871
# 684057            0.825403                        NaN            0.965422
# 684059            0.915169                   0.881386            0.961724
# ...                    ...                        ...                 ...
# 1660034           0.975864                   0.918233            0.954496
# 1660035           0.963458                   0.971475            0.955843
# 1660036           0.987716                        NaN            0.971806
# 1674021           0.943055                   0.758515            0.979652
# 1789883           0.949125                   0.841085            0.941536
#
#          GDSC2_XAV939_1268  GDSC2_YK-4-279_1239  GDSC2_ZM447439_1050
# 683665            0.939151             0.695062                  NaN
# 683667            0.942191             0.784064                  NaN
# 684052            0.973265             0.617951                  NaN
# 684057            0.973363                  NaN                  NaN
# 684059            0.985809             0.670564                  NaN
# ...                    ...                  ...                  ...
# 1660034           0.949847             0.757741                  NaN
# 1660035           0.968306             0.875885                  NaN
# 1660036           0.993065                  NaN                  NaN
# 1674021           0.959474             0.760292                  NaN
# 1789883           0.938305             0.736408                  NaN
#
# [809 rows x 166 columns]

# %% [markdown]
# ## CTRP2

# %%
ctrp2_exp=pd.read_csv('../data/v20.meta.per_experiment.txt',sep='\t')
dict_expid_cclid={}
for idx in ctrp2_exp.index:
    dict_expid_cclid[ctrp2_exp.loc[idx,'experiment_id']]=ctrp2_exp.loc[idx,'master_ccl_id']

# %%
ctrp2_val=pd.read_csv('../data/v20.data.curves_post_qc.txt',sep='\t')
ctrp2_val['master_ccl_id']=[dict_expid_cclid[x] for x in ctrp2_val['experiment_id']]

# %%
dict_cid_cpd_val={}
for idx in ctrp2_val.index:
    val=ctrp2_val.loc[idx,'area_under_curve']
    cid=ctrp2_val.loc[idx,'master_ccl_id']
    cpd=ctrp2_val.loc[idx,'master_cpd_id']
    if cid not in dict_cid_cpd_val:
        dict_cid_cpd_val[cid]={}
    else:
        dict_cid_cpd_val[cid][cpd]=val
        
ctrp2_auc=pd.DataFrame(dict_cid_cpd_val)

# %%
ctrp2_cell=pd.read_csv('../data/v20.meta.per_cell_line.txt',sep='\t')
ctrp2_cell['master_ccl_id'].duplicated().sum()
dict_cellid_cname_ctrp2={k:v for k,v in zip(ctrp2_cell['master_ccl_id'],ctrp2_cell['ccl_name'])}

# %%
ctrp2_info=pd.read_csv('../data/CTRPv2.0._INFORMER_SET.csv')
ctrp2_info_sel=ctrp2_info[ctrp2_info['cpd_status'].isin(['clinical','FDA'])]
ctrp2_info_sel=ctrp2_info_sel[~ctrp2_info_sel['master_cpd_id'].isna()]
dict_cpdid_name_ctrp2={k:v for k,v in zip(ctrp2_info_sel['master_cpd_id'],ctrp2_info_sel['cpd_name'])}

# %%
ctrp2_anno=pd.read_csv('../data/CTRP2_pharmacoDB_drug_info_manually_curated.txt',sep='\t')
ctrp2_add=ctrp2_anno[['master_cpd_id','cid']].fillna(-1).astype(int)

# %%
ctrp2_info_sel=ctrp2_info_sel.merge(ctrp2_add,left_on='master_cpd_id',right_on='master_cpd_id',how='left')

# %%
ctrp2_auc_sel=ctrp2_auc.loc[ctrp2_auc.index.isin(dict_cpdid_name_ctrp2),:]
ctrp2_auc_sel=ctrp2_auc_sel.rename(columns=dict_cellid_cname_ctrp2).sort_index(axis=1)

# %%
ctrp2_auc_sel
# Out:
#            2004   22RV1  2313287    253J  253JBV   42MGBA     5637    639V  \
# 25036   13.7950  13.419   13.061  13.521  14.362  12.9790  12.6900  13.683
# 25334   14.2070  14.173   13.774  13.513  14.747  14.2990  12.0580  13.145
# 25344   12.0720  11.254   11.810  12.734  14.096   7.8500   8.6557  14.127
# 26870       NaN  14.018   16.643  15.751  14.365      NaN  15.1770  15.000
# 26874   15.5810  14.894   14.819  15.257  14.817  14.7170  15.6690  14.524
# ...         ...     ...      ...     ...     ...      ...      ...     ...
# 687579  12.0740     NaN      NaN     NaN     NaN  11.9500      NaN     NaN
# 687694  15.6890     NaN      NaN     NaN     NaN  14.8440      NaN     NaN
# 687720   7.0814     NaN      NaN     NaN     NaN   9.4644      NaN     NaN
# 687954  11.7470     NaN      NaN     NaN     NaN  12.2470      NaN     NaN
# 688229   6.8527     NaN      NaN     NaN     NaN   9.6997      NaN     NaN
#
#            647V      697  ...   YAMATO    YAPC   YD10B    YD15    YD38  \
# 25036   13.9110      NaN  ...  14.7550  13.904  13.248  14.052  13.883
# 25334   12.6310      NaN  ...  14.5370  14.302  14.288  13.260  14.725
# 25344   13.8310  11.1370  ...  15.2400  13.269  12.185  12.583  12.021
# 26870       NaN      NaN  ...      NaN     NaN  16.609  14.999  16.234
# 26874   14.4300      NaN  ...  16.7910  15.535  14.005  16.208  14.318
# ...         ...      ...  ...      ...     ...     ...     ...     ...
# 687579  15.3980  14.2320  ...  13.7060     NaN     NaN     NaN     NaN
# 687694  15.0710  14.4310  ...  15.0000     NaN     NaN     NaN     NaN
# 687720   7.0018   4.7709  ...   7.6535     NaN     NaN     NaN     NaN
# 687954  14.6500   8.0356  ...  14.8870     NaN     NaN     NaN     NaN
# 688229   8.0956   5.1539  ...   8.2331     NaN     NaN     NaN     NaN
#
#            YD8     YH13     YKG1   ZR751   ZR7530
# 25036   14.059  12.6710      NaN  14.896  12.9810
# 25334   14.285  14.3150      NaN  17.245  14.6980
# 25344   13.585  14.4760  14.2070  14.301  14.2230
# 26870      NaN      NaN      NaN     NaN      NaN
# 26874   16.770  12.6890      NaN     NaN  14.2450
# ...        ...      ...      ...     ...      ...
# 687579     NaN  15.7460  14.9230     NaN  14.8790
# 687694     NaN  14.7880  15.3820     NaN  14.6960
# 687720     NaN   7.7349  10.7310     NaN   9.1904
# 687954     NaN  14.2220  15.5480     NaN  14.7600
# 688229     NaN   8.0474   8.3161     NaN  11.4960
#
# [173 rows x 887 columns]

# %%
dids=[]
for idx in ctrp2_auc_sel.index:
    did='CTRP2_'+dict_cpdid_name_ctrp2[idx]+'_'+str(idx)
    dids.append(did)
ctrp2_auc_sel.index=dids

# %%
ctrp2_auc_sel=ctrp2_auc_sel.sort_index()

# %% [markdown]
# ## CTRP1

# %%
ctrp1_val=pd.read_csv('../data/v10.D3.area_under_conc_curve.txt',sep='\t')

# %%
dict_cid_cpd_val={}
for idx in ctrp1_val.index:
    val=ctrp1_val.loc[idx,'area_under_curve']
    cid=ctrp1_val.loc[idx,'ccl_name']
    cpd=ctrp1_val.loc[idx,'cpd_name']
    if cid not in dict_cid_cpd_val:
        dict_cid_cpd_val[cid]={}
    else:
        dict_cid_cpd_val[cid][cpd]=val        
ctrp1_auc=pd.DataFrame(dict_cid_cpd_val)

# %%
ctrp1_info=pd.read_csv('../data/CTRPv1.0._INFORMER_SET.csv')
ctrp1_info_sel=ctrp1_info[ctrp1_info['cpd_status'].isin(['clinical candidate', 'FDA-approved'])]
ctrp1_info_sel
ctrp1_info_sel=ctrp1_info_sel[~ctrp1_info_sel['master_cpd_id'].isna()]
dict_cpdname_did_ctrp1={v:k for k,v in zip(ctrp1_info_sel['master_cpd_id'],ctrp1_info_sel['cpd_name'])}

# %%
ctrp1_info_sel[ctrp1_info_sel['pubchem_cid'].isna()]
# Out:
#        cpd_name                                 cpd_synonym    cpd_status  \
# 308   sirolimus                          rapamycin;Rapamune  FDA-approved
# 316  tacrolimus  FK-506;fujimycin;Prograf;Advagraf;Protopic  FDA-approved
#
#                         target_or_activity_of_compound  \
# 308  inhibitor of mTOR via FRB domain (in complex w...
# 316    inhibitor of calcineurin (in complex with FKBP)
#
#           gene_symbol_of_protein_target  top_test_conc_umol  \
# 308                                MTOR                37.0
# 316  PPP3CA;PPP3CB;PPP3CC;PPP3R1;PPP3R2                74.0
#
#      percent_cpd_purity                                         cpd_smiles  \
# 308                 NaN  CO[C@@H]1C[C@H](C[C@@H](C)[C@@H]2CC(=O)[C@H](C...
# 316                 NaN  CO[C@@H]1CC(CC[C@H]1O)\C=C(/C)\[C@H]2OC(=O)[C@...
#
#      pubchem_cid   broad_cpd_id  master_cpd_id
# 308          NaN  BRD-A23770159         411830
# 316          NaN  BRD-K08845546          55450

# %%
ctrp1_info_sel.loc[308,'pubchem_cid']=5284616
ctrp1_info_sel.loc[316,'pubchem_cid']=445643

# %%
ctrp1_auc_sel=ctrp1_auc[ctrp1_auc.index.isin(ctrp1_info_sel['cpd_name'])]
ctrp1_auc_sel=ctrp1_auc_sel.sort_index().sort_index(axis=1)

# %%
dids=[]
for idx in ctrp1_auc_sel.index:
    did='CTRP1_'+str(idx)+'_'+str(dict_cpdname_did_ctrp1[idx])
    dids.append(did)
ctrp1_auc_sel.index=dids

# %%
ctrp1_auc_sel
# Out:
#                                5637   A2780    A375    A549     AGS    AMO1  \
# CTRP1_2-deoxyglucose_347781  6.2317     NaN     NaN  6.5936     NaN     NaN
# CTRP1_ABT-737_411738         5.2349  6.4910  7.1257  6.2269  3.7019  7.0969
# CTRP1_ABT-751_417983         1.3811  2.2385  2.6517  3.7262  2.0065  1.1897
# CTRP1_ATRA_411870               NaN  6.6698  5.9579     NaN  7.5154  9.0956
# CTRP1_BEZ235_348992             NaN  3.4951  3.8438     NaN  3.3303  4.9585
# ...                             ...     ...     ...     ...     ...     ...
# CTRP1_valdecoxib_32372          NaN  4.9585  6.6086     NaN  6.8206  7.3084
# CTRP1_veliparib_606034          NaN     NaN  6.3404     NaN     NaN     NaN
# CTRP1_vismodegib_397704      6.6173  7.2539  6.9366  7.0051  6.2829  8.5852
# CTRP1_vorinostat_56554       2.4331  1.9301  2.7053  2.7953  1.3732  2.0972
# CTRP1_zileuton_346974           NaN  5.5863  6.6267     NaN  5.2206  5.9855
#
#                                 BEN     BL70  C2BBE1  CAL12T  ...   SW948  \
# CTRP1_2-deoxyglucose_347781  7.2503  6.10170  6.1555     NaN  ...     NaN
# CTRP1_ABT-737_411738         3.5973  5.47980  5.2244  6.7488  ...  5.2419
# CTRP1_ABT-751_417983         5.8026  0.15431     NaN  3.9351  ...  4.2293
# CTRP1_ATRA_411870               NaN      NaN     NaN  6.7019  ...  5.4495
# CTRP1_BEZ235_348992             NaN      NaN     NaN  3.3834  ...  2.4341
# ...                             ...      ...     ...     ...  ...     ...
# CTRP1_valdecoxib_32372          NaN      NaN     NaN  5.0076  ...  5.4862
# CTRP1_veliparib_606034          NaN      NaN     NaN     NaN  ...     NaN
# CTRP1_vismodegib_397704      6.8776  7.04650  6.6561  6.9891  ...  6.8072
# CTRP1_vorinostat_56554       2.5882  0.97163  2.6140  3.4094  ...  1.1170
# CTRP1_zileuton_346974           NaN      NaN     NaN  6.3520  ...  6.7637
#
#                               T3M10     THP1   TYKNU    U2OS    U937   UMUC3  \
# CTRP1_2-deoxyglucose_347781     NaN      NaN     NaN     NaN     NaN  6.9127
# CTRP1_ABT-737_411738         1.4003  5.77030  6.3093  6.7599  4.9088  5.3930
# CTRP1_ABT-751_417983         4.6704  2.53670  3.2594  4.4100  1.1265  3.7863
# CTRP1_ATRA_411870            6.3662  3.89240  6.2165  6.7517  3.9180     NaN
# CTRP1_BEZ235_348992          5.0682  2.89110  3.0690  3.7451  2.9151     NaN
# ...                             ...      ...     ...     ...     ...     ...
# CTRP1_valdecoxib_32372       5.1755  4.50830  5.3782     NaN  3.8451     NaN
# CTRP1_veliparib_606034       6.6674  5.66240  6.3382     NaN  7.4383     NaN
# CTRP1_vismodegib_397704      6.6719  6.07770  6.2801  6.8144  6.5591  6.8400
# CTRP1_vorinostat_56554       3.7680  0.98992  2.7057  2.0930  1.0660  4.6142
# CTRP1_zileuton_346974        5.7622  7.23580  6.2930     NaN  5.7432     NaN
#
#                              VMRCLCD  VMRCRCW  WSUDLCL2
# CTRP1_2-deoxyglucose_347781  6.55890   6.7850       NaN
# CTRP1_ABT-737_411738         3.77400   4.8952   3.18870
# CTRP1_ABT-751_417983         0.80486   4.8160   0.56658
# CTRP1_ATRA_411870                NaN      NaN   4.33330
# CTRP1_BEZ235_348992              NaN      NaN   2.14060
# ...                              ...      ...       ...
# CTRP1_valdecoxib_32372           NaN      NaN   5.47510
# CTRP1_veliparib_606034           NaN      NaN   6.85490
# CTRP1_vismodegib_397704      6.75210   6.6989   6.79200
# CTRP1_vorinostat_56554       1.12710   3.6560   0.93040
# CTRP1_zileuton_346974            NaN      NaN   6.44390
#
# [90 rows x 242 columns]

# %% [markdown]
# ## PRISM

# %%
prism=pd.read_csv('../data/secondary-screen-dose-response-curve-parameters.csv')
# Out:
# /Users/tshiro/.pyenv/versions/miniforge3-4.10/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dict_bid_did_val={}
for idx in prism.index:
    bid=prism.loc[idx,'broad_id']
    did=prism.loc[idx,'depmap_id']
    val=prism.loc[idx,'auc']
    if bid not in dict_bid_did_val:
        dict_bid_did_val[bid]={}
    else:
        dict_bid_did_val[bid][did]=val

# %%
prism_auc=pd.DataFrame(dict_bid_did_val).T
prism_auc
# Out:
#                         ACH-000320  ACH-001145  ACH-000873  ACH-000855  \
# BRD-K71847383-001-12-5    1.240300    1.472333    1.207160    1.229332
# BRD-A98990573-003-01-3    1.565786    1.525007    1.333858    1.461459
# BRD-K47832606-001-30-1    0.336463    0.485618    0.548483    0.631609
# BRD-K72951360-001-01-4    0.651509    0.505583    0.591650    0.617227
# BRD-K33127281-001-05-6    1.379432    0.968500    1.194919    1.209085
# ...                            ...         ...         ...         ...
# BRD-K85402309-043-01-9    0.866265    0.862640    0.781424    1.000000
# BRD-K88510285-001-17-8    0.492455    0.633637    0.457427    0.534181
# BRD-K92723993-001-17-4    1.000000    1.000000    0.989859         NaN
# BRD-M97302542-001-04-4    1.000000    0.996181    1.000000    1.000000
# BRD-K13514097-001-04-6    1.000000    0.873883    1.000000    0.663248
#
#                         ACH-000913  ACH-000558  ACH-000593  ACH-000488  \
# BRD-K71847383-001-12-5    1.130378    1.436740    1.328064    1.200396
# BRD-A98990573-003-01-3    1.455895    1.581816    1.544465    1.249404
# BRD-K47832606-001-30-1    0.647397    0.580288    0.645974    0.598061
# BRD-K72951360-001-01-4    0.809460    0.826771    0.752404    0.630702
# BRD-K33127281-001-05-6    1.165317    1.260609    1.135452    1.121895
# ...                            ...         ...         ...         ...
# BRD-K85402309-043-01-9    0.694885    0.943005    0.948937    0.796833
# BRD-K88510285-001-17-8    0.720609    0.511024    0.687134    0.771501
# BRD-K92723993-001-17-4    1.000000         NaN    1.000000    1.000000
# BRD-M97302542-001-04-4    0.926474    0.847692    0.961398    0.992998
# BRD-K13514097-001-04-6    0.730226    0.976234    0.782534    0.556155
#
#                         ACH-000832  ACH-000781  ...  ACH-000924  ACH-000628  \
# BRD-K71847383-001-12-5    1.335735    1.467798  ...         NaN         NaN
# BRD-A98990573-003-01-3    1.462856    1.562774  ...         NaN         NaN
# BRD-K47832606-001-30-1    0.564635    0.690942  ...         NaN         NaN
# BRD-K72951360-001-01-4    0.647558    0.707443  ...         NaN         NaN
# BRD-K33127281-001-05-6    1.172720    1.236926  ...    1.086418    1.255210
# ...                            ...         ...  ...         ...         ...
# BRD-K85402309-043-01-9    0.946861         NaN  ...    1.000000    1.000000
# BRD-K88510285-001-17-8    0.515982    1.000000  ...    0.839772    0.717733
# BRD-K92723993-001-17-4    0.972794    1.000000  ...    1.000000    1.000000
# BRD-M97302542-001-04-4    0.987591    0.864479  ...    0.913766    1.000000
# BRD-K13514097-001-04-6    1.000000    0.568287  ...    0.915327    0.762295
#
#                         ACH-000510  ACH-000086  ACH-000947  ACH-000917  \
# BRD-K71847383-001-12-5         NaN         NaN         NaN         NaN
# BRD-A98990573-003-01-3         NaN         NaN         NaN         NaN
# BRD-K47832606-001-30-1         NaN         NaN         NaN         NaN
# BRD-K72951360-001-01-4         NaN         NaN         NaN         NaN
# BRD-K33127281-001-05-6    1.131118    0.977359    0.987091     1.40125
# ...                            ...         ...         ...         ...
# BRD-K85402309-043-01-9    0.988552    0.718694    0.758549         NaN
# BRD-K88510285-001-17-8    0.729825    0.617289    0.538059         NaN
# BRD-K92723993-001-17-4    1.000000    1.000000         NaN         NaN
# BRD-M97302542-001-04-4    0.881420    1.000000         NaN         NaN
# BRD-K13514097-001-04-6    1.000000    0.810215         NaN         NaN
#
#                         ACH-000454  ACH-000030  ACH-000476  ACH-000826
# BRD-K71847383-001-12-5         NaN         NaN         NaN         NaN
# BRD-A98990573-003-01-3         NaN         NaN         NaN         NaN
# BRD-K47832606-001-30-1         NaN         NaN         NaN         NaN
# BRD-K72951360-001-01-4         NaN         NaN         NaN         NaN
# BRD-K33127281-001-05-6    0.924889    1.076209         NaN         NaN
# ...                            ...         ...         ...         ...
# BRD-K85402309-043-01-9    0.833390    0.780134    0.929951    0.891253
# BRD-K88510285-001-17-8    0.509546    0.591776    0.758900    1.000000
# BRD-K92723993-001-17-4    0.936010    0.911568    0.915373    1.000000
# BRD-M97302542-001-04-4    1.000000    0.975725    1.000000    1.000000
# BRD-K13514097-001-04-6    0.745815    0.740103    0.945534    0.836894
#
# [1502 rows x 481 columns]

# %%
prism_anno=pd.read_csv('../data/PRISM_pharmacoDB_drug_info_manually_curated.txt',sep='\t')
prism_anno['disease.area']=prism_anno['disease.area'].fillna('NoData')

# %%
flag=prism_anno['disease.area'].str.contains('oncology')|prism_anno['disease.area'].str.contains('malignancy')
prism_anno=prism_anno[flag]
prism_anno=prism_anno[~prism_anno['cid'].isna()]
prism_anno['cid']=prism_anno['cid'].astype(int)

# %%
prism_anno_dup=prism_anno[prism_anno['broad_id'].str.contains('///')]
prism_anno_ndup=prism_anno[~prism_anno['broad_id'].str.contains('///')]

# %%
dupids=prism_anno_dup['broad_id']

# %%
adds=[]
for dupid in dupids:
    bids=dupid.split('///')
    add=prism_anno_dup[prism_anno_dup['broad_id']==dupid]
    add=pd.concat([add,add])
    add.loc[:,'broad_id']=bids
    adds.append(add)
prism_anno_dup_c=pd.concat(adds)
prism_anno_dup_c
# Out:
#                Unnamed: 0         PRISM.drugid                broad_id  \
# 33    Abiraterone-acetate  abiraterone-acetate  BRD-K50071428-001-03-3
# 33    Abiraterone-acetate  abiraterone-acetate  BRD-K24048528-001-02-5
# 54               Afatinib             afatinib  BRD-K66175015-001-12-4
# 54               Afatinib             afatinib  BRD-K66175015-001-09-0
# 59              Alectinib            alectinib  BRD-K11267252-001-04-4
# ...                   ...                  ...                     ...
# 1379          Vemurafenib          vemurafenib  BRD-K56343971-001-10-6
# 1380           Venetoclax           venetoclax  BRD-K62391742-001-09-7
# 1380           Venetoclax           venetoclax  BRD-K62391742-001-03-0
# 1394           Vorinostat           vorinostat  BRD-K81418486-001-47-5
# 1394           Vorinostat           vorinostat  BRD-K81418486-001-44-2
#
#                compound_plate                                     moa  \
# 33                    PREP020         androgen biosynthesis inhibitor
# 33                    PREP020         androgen biosynthesis inhibitor
# 54    PROS003_PR500///PREP021                          EGFR inhibitor
# 54    PROS003_PR500///PREP021                          EGFR inhibitor
# 59    PREP020///PROS003_PR500  ALK tyrosine kinase receptor inhibitor
# ...                       ...                                     ...
# 1379  PROS004_PR500///PREP022                           RAF inhibitor
# 1380  PROS001_PR500///PREP045                           BCL inhibitor
# 1380  PROS001_PR500///PREP045                           BCL inhibitor
# 1394  PREP048///PROS001_PR500                          HDAC inhibitor
# 1394  PREP048///PROS001_PR500                          HDAC inhibitor
#
#                                                  target  \
# 33                           CYP11B1, CYP17A1///CYP17A1
# 33                           CYP11B1, CYP17A1///CYP17A1
# 54                                   EGFR, ERBB2, ERBB4
# 54                                   EGFR, ERBB2, ERBB4
# 59                                             ALK, MET
# ...                                                 ...
# 1379                                         BRAF, RAF1
# 1380                                               BCL2
# 1380                                               BCL2
# 1394  HDAC1, HDAC10, HDAC11, HDAC2, HDAC3, HDAC5, HD...
# 1394  HDAC1, HDAC10, HDAC11, HDAC2, HDAC3, HDAC5, HD...
#
#                 disease.area                          indication  \
# 33                  oncology                     prostate cancer
# 33                  oncology                     prostate cancer
# 54                  oncology  non-small cell lung cancer (NSCLC)
# 54                  oncology  non-small cell lung cancer (NSCLC)
# 59                  oncology  non-small cell lung cancer (NSCLC)
# ...                      ...                                 ...
# 1379                oncology                            melanoma
# 1380  hematologic malignancy  chronic lymphocytic leukemia (CLL)
# 1380  hematologic malignancy  chronic lymphocytic leukemia (CLL)
# 1394  hematologic malignancy    cutaneous T-cell lymphoma (CTCL)
# 1394  hematologic malignancy    cutaneous T-cell lymphoma (CTCL)
#
#                                                  smiles     phase  \
# 33    CC(=O)O[C@H]1CC[C@]2(C)[C@H]3CC[C@@]4(C)[C@@H]...  Launched
# 33    CC(=O)O[C@H]1CC[C@]2(C)[C@H]3CC[C@@]4(C)[C@@H]...  Launched
# 54    CN(C)C\C=C\C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...  Launched
# 54    CN(C)C\C=C\C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...  Launched
# 59    CCc1cc2C(=O)c3c([nH]c4cc(ccc34)C#N)C(C)(C)c2cc...  Launched
# ...                                                 ...       ...
# 1379  CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(cc23)...  Launched
# 1380  CC1(C)CCC(CN2CCN(CC2)c2ccc(C(=O)NS(=O)(=O)c3cc...  Launched
# 1380  CC1(C)CCC(CN2CCN(CC2)c2ccc(C(=O)NS(=O)(=O)c3cc...  Launched
# 1394  ONC(=O)CCCCCCC(=O)Nc1ccccc1, ONC(=O)CCCCCCC(=O...  Launched
# 1394  ONC(=O)CCCCCCC(=O)Nc1ccccc1, ONC(=O)CCCCCCC(=O...  Launched
#
#            drugid       cid                     inchikey
# 33    Abiraterone   9821849  GZOSMCIZMLWJML-VJLLXTKPSA-N
# 33    Abiraterone   9821849  GZOSMCIZMLWJML-VJLLXTKPSA-N
# 54       Afatinib  10184653  ULXXDDBFHOBEHA-CWDCEQMOSA-N
# 54       Afatinib  10184653  ULXXDDBFHOBEHA-CWDCEQMOSA-N
# 59      Alectinib  49806720                          NaN
# ...           ...       ...                          ...
# 1379  Vemurafenib  42611257  GPXBXXGIAQBQNI-UHFFFAOYSA-N
# 1380   Venetoclax  49846579                          NaN
# 1380   Venetoclax  49846579                          NaN
# 1394   Vorinostat      5311  WAEXFXRVDQXREF-UHFFFAOYSA-N
# 1394   Vorinostat      5311  WAEXFXRVDQXREF-UHFFFAOYSA-N
#
# [62 rows x 13 columns]

# %%
prism_anno_r=pd.concat([prism_anno_ndup,prism_anno_dup_c])
bid_dup=prism_anno_r[prism_anno_r['broad_id'].duplicated()]['broad_id'].values[0]
prism_anno_r[prism_anno_r['broad_id']==bid_dup]
# Out:
#              Unnamed: 0         PRISM.drugid                broad_id  \
# 32          Abiraterone          abiraterone  BRD-K50071428-001-03-3
# 33  Abiraterone-acetate  abiraterone-acetate  BRD-K50071428-001-03-3
#
#    compound_plate                              moa  \
# 32        PREP031  androgen biosynthesis inhibitor
# 33        PREP020  androgen biosynthesis inhibitor
#
#                         target disease.area       indication  \
# 32  CYP11B1, CYP17A1///CYP17A1     oncology  prostate cancer
# 33  CYP11B1, CYP17A1///CYP17A1     oncology  prostate cancer
#
#                                                smiles     phase       drugid  \
# 32  C[C@]12CC[C@H]3[C@@H](CC=C4C[C@@H](O)CC[C@]34C...  Launched  Abiraterone
# 33  CC(=O)O[C@H]1CC[C@]2(C)[C@H]3CC[C@@]4(C)[C@@H]...  Launched  Abiraterone
#
#         cid                     inchikey
# 32   132971  GZOSMCIZMLWJML-VJLLXTKPSA-N
# 33  9821849  GZOSMCIZMLWJML-VJLLXTKPSA-N

# %%
did_dup=prism_anno_r[prism_anno_r['PRISM.drugid'].duplicated()]['PRISM.drugid']
prism_anno_r[prism_anno_r['PRISM.drugid'].isin(did_dup)]
# Out:
#                Unnamed: 0         PRISM.drugid                broad_id  \
# 33    Abiraterone-acetate  abiraterone-acetate  BRD-K50071428-001-03-3
# 33    Abiraterone-acetate  abiraterone-acetate  BRD-K24048528-001-02-5
# 54               Afatinib             afatinib  BRD-K66175015-001-12-4
# 54               Afatinib             afatinib  BRD-K66175015-001-09-0
# 59              Alectinib            alectinib  BRD-K11267252-001-04-4
# ...                   ...                  ...                     ...
# 1379          Vemurafenib          vemurafenib  BRD-K56343971-001-10-6
# 1380           Venetoclax           venetoclax  BRD-K62391742-001-09-7
# 1380           Venetoclax           venetoclax  BRD-K62391742-001-03-0
# 1394           Vorinostat           vorinostat  BRD-K81418486-001-47-5
# 1394           Vorinostat           vorinostat  BRD-K81418486-001-44-2
#
#                compound_plate                                     moa  \
# 33                    PREP020         androgen biosynthesis inhibitor
# 33                    PREP020         androgen biosynthesis inhibitor
# 54    PROS003_PR500///PREP021                          EGFR inhibitor
# 54    PROS003_PR500///PREP021                          EGFR inhibitor
# 59    PREP020///PROS003_PR500  ALK tyrosine kinase receptor inhibitor
# ...                       ...                                     ...
# 1379  PROS004_PR500///PREP022                           RAF inhibitor
# 1380  PROS001_PR500///PREP045                           BCL inhibitor
# 1380  PROS001_PR500///PREP045                           BCL inhibitor
# 1394  PREP048///PROS001_PR500                          HDAC inhibitor
# 1394  PREP048///PROS001_PR500                          HDAC inhibitor
#
#                                                  target  \
# 33                           CYP11B1, CYP17A1///CYP17A1
# 33                           CYP11B1, CYP17A1///CYP17A1
# 54                                   EGFR, ERBB2, ERBB4
# 54                                   EGFR, ERBB2, ERBB4
# 59                                             ALK, MET
# ...                                                 ...
# 1379                                         BRAF, RAF1
# 1380                                               BCL2
# 1380                                               BCL2
# 1394  HDAC1, HDAC10, HDAC11, HDAC2, HDAC3, HDAC5, HD...
# 1394  HDAC1, HDAC10, HDAC11, HDAC2, HDAC3, HDAC5, HD...
#
#                 disease.area                          indication  \
# 33                  oncology                     prostate cancer
# 33                  oncology                     prostate cancer
# 54                  oncology  non-small cell lung cancer (NSCLC)
# 54                  oncology  non-small cell lung cancer (NSCLC)
# 59                  oncology  non-small cell lung cancer (NSCLC)
# ...                      ...                                 ...
# 1379                oncology                            melanoma
# 1380  hematologic malignancy  chronic lymphocytic leukemia (CLL)
# 1380  hematologic malignancy  chronic lymphocytic leukemia (CLL)
# 1394  hematologic malignancy    cutaneous T-cell lymphoma (CTCL)
# 1394  hematologic malignancy    cutaneous T-cell lymphoma (CTCL)
#
#                                                  smiles     phase  \
# 33    CC(=O)O[C@H]1CC[C@]2(C)[C@H]3CC[C@@]4(C)[C@@H]...  Launched
# 33    CC(=O)O[C@H]1CC[C@]2(C)[C@H]3CC[C@@]4(C)[C@@H]...  Launched
# 54    CN(C)C\C=C\C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...  Launched
# 54    CN(C)C\C=C\C(=O)Nc1cc2c(Nc3ccc(F)c(Cl)c3)ncnc2...  Launched
# 59    CCc1cc2C(=O)c3c([nH]c4cc(ccc34)C#N)C(C)(C)c2cc...  Launched
# ...                                                 ...       ...
# 1379  CCCS(=O)(=O)Nc1ccc(F)c(C(=O)c2c[nH]c3ncc(cc23)...  Launched
# 1380  CC1(C)CCC(CN2CCN(CC2)c2ccc(C(=O)NS(=O)(=O)c3cc...  Launched
# 1380  CC1(C)CCC(CN2CCN(CC2)c2ccc(C(=O)NS(=O)(=O)c3cc...  Launched
# 1394  ONC(=O)CCCCCCC(=O)Nc1ccccc1, ONC(=O)CCCCCCC(=O...  Launched
# 1394  ONC(=O)CCCCCCC(=O)Nc1ccccc1, ONC(=O)CCCCCCC(=O...  Launched
#
#            drugid       cid                     inchikey
# 33    Abiraterone   9821849  GZOSMCIZMLWJML-VJLLXTKPSA-N
# 33    Abiraterone   9821849  GZOSMCIZMLWJML-VJLLXTKPSA-N
# 54       Afatinib  10184653  ULXXDDBFHOBEHA-CWDCEQMOSA-N
# 54       Afatinib  10184653  ULXXDDBFHOBEHA-CWDCEQMOSA-N
# 59      Alectinib  49806720                          NaN
# ...           ...       ...                          ...
# 1379  Vemurafenib  42611257  GPXBXXGIAQBQNI-UHFFFAOYSA-N
# 1380   Venetoclax  49846579                          NaN
# 1380   Venetoclax  49846579                          NaN
# 1394   Vorinostat      5311  WAEXFXRVDQXREF-UHFFFAOYSA-N
# 1394   Vorinostat      5311  WAEXFXRVDQXREF-UHFFFAOYSA-N
#
# [62 rows x 13 columns]

# %%
prism_anno_rc=prism_anno_r[~prism_anno_r['broad_id'].duplicated()]

# %%
dict_rename={bid:'PRISM_'+did+'_'+bid for bid,did in zip(prism_anno_rc['broad_id'],prism_anno_rc['PRISM.drugid'])}

# %%
prism_auc_c=prism_auc[prism_auc.index.isin(dict_rename)]
prism_auc_w=prism_auc_c.rename(index=dict_rename).sort_index()

# %% [markdown]
# ## gCSI

# %%
gcsi=pd.read_csv('../data/gCSI2019_pharmacoDB_profiles.tsv',sep='\t')
gcsi['Norm_CellLineName']=[x.split('_')[0] for x in gcsi['Unnamed: 0']]
gcsi['DrugName']=[x.split('_')[1] for x in gcsi['Unnamed: 0']]

# %%
dict_cell_drug_val={}
val='GR_AOC_published'
for idx in gcsi.index:
    cell=gcsi.loc[idx,'Norm_CellLineName']
    drug=gcsi.loc[idx,'DrugName']
    if cell not in dict_cell_drug_val:
        dict_cell_drug_val[cell]={}
    else:
        dict_cell_drug_val[cell][drug]=gcsi.loc[idx,val]

# %%
gcsi_add=pd.DataFrame(dict_cell_drug_val).sort_index().sort_index(axis=1).T
gcsi_add.index=[x.replace('-','').replace(' ','').replace(';','').upper() for x in gcsi_add.index]
gcsi_add
# Out:
#           17-AAG      5-FU    AZ-628  AZD-7762  AZD-8055  Azacitidine  \
# 22RV1        NaN  0.279667  0.166333       NaN       NaN          NaN
# 769P         NaN       NaN       NaN       NaN       NaN     0.171000
# 8305C        NaN       NaN       NaN       NaN       NaN          NaN
# 8505C        NaN       NaN       NaN       NaN       NaN          NaN
# A253         NaN       NaN       NaN       NaN       NaN          NaN
# ...          ...       ...       ...       ...       ...          ...
# WSUDLCL2     NaN       NaN       NaN       NaN       NaN     0.345889
# YAPC         NaN       NaN  0.095444       NaN       NaN     0.302556
# YMB1E        NaN       NaN  0.124333       NaN       NaN     0.374778
# ZR751        NaN       NaN       NaN       NaN       NaN          NaN
# HUH1         NaN       NaN       NaN       NaN       NaN          NaN
#
#           Bortezomib  Bosutinib   CAL-101  CHIR-99021  ...  OligomycinA  \
# 22RV1            NaN        NaN       NaN         NaN  ...          NaN
# 769P             NaN        NaN  0.114333         NaN  ...     0.246111
# 8305C            NaN        NaN  0.149889         NaN  ...     0.574000
# 8505C            NaN        NaN  0.047778         NaN  ...     0.251444
# A253             NaN        NaN       NaN         NaN  ...          NaN
# ...              ...        ...       ...         ...  ...          ...
# WSUDLCL2         NaN        NaN  0.222667         NaN  ...     0.124222
# YAPC             NaN        NaN  0.048444         NaN  ...     0.482000
# YMB1E            NaN        NaN  0.251778         NaN  ...     0.607556
# ZR751            NaN        NaN       NaN         NaN  ...          NaN
# HUH1             NaN        NaN  0.098444         NaN  ...     0.657333
#
#           PF-4708671  PLX-4720  Paclitaxel  Palbociclib   TGX-221  Tivantinib  \
# 22RV1       0.014222       NaN         NaN          NaN       NaN         NaN
# 769P             NaN       NaN    0.437667     0.064444  0.156000    0.413333
# 8305C            NaN       NaN    0.652556          NaN       NaN    0.732333
# 8505C            NaN       NaN    0.558333          NaN       NaN    0.391000
# A253             NaN       NaN         NaN          NaN       NaN         NaN
# ...              ...       ...         ...          ...       ...         ...
# WSUDLCL2         NaN       NaN    1.016444     0.132333  0.062889    0.674444
# YAPC        0.077778       NaN    0.275556     0.069000       NaN    0.333000
# YMB1E       0.115222       NaN    0.310111     0.140000  0.620667    0.516222
# ZR751       0.220778       NaN         NaN          NaN       NaN         NaN
# HUH1             NaN       NaN    0.443000          NaN       NaN    0.460444
#
#           Vinblastine  Vincristine  Vorinostat
# 22RV1             NaN          NaN         NaN
# 769P         0.152444    -0.034000    0.140556
# 8305C             NaN     0.159778    0.465000
# 8505C             NaN     0.143000    0.340333
# A253              NaN          NaN         NaN
# ...               ...          ...         ...
# WSUDLCL2     0.465000     0.568667    0.777667
# YAPC              NaN     0.104222    0.066111
# YMB1E             NaN     0.190889    0.258444
# ZR751             NaN          NaN         NaN
# HUH1              NaN     0.065778    0.279667
#
# [569 rows x 44 columns]

# %%
gcsi_anno=pd.read_csv('../data/gCSI2019_drug_info.txt'
                     ,sep='\t',index_col=0)
gcsi_anno=gcsi_anno[~gcsi_anno['cid'].isna()]
gcsi_anno['cid']=gcsi_anno['cid'].astype(int).astype(str)
sorted(gcsi_anno['drugid'])
# Out:
# ['5-Fluorouracil',
#  'AZ-628',
#  'AZD7762',
#  'AZD8055',
#  'Azacitidine',
#  'Bortezomib',
#  'Bosutinib',
#  'Chir-99021',
#  'Cisplatin',
#  'Crizotinib',
#  'Dabrafenib',
#  'Dasatinib',
#  'Docetaxel',
#  'Erastin',
#  'Erlotinib',
#  'Etoposide',
#  'GSK2636771',
#  'Gefitinib',
#  'Gemcitabine',
#  'Ibrutinib',
#  'Idelalisib',
#  'JQ1 compound',
#  'Lapatinib',
#  'Lenalidomide',
#  'MI-2',
#  'MK-2206',
#  'MLN2480',
#  'Methotrexate',
#  'NU-7441',
#  'Narciclasine',
#  'Nilotinib',
#  'Oligomycin A',
#  'PF-4708671',
#  'PLX4720',
#  'Paclitaxel',
#  'Palbociclib',
#  'Pictilisib',
#  'TGX221',
#  'Tanespimycin',
#  'Tivantinib',
#  'Vincaleukoblastine',
#  'Vincristine',
#  'Vorinostat']

# %%
dict_for_replace={'5-FU':'5-Fluorouracil','CHIR-99021':'Chir-99021',"JQ1":'JQ1 compound',
                    "NU7441":'NU-7441','PLX-4720':'PLX4720','TGX-221':'TGX221',
                  'AZD-7762':'AZD7762','AZD-8055':'AZD8055','Vinblastine':'Vincaleukoblastine',
                    'OligomycinA':'Oligomycin A','17-AAG':'Tanespimycin'}

# %%
gcsi_add=gcsi_add.rename(columns=dict_for_replace)

# %%
dict_name_cid={k:str(int(v)) for k,v in zip(gcsi_anno['drugid'],gcsi_anno['cid'])}

# %%
gcsi_add=gcsi_add.loc[:,gcsi_add.columns.isin(dict_name_cid)]

# %%
gcsi_add.columns=['gCSI_'+x+"_CID"+dict_name_cid[x] for x in gcsi_add.columns]
gcsi_add
# Out:
#           gCSI_Tanespimycin_CID6505803  gCSI_5-Fluorouracil_CID3385  \
# 22RV1                              NaN                     0.279667
# 769P                               NaN                          NaN
# 8305C                              NaN                          NaN
# 8505C                              NaN                          NaN
# A253                               NaN                          NaN
# ...                                ...                          ...
# WSUDLCL2                           NaN                          NaN
# YAPC                               NaN                          NaN
# YMB1E                              NaN                          NaN
# ZR751                              NaN                          NaN
# HUH1                               NaN                          NaN
#
#           gCSI_AZ-628_CID11676786  gCSI_AZD7762_CID11152667  \
# 22RV1                    0.166333                       NaN
# 769P                          NaN                       NaN
# 8305C                         NaN                       NaN
# 8505C                         NaN                       NaN
# A253                          NaN                       NaN
# ...                           ...                       ...
# WSUDLCL2                      NaN                       NaN
# YAPC                     0.095444                       NaN
# YMB1E                    0.124333                       NaN
# ZR751                         NaN                       NaN
# HUH1                          NaN                       NaN
#
#           gCSI_AZD8055_CID25262965  gCSI_Azacitidine_CID9444  \
# 22RV1                          NaN                       NaN
# 769P                           NaN                  0.171000
# 8305C                          NaN                       NaN
# 8505C                          NaN                       NaN
# A253                           NaN                       NaN
# ...                            ...                       ...
# WSUDLCL2                       NaN                  0.345889
# YAPC                           NaN                  0.302556
# YMB1E                          NaN                  0.374778
# ZR751                          NaN                       NaN
# HUH1                           NaN                       NaN
#
#           gCSI_Bortezomib_CID387447  gCSI_Bosutinib_CID5328940  \
# 22RV1                           NaN                        NaN
# 769P                            NaN                        NaN
# 8305C                           NaN                        NaN
# 8505C                           NaN                        NaN
# A253                            NaN                        NaN
# ...                             ...                        ...
# WSUDLCL2                        NaN                        NaN
# YAPC                            NaN                        NaN
# YMB1E                           NaN                        NaN
# ZR751                           NaN                        NaN
# HUH1                            NaN                        NaN
#
#           gCSI_Chir-99021_CID9956119  gCSI_Cisplatin_CID24191118  ...  \
# 22RV1                            NaN                    0.428333  ...
# 769P                             NaN                         NaN  ...
# 8305C                            NaN                         NaN  ...
# 8505C                            NaN                         NaN  ...
# A253                             NaN                         NaN  ...
# ...                              ...                         ...  ...
# WSUDLCL2                         NaN                         NaN  ...
# YAPC                             NaN                    0.082000  ...
# YMB1E                            NaN                    0.045778  ...
# ZR751                            NaN                   -0.053333  ...
# HUH1                             NaN                         NaN  ...
#
#           gCSI_Oligomycin A_CID5472285  gCSI_PF-4708671_CID51371303  \
# 22RV1                              NaN                     0.014222
# 769P                          0.246111                          NaN
# 8305C                         0.574000                          NaN
# 8505C                         0.251444                          NaN
# A253                               NaN                          NaN
# ...                                ...                          ...
# WSUDLCL2                      0.124222                          NaN
# YAPC                          0.482000                     0.077778
# YMB1E                         0.607556                     0.115222
# ZR751                              NaN                     0.220778
# HUH1                          0.657333                          NaN
#
#           gCSI_PLX4720_CID24180719  gCSI_Paclitaxel_CID36314  \
# 22RV1                          NaN                       NaN
# 769P                           NaN                  0.437667
# 8305C                          NaN                  0.652556
# 8505C                          NaN                  0.558333
# A253                           NaN                       NaN
# ...                            ...                       ...
# WSUDLCL2                       NaN                  1.016444
# YAPC                           NaN                  0.275556
# YMB1E                          NaN                  0.310111
# ZR751                          NaN                       NaN
# HUH1                           NaN                  0.443000
#
#           gCSI_Palbociclib_CID5330286  gCSI_TGX221_CID9907093  \
# 22RV1                             NaN                     NaN
# 769P                         0.064444                0.156000
# 8305C                             NaN                     NaN
# 8505C                             NaN                     NaN
# A253                              NaN                     NaN
# ...                               ...                     ...
# WSUDLCL2                     0.132333                0.062889
# YAPC                         0.069000                     NaN
# YMB1E                        0.140000                0.620667
# ZR751                             NaN                     NaN
# HUH1                              NaN                     NaN
#
#           gCSI_Tivantinib_CID11494412  gCSI_Vincaleukoblastine_CID241902  \
# 22RV1                             NaN                                NaN
# 769P                         0.413333                           0.152444
# 8305C                        0.732333                                NaN
# 8505C                        0.391000                                NaN
# A253                              NaN                                NaN
# ...                               ...                                ...
# WSUDLCL2                     0.674444                           0.465000
# YAPC                         0.333000                                NaN
# YMB1E                        0.516222                                NaN
# ZR751                             NaN                                NaN
# HUH1                         0.460444                                NaN
#
#           gCSI_Vincristine_CID5978  gCSI_Vorinostat_CID5311
# 22RV1                          NaN                      NaN
# 769P                     -0.034000                 0.140556
# 8305C                     0.159778                 0.465000
# 8505C                     0.143000                 0.340333
# A253                           NaN                      NaN
# ...                            ...                      ...
# WSUDLCL2                  0.568667                 0.777667
# YAPC                      0.104222                 0.066111
# YMB1E                     0.190889                 0.258444
# ZR751                          NaN                      NaN
# HUH1                      0.065778                 0.279667
#
# [569 rows x 41 columns]

# %% [markdown]
# ## Write out

# %%
print(gdsc1_add.shape)
print(gdsc2_add.shape)
print(ctrp2_auc_sel.shape)
print(ctrp1_auc_sel.shape)
print(prism_auc_w.shape)
print(gcsi_add.shape)
# Out:
# (987, 240)
# (809, 166)
# (173, 887)
# (90, 242)
# (172, 481)
# (569, 41)

# %%
gdsc1_add.to_csv('../intermediate/GDSC1_AUC_selected.txt',sep='\t')
gdsc2_add.to_csv('../intermediate/GDSC2_AUC_selected.txt',sep='\t')
ctrp1_auc_sel.T.to_csv('../intermediate/CTRP1_AUC_FDA_clinical_selected.txt',sep='\t')
ctrp2_auc_sel.T.to_csv('../intermediate/CTRP2_AUC_FDA_clinical_selected.txt',sep='\t')
prism_auc_w.T.to_csv('../intermediate/PRISM_AUC_oncology_selected.txt',sep='\t')
gcsi_add.to_csv('../intermediate/gCSI_GR_AOC_selected.txt',sep='\t')

# %%
ctrp1_info_sel['pubchem_cid'].astype(int)
# Out:
# 8        439268
# 21     11228183
# 22      3035714
# 30         2244
# 31       444795
#          ...
# 342    11960529
# 344    24776445
# 345        5311
# 350    10126189
# 352       60490
# Name: pubchem_cid, Length: 90, dtype: int64

# %%
cids= set(gdsc1_drug_sel['pubchem'].astype(int))|set(gdsc2_drug_sel['pubchem'].astype(int))|set(ctrp2_info_sel['cid'].astype(int))|\
set(prism_anno['cid'].astype(int))|set(gcsi_anno['cid'].astype(int))|set(ctrp1_info_sel['pubchem_cid'].astype(int))
cids=sorted(cids)[1:]
with open('../intermediate//'+'All_cids.csv','w') as fw:
    fw.write( '\n'.join(list(map(str,cids)))+'\n' )

# %% [markdown]
# * this file is converted by Pubchem website, https://pubchem.ncbi.nlm.nih.gov/#upload=true
# to "All_cids_from_pubchem.csv"

# %% [markdown]
# # Drug categorization

# %% [markdown]
# ## GDSC

# %%
pubchem=pd.read_csv('../intermediate/All_cids_converted_from_pubchem.csv')
dict_cid_name={k:v for k,v in zip(pubchem['cid'],pubchem['cmpdname'])}
pubchem['cmpdname'].duplicated().sum()
# Out:
# 0

# %%
counter=Counter(gdsc1_drug_sel['pathway_name']).most_common()
a=[x[0] for x in counter]
counter
# Out:
# [('Other', 32),
#  ('Other, kinases', 27),
#  ('RTK signaling', 26),
#  ('PI3K/MTOR signaling', 23),
#  ('ERK MAPK signaling', 17),
#  ('DNA replication', 12),
#  ('Cell cycle', 12),
#  ('Mitosis', 11),
#  ('Chromatin histone acetylation', 10),
#  ('Protein stability and degradation', 8),
#  ('Genome integrity', 8),
#  ('EGFR signaling', 7),
#  ('Cytoskeleton', 7),
#  ('Chromatin other', 6),
#  ('JNK and p38 signaling', 6),
#  ('Apoptosis regulation', 6),
#  ('Metabolism', 5),
#  ('WNT signaling', 4),
#  ('Hormone-related', 3),
#  ('IGF1R signaling', 3),
#  ('Chromatin histone methylation', 3),
#  ('p53 pathway', 3),
#  ('ABL signaling', 2)]

# %%
Counter(gdsc2_drug_sel['pathway_name']).most_common()
# Out:
# [('PI3K/MTOR signaling', 21),
#  ('DNA replication', 20),
#  ('Other', 17),
#  ('Other, kinases', 14),
#  ('Genome integrity', 13),
#  ('ERK MAPK signaling', 13),
#  ('Apoptosis regulation', 12),
#  ('RTK signaling', 11),
#  ('Cell cycle', 10),
#  ('WNT signaling', 9),
#  ('Protein stability and degradation', 9),
#  ('Mitosis', 8),
#  ('EGFR signaling', 7),
#  ('Chromatin histone methylation', 7),
#  ('Chromatin other', 7),
#  ('Hormone-related', 5),
#  ('Metabolism', 4),
#  ('IGF1R signaling', 4),
#  ('Chromatin histone acetylation', 4),
#  ('p53 pathway', 4),
#  ('-', 2),
#  ('JNK and p38 signaling', 2),
#  ('Cytoskeleton', 2),
#  ('ABL signaling', 1)]

# %%
Counter(gdsc1_drug_sel['targets']).most_common()
# Out:
# [('MEK1, MEK2', 7),
#  ('BRAF', 6),
#  ('HSP90', 5),
#  ('PARP1, PARP2', 5),
#  ('AKT1, AKT2, AKT3', 4),
#  ('EGFR', 4),
#  ('IGF1R, IR', 4),
#  ('HDAC1', 4),
#  ('EGFR, ERBB2', 3),
#  ('Microtubule stabiliser', 3),
#  ('GSK3A, GSK3B', 3),
#  ('PI3K (class 1)', 3),
#  ('ROCK1, ROCK2', 3),
#  ('AR', 2),
#  ('Antimetabolite', 2),
#  ('dsDNA break induction', 2),
#  ('CDC7', 2),
#  ('MTORC1, MTORC2', 2),
#  ('G9a and GLP methyltransferases', 2),
#  ('Microtubule destabiliser', 2),
#  ('MTOR', 2),
#  ('PDK1 (PDPK1)', 2),
#  ('Amyloid beta20, Amyloid beta40', 2),
#  ('Farnesyl-transferase (FNTA)', 2),
#  ('MDM2', 2),
#  ('SMO', 2),
#  ('ATM', 2),
#  ('PI3K (class 1), MTORC1, MTORC2', 2),
#  ('ALK', 2),
#  ('BRD2, BRD3, BRD4, BRDT', 2),
#  ('DNA crosslinker', 2),
#  ('PI3Kbeta', 2),
#  ('SRC, ABL, TEC', 1),
#  ('PDGFR, KIT, VEGFR', 1),
#  ('MET', 1),
#  ('PKC, PPK, FLT1, c-FGR, others', 1),
#  ('PB1, SMARCA4, SMARCA2', 1),
#  ('JNK2, JNK3', 1),
#  ('IGF1R', 1),
#  ('BTK', 1),
#  ('IKK1, IKK2', 1),
#  ('JAK1, JAK2', 1),
#  ('JNK1, JNK2, JNK2', 1),
#  ('PI3Kgamma', 1),
#  ('ERK5, BET', 1),
#  ('ERK5', 1),
#  ('EPHB4, RAF, SRC, ABL', 1),
#  ('CDK9', 1),
#  ('PIK3CB', 1),
#  ('Pyrimidine antimetabolite', 1),
#  ('DNA alkylating agent', 1),
#  ('AMPK agonist', 1),
#  ('HDAC inhibitor Class I, IIa, IIb, IV', 1),
#  ('LCK, FYN', 1),
#  ('Dihydrofolate reductase (DHFR)', 1),
#  ('AURKA, AURKB', 1),
#  ('PAK1', 1),
#  ('SYK', 1),
#  ('CSF1R, KIT,  PDGFRA, PDGFRB', 1),
#  ('KSP', 1),
#  ('PKCB', 1),
#  ('HDAC1, HDAC6', 1),
#  ('VEGFR1, VEGFR2, VEGFR3, CSF1R, FLT3, KIT', 1),
#  ('PK3CG', 1),
#  ('MET, ALK, ROS1', 1),
#  ('NAMPT', 1),
#  ('TNKS1, TNKS2', 1),
#  ('NTRK1', 1),
#  ('p38', 1),
#  ('VEGFR, RET, KIT, PDGFR', 1),
#  ('DNAPK', 1),
#  ('SRC, LCK', 1),
#  ('ABL, PDGFRA, VEGFR2, FGFR1, SRC, TIE2, FLT3', 1),
#  ('PKC', 1),
#  ('EIF2A', 1),
#  ('MDM4', 1),
#  ('JAK3', 1),
#  ('PI3Kalpha, DAPK3, CLK4, PIM3, HIPK2', 1),
#  ('ABL, SRC, Ephrins, PDGFR, KIT', 1),
#  ('BCR-ABL', 1),
#  ('RAC1, RAC2, RAC3', 1),
#  ('TGFBR1, ACVR1B, ACVR1C', 1),
#  ('EGLN1', 1),
#  ('RNA helicase A', 1),
#  ('CHEK1, CHEK2', 1),
#  ('TBK1, PDK1 (PDPK1), IKK, AURKB, AURKC', 1),
#  ('PLK1, PLK2, PLK3', 1),
#  ('ITK', 1),
#  ('Proteasome, CAPN1', 1),
#  ('JNK', 1),
#  ('HIF-PH', 1),
#  ('PPARgamma, PPARdelta', 1),
#  ('BCL2, BCL-XL, BCL-W, MCL1', 1),
#  ('Biguanide agent', 1),
#  ('ERBB2', 1),
#  ('Autophagy inducer', 1),
#  ('MEK5, ERK5', 1),
#  ('RNA Polymerase 1', 1),
#  ('MET, KDR, TIE2, VEGFR3/FLT4, RON, PDGFR, FGFR1, EGFR', 1),
#  ('PDGFR, KIT, VEGFR, FLT3, RET, CSF1R', 1),
#  ('TAK1', 1),
#  ('Induces reactive oxygen species', 1),
#  ('L3MBTL3', 1),
#  ('Anthracycline', 1),
#  ('SHP-1 (PTPN6), SHP-2 (PTPN11)', 1),
#  ('BCL2, BCL-XL, BCL-W', 1),
#  ('FLT3, JAK2, NTRK1, NTRK2, NTRK3', 1),
#  ('BMX', 1),
#  ('WEE1, CHEK1', 1),
#  ('FAK, FAK2', 1),
#  ('p38alpha, p38beta', 1),
#  ('PI3Kdelta', 1),
#  ('VEGFR, MET, RET, KIT, FLT1, FLT3, FLT4, TIE2,AXL', 1),
#  ('FLT3', 1),
#  ('ERK2', 1),
#  ('KIT, VEGFR2', 1),
#  ('VEGFR1, VEGFR2, VEGFR3, PDGFR, KIT', 1),
#  ('LXR, FXR', 1),
#  ('ABL, KIT, PDGFR', 1),
#  ('ABL, SRC', 1),
#  ('BCL2, BCL-XL, MCL1', 1),
#  ('BRD4', 1),
#  ('DOT1L', 1),
#  ('TOP2', 1),
#  ('ARFGAP1', 1),
#  ('NAE', 1),
#  ('Retinoic acid', 1),
#  ('ABL', 1),
#  ('RSK, AURKB, PIM1, PIM3', 1),
#  ('SERCA', 1),
#  ('CSF1R', 1),
#  ('CDK1, CDK2, CDK4, CDK6, CDK9', 1),
#  ('AURKA, AURKC', 1),
#  ('BIRC5', 1),
#  ('CDK2, CDK7, CDK5', 1),
#  ('ALK5', 1),
#  ('JAK2', 1),
#  ('MTORC1', 1),
#  ('PDGFR, KIT, VEGFR, RAF', 1),
#  ('KIF11', 1),
#  ('CDK1,CDK2,CDK5,CDK7,CDK9, PKC', 1),
#  ('CDK4', 1),
#  ('PPM1D', 1),
#  ('ESR1', 1),
#  ('CRBN', 1),
#  ('RSK2', 1),
#  ('PLK1', 1),
#  ('XIAP', 1),
#  ('SGK2, SGK3', 1),
#  ('TAK1, M4K2', 1),
#  ('Proteasome', 1),
#  ('CDK2, CDK7, CDK9', 1),
#  ('Endothelin-1 receptor (EDNRA)', 1),
#  ('HDAC,RAR', 1),
#  ('BRD2, BRD3, BRD4', 1),
#  ('HDAC1-10, EGFR, ERBB2', 1),
#  ('PDK1', 1),
#  ('KIT, PDGFRA, PDGFRB', 1),
#  ('KIT, PDGFRA, FLT3', 1),
#  ('IKK2', 1),
#  ('ROCK', 1),
#  ('PIKFYVE', 1),
#  ('SIRT1', 1),
#  ('AURKA, AURKB, AURKC, others', 1),
#  ('gamma-secretase', 1),
#  ('CDK1', 1),
#  ('AKT1, AKT2', 1),
#  ('CDK4, CDK6', 1),
#  ('S6K1', 1),
#  ('TOP1', 1),
#  ('HDAC1, HDAC3', 1),
#  ('IKK', 1),
#  ('p38, JNK2', 1),
#  ('FGFR1, FGFR2, FGFR3', 1),
#  ('not defined', 1),
#  ('Procaspase-3, Procaspase-7', 1),
#  ('Antimetabolite (DNA & RNA)', 1),
#  ('Retinioic X receptor (RXR) agonist', 1),
#  ('ERK1, ERK2', 1),
#  ('HDAC1, HDAC6, HDAC8', 1),
#  ('MPS1', 1)]

# %%
drug_anno=[]
for idx in gdsc1_drug_sel.index:
    name=gdsc1_drug_sel.loc[idx,'drug_name']
    pathway=gdsc1_drug_sel.loc[idx,'pathway_name']
    target=gdsc1_drug_sel.loc[idx,'targets']
    if 'platin' in name:
        drug_anno.append('Platinum')
    elif 'parib' in name:
        drug_anno.append('PARP inhibitor')
    elif 'Microtubule' in target:
        drug_anno.append('Antimicrotubule')
    elif 'Pyrimidine synthesis inhibitor' in target:
        drug_anno.append('Antimetabolite')
    elif 'Alkylating agent' in target:
        drug_anno.append('DNA alkylator')
    elif 'Anthracycline'  in target:
        drug_anno.append('DNA inhibitor')
    elif 'Pyrimidine antimetabolite' in target:
        drug_anno.append('Antimetabolite')
    elif 'Antimetabolite' in target:
        drug_anno.append('Antimetabolite')
    elif 'Anti-metabolite' in target:
        drug_anno.append('Antimetabolite')
    elif 'Dihydrofolate reductase (DHFR)' in target:
        drug_anno.append('Antimetabolite')
    elif 'DNA crosslinker' in target:
        drug_anno.append('DNA alkylator')
    elif 'dsDNA break induction' in target:
        drug_anno.append('DNA inhibitor')
    elif 'DNA replication' in pathway:
        drug_anno.append('DNA inhibitor')
    elif 'DNA alkylating agent' in target:
        drug_anno.append('DNA alkylator')
    elif 'PARP' in target:
        drug_anno.append('PARP inhibitor')
    elif 'TOP' in target:
        drug_anno.append('Topoisomerase inhibitor') 
    elif name in ['Fludarabine','Nelarabine','Dactinomycin','Mitoxantrone',
                 'Teniposide']:
        drug_anno.append('DNA inhibitor')
    elif name in ['Carmustine']:
        drug_anno.append('DNA alkylator')
    elif pathway in ['ERK MAPK signaling','RTK signaling', 'PI3K/MTOR signaling','Cell cycle',
                    'WNT signaling','Protein stability and degradation','WNT signaling',
                     'EGFR signaling','JNK and p38 signaling','p53 pathway','Hormone-related',
                    'Apoptosis regulation','Cytoskeleton','Metabolism','Metabolism',
                     'IGF1R signaling','Genome integrity']:
        drug_anno.append(pathway)
    elif pathway in ['Chromatin histone acetylation','Chromatin histone methylation',
                     'Chromatin other',]:
        drug_anno.append('Chromatin-related')
    elif pathway in ['ABL signaling','Mitosis','IGF1R signaling',]:
        drug_anno.append('Others')   
    else:
        drug_anno.append('Others')
Counter(drug_anno).most_common()
# Out:
# [('Others', 64),
#  ('RTK signaling', 26),
#  ('PI3K/MTOR signaling', 23),
#  ('Chromatin-related', 19),
#  ('ERK MAPK signaling', 17),
#  ('Cell cycle', 12),
#  ('Protein stability and degradation', 8),
#  ('DNA inhibitor', 8),
#  ('EGFR signaling', 7),
#  ('Cytoskeleton', 7),
#  ('JNK and p38 signaling', 6),
#  ('Apoptosis regulation', 6),
#  ('PARP inhibitor', 5),
#  ('Antimetabolite', 5),
#  ('Antimicrotubule', 5),
#  ('Metabolism', 5),
#  ('WNT signaling', 4),
#  ('Hormone-related', 3),
#  ('IGF1R signaling', 3),
#  ('Genome integrity', 3),
#  ('p53 pathway', 3),
#  ('Platinum', 1),
#  ('DNA alkylator', 1)]

# %%
gdsc1_drug_sel['drug_anno']=drug_anno
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_13085/1794871316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdsc1_drug_sel['drug_anno']=drug_anno

# %%
drug_anno=[]
for idx in gdsc2_drug_sel.index:
    name=gdsc2_drug_sel.loc[idx,'drug_name']
    pathway=gdsc2_drug_sel.loc[idx,'pathway_name']
    target=gdsc2_drug_sel.loc[idx,'targets']
    if 'platin' in name:
        drug_anno.append('Platinum')
    elif 'parib' in name:
        drug_anno.append('PARP inhibitor')
    elif name in ['Irinotecan']:
        drug_anno.append('Topoisomerase inhibitor')
    elif 'Microtubule' in target:
        drug_anno.append('Antimicrotubule')
    elif 'Pyrimidine synthesis inhibitor' in target:
        drug_anno.append('Antimetabolite')
    elif 'Alkylating agent' in target:
        drug_anno.append('DNA alkylator')
    elif 'Anthracycline'  in target:
        drug_anno.append('DNA inhibitor')
    elif 'Pyrimidine antimetabolite' in target:
        drug_anno.append('Antimetabolite')
    elif 'Antimetabolite' in target:
        drug_anno.append('Antimetabolite')
    elif 'Anti-metabolite' in target:
        drug_anno.append('Antimetabolite')
    elif 'Dihydrofolate reductase (DHFR)' in target:
        drug_anno.append('Antimetabolite')
    elif 'DNA crosslinker' in target:
        drug_anno.append('DNA alkylator')
    elif 'dsDNA break induction' in target:
        drug_anno.append('DNA inhibitor')
    elif 'DNA replication' in pathway:
        drug_anno.append('DNA inhibitor')
    elif 'DNA alkylating agent' in target:
        drug_anno.append('DNA alkylator')
    elif 'PARP' in target:
        drug_anno.append('PARP inhibitor')
    elif name in ['Fludarabine','Nelarabine','Dactinomycin','Mitoxantrone',
                 'Teniposide']:
        drug_anno.append('DNA inhibitor')
    elif name in ['Carmustine']:
        drug_anno.append('DNA alkylator')
    elif pathway in ['ERK MAPK signaling','RTK signaling', 'PI3K/MTOR signaling','Cell cycle',
                    'WNT signaling','Protein stability and degradation','WNT signaling',
                     'EGFR signaling','JNK and p38 signaling','p53 pathway','Hormone-related',
                    'Apoptosis regulation','Cytoskeleton','Metabolism','Metabolism',
                     'IGF1R signaling','Genome integrity']:
        drug_anno.append(pathway)
    elif pathway in ['Chromatin histone acetylation','Chromatin histone methylation',
                     'Chromatin other',]:
        drug_anno.append('Chromatin-related')
    elif pathway in ['ABL signaling','Mitosis','IGF1R signaling',]:
        drug_anno.append('Others')   
    else:
        drug_anno.append('Others')
Counter(drug_anno).most_common()
# Out:
# [('Others', 32),
#  ('PI3K/MTOR signaling', 21),
#  ('Chromatin-related', 18),
#  ('DNA inhibitor', 13),
#  ('ERK MAPK signaling', 13),
#  ('Apoptosis regulation', 12),
#  ('RTK signaling', 11),
#  ('Cell cycle', 10),
#  ('WNT signaling', 9),
#  ('Protein stability and degradation', 9),
#  ('Genome integrity', 8),
#  ('EGFR signaling', 7),
#  ('Antimetabolite', 6),
#  ('Hormone-related', 5),
#  ('Antimicrotubule', 5),
#  ('PARP inhibitor', 5),
#  ('Metabolism', 4),
#  ('IGF1R signaling', 4),
#  ('p53 pathway', 4),
#  ('Platinum', 3),
#  ('DNA alkylator', 2),
#  ('JNK and p38 signaling', 2),
#  ('Cytoskeleton', 2),
#  ('Topoisomerase inhibitor', 1)]

# %%
gdsc2_drug_sel['drug_anno']=drug_anno
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_13085/2036774952.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdsc2_drug_sel['drug_anno']=drug_anno

# %%
dict_cid_anno={int(k):v for k,v in zip(gdsc1_drug_sel['pubchem'],gdsc1_drug_sel['drug_anno'])}
for idx in gdsc2_drug_sel.index:
    k=int(gdsc2_drug_sel.loc[idx,'pubchem'])
    v=gdsc2_drug_sel.loc[idx,'drug_anno']
    dict_cid_anno[k]=v

# %%
dict_cid_anno
# Out:
# {5327091: 'Protein stability and degradation',
#  44819241: 'PARP inhibitor',
#  11707110: 'ERK MAPK signaling',
#  10184653: 'EGFR signaling',
#  2375: 'Hormone-related',
#  126941: 'Antimetabolite',
#  23725625: 'PARP inhibitor',
#  5328940: 'Others',
#  6450551: 'RTK signaling',
#  10461815: 'RTK signaling',
#  9829523: 'Others',
#  78243717: 'Chromatin-related',
#  25222038: 'JNK and p38 signaling',
#  11640390: 'IGF1R signaling',
#  5360373: 'DNA inhibitor',
#  54676905: 'Others',
#  9813758: 'Others',
#  25126798: 'Others',
#  10109823: 'JNK and p38 signaling',
#  5289247: 'PI3K/MTOR signaling',
#  46844147: 'Others',
#  46843772: 'ERK MAPK signaling',
#  10451420: 'DNA inhibitor',
#  16747388: 'Others',
#  16725726: 'PI3K/MTOR signaling',
#  66577006: 'Others',
#  25262965: 'PI3K/MTOR signaling',
#  44137675: 'PI3K/MTOR signaling',
#  46224516: 'Chromatin-related',
#  60750: 'Antimetabolite',
#  5394: 'DNA inhibitor',
#  5311497: 'Antimicrotubule',
#  10127622: 'ERK MAPK signaling',
#  65110: 'Metabolism',
#  148124: 'Antimicrotubule',
#  5311: 'Chromatin-related',
#  6918289: 'PI3K/MTOR signaling',
#  9549184: 'Others',
#  4993: 'Antimetabolite',
#  9914412: 'Others',
#  10027278: 'Metabolism',
#  521106: 'Cytoskeleton',
#  10200390: 'Others',
#  10113978: 'RTK signaling',
#  6450816: 'Others',
#  176167: 'Others',
#  24951314: 'Chromatin-related',
#  11485656: 'RTK signaling',
#  6852167: 'PI3K/MTOR signaling',
#  11626560: 'RTK signaling',
#  46883536: 'Others',
#  85668777: 'EGFR signaling',
#  9956119: 'WNT signaling',
#  6914657: 'Metabolism',
#  2726824: 'WNT signaling',
#  6710780: 'Antimicrotubule',
#  123631: 'EGFR signaling',
#  9943465: 'RTK signaling',
#  176158: 'WNT signaling',
#  10341154: 'JNK and p38 signaling',
#  11667893: 'RTK signaling',
#  300471: 'Protein stability and degradation',
#  11327430: 'Genome integrity',
#  11844351: 'Others',
#  49836027: 'PI3K/MTOR signaling',
#  24826799: 'Others',
#  3005532: 'Others',
#  10196499: 'PI3K/MTOR signaling',
#  24785538: 'RTK signaling',
#  5280757: 'Others',
#  11754511: 'Metabolism',
#  36314: 'Antimicrotubule',
#  5717801: 'Others',
#  208908: 'EGFR signaling',
#  42640: 'p53 pathway',
#  3796: 'Others',
#  9884685: 'Others',
#  3062316: 'Others',
#  5311510: 'Others',
#  17755052: 'PI3K/MTOR signaling',
#  9938202: 'Cytoskeleton',
#  11609586: 'p53 pathway',
#  9858940: 'RTK signaling',
#  54685215: 'Others',
#  44632017: 'Others',
#  5460769: 'DNA inhibitor',
#  11152667: 'Cell cycle',
#  24776445: 'Others',
#  10077147: 'Others',
#  11364421: 'Cell cycle',
#  20635522: 'Others',
#  462382: 'Protein stability and degradation',
#  11624601: 'JNK and p38 signaling',
#  560326: 'Metabolism',
#  3463933: 'Others',
#  11404337: 'Apoptosis regulation',
#  8249: 'Others',
#  9874913: 'EGFR signaling',
#  704473: 'Others',
#  6918848: 'Chromatin-related',
#  46931012: 'ERK MAPK signaling',
#  6445562: 'EGFR signaling',
#  25257557: 'Others',
#  42642645: 'RTK signaling',
#  442972: 'Others',
#  5329102: 'RTK signaling',
#  9863776: 'Others',
#  637858: 'Others',
#  57339144: 'Chromatin-related',
#  31703: 'DNA inhibitor',
#  5459322: 'Others',
#  44551660: 'Genome integrity',
#  176870: 'EGFR signaling',
#  24978538: 'Apoptosis regulation',
#  44182295: 'ERK MAPK signaling',
#  126565: 'Others',
#  49821040: 'Others',
#  10384072: 'Cell cycle',
#  11713159: 'Cytoskeleton',
#  25124816: 'IGF1R signaling',
#  9952773: 'JNK and p38 signaling',
#  11625818: 'PI3K/MTOR signaling',
#  25102847: 'RTK signaling',
#  24889392: 'RTK signaling',
#  11634725: 'ERK MAPK signaling',
#  25167777: 'PI3K/MTOR signaling',
#  9868037: 'RTK signaling',
#  44224160: 'PI3K/MTOR signaling',
#  9911830: 'RTK signaling',
#  24772860: 'Protein stability and degradation',
#  447912: 'Others',
#  16095342: 'Cytoskeleton',
#  5291: 'Others',
#  10302451: 'Others',
#  11977753: 'PI3K/MTOR signaling',
#  11316960: 'ERK MAPK signaling',
#  10390396: 'IGF1R signaling',
#  11455910: 'Apoptosis regulation',
#  9931953: 'PARP inhibitor',
#  71271629: 'Chromatin-related',
#  56962337: 'Chromatin-related',
#  36462: 'DNA inhibitor',
#  44462760: 'ERK MAPK signaling',
#  4263900: 'Others',
#  16720766: 'Others',
#  444795: 'Others',
#  644241: 'Others',
#  24180719: 'ERK MAPK signaling',
#  10459196: 'Others',
#  7251185: 'Chromatin-related',
#  53302361: 'ERK MAPK signaling',
#  446378: 'Others',
#  11617559: 'RTK signaling',
#  11338033: 'Cell cycle',
#  11647372: 'PI3K/MTOR signaling',
#  46885626: 'Others',
#  11178236: 'Apoptosis regulation',
#  49806720: 'RTK signaling',
#  46191454: 'Cell cycle',
#  9967941: 'RTK signaling',
#  16722836: 'Others',
#  11676786: 'ERK MAPK signaling',
#  5384616: 'PI3K/MTOR signaling',
#  216239: 'Others',
#  76044: 'Others',
#  644215: 'Cell cycle',
#  24825971: 'Cell cycle',
#  2314623: 'Cell cycle',
#  2733526: 'Hormone-related',
#  46907787: 'Chromatin-related',
#  84691: 'Platinum',
#  6253: 'Antimetabolite',
#  6918454: 'ERK MAPK signaling',
#  11960529: 'PARP inhibitor',
#  216326: 'Protein stability and degradation',
#  6505803: 'Protein stability and degradation',
#  16663089: 'Others',
#  10172943: 'PI3K/MTOR signaling',
#  9826308: 'Cell cycle',
#  9907093: 'PI3K/MTOR signaling',
#  11433190: 'p53 pathway',
#  3218: 'Apoptosis regulation',
#  25022668: 'Others',
#  10096043: 'Protein stability and degradation',
#  448013: 'Antimicrotubule',
#  53340664: 'Others',
#  387447: 'Protein stability and degradation',
#  160355: 'Cell cycle',
#  9910224: 'Others',
#  24894414: 'Chromatin-related',
#  6918638: 'Chromatin-related',
#  46943432: 'Chromatin-related',
#  24756910: 'Others',
#  56965967: 'Others',
#  10074640: 'RTK signaling',
#  11282283: 'RTK signaling',
#  9903786: 'Others',
#  9810884: 'Cytoskeleton',
#  9956222: 'PI3K/MTOR signaling',
#  5113032: 'Chromatin-related',
#  5494449: 'Others',
#  16760646: 'Others',
#  44450571: 'Cell cycle',
#  46930998: 'PI3K/MTOR signaling',
#  5330286: 'Cell cycle',
#  9826528: 'ERK MAPK signaling',
#  51371303: 'PI3K/MTOR signaling',
#  5746: 'DNA alkylator',
#  104842: 'DNA inhibitor',
#  5278396: 'Genome integrity',
#  4261: 'Chromatin-related',
#  11626927: 'Others',
#  156422: 'JNK and p38 signaling',
#  1401: 'RTK signaling',
#  5208: 'Others',
#  6753378: 'Apoptosis regulation',
#  3385: 'Antimetabolite',
#  82146: 'Others',
#  6445533: 'Chromatin-related',
#  159324: 'Others',
#  11373846: 'Cytoskeleton',
#  11493598: 'ERK MAPK signaling',
#  53394750: 'Chromatin-related',
#  44143370: 'DNA inhibitor',
#  25195352: 'Others',
#  16038120: 'RTK signaling',
#  11228183: 'Apoptosis regulation',
#  46843057: 'PI3K/MTOR signaling',
#  56645356: 'Metabolism',
#  71299339: 'Metabolism',
#  24771867: 'Others',
#  56649450: 'PI3K/MTOR signaling',
#  68947304: 'PI3K/MTOR signaling',
#  91663328: 'WNT signaling',
#  25099184: 'Others',
#  78209992: 'EGFR signaling',
#  51039095: 'RTK signaling',
#  25227436: 'Others',
#  49847690: 'Apoptosis regulation',
#  54761306: 'Genome integrity',
#  52913813: 'PI3K/MTOR signaling',
#  9927531: 'Genome integrity',
#  9926054: 'Others',
#  16654980: 'PI3K/MTOR signaling',
#  24360: 'DNA inhibitor',
#  2578: 'DNA alkylator',
#  9933475: 'RTK signaling',
#  131698633: 'Chromatin-related',
#  2907: 'DNA alkylator',
#  42623951: 'PI3K/MTOR signaling',
#  2942: 'Others',
#  457193: 'DNA inhibitor',
#  46926350: 'Cell cycle',
#  59473233: 'Others',
#  41867: 'DNA inhibitor',
#  56962336: 'Chromatin-related',
#  57345410: 'Chromatin-related',
#  657237: 'Antimetabolite',
#  104741: 'Hormone-related',
#  56941241: 'Hormone-related',
#  124886: 'Others',
#  70676303: 'PI3K/MTOR signaling',
#  68107965: 'Others',
#  53469448: 'Metabolism',
#  70983932: 'Others',
#  71268957: 'Chromatin-related',
#  117072552: 'Chromatin-related',
#  91668541: 'Chromatin-related',
#  24821094: 'Others',
#  24788740: 'PI3K/MTOR signaling',
#  60838: 'Topoisomerase inhibitor',
#  2155128: 'WNT signaling',
#  73555129: 'ERK MAPK signaling',
#  24737642: 'Apoptosis regulation',
#  3899: 'Antimetabolite',
#  46926973: 'WNT signaling',
#  118704762: 'PI3K/MTOR signaling',
#  11655119: 'Others',
#  16241412: 'Apoptosis regulation',
#  227681: 'p53 pathway',
#  520459: 'Genome integrity',
#  4212: 'DNA inhibitor',
#  24856436: 'Cell cycle',
#  16224745: 'Cell cycle',
#  60167849: 'Protein stability and degradation',
#  2802462: 'WNT signaling',
#  3011155: 'DNA inhibitor',
#  24958200: 'PARP inhibitor',
#  9825149: 'IGF1R signaling',
#  35397514: 'Chromatin-related',
#  71496458: 'EGFR signaling',
#  9936746: 'Chromatin-related',
#  5310940: 'Platinum',
#  46931953: 'Protein stability and degradation',
#  24753719: 'Chromatin-related',
#  1018: 'Others',
#  52918385: 'p53 pathway',
#  44462758: 'Others',
#  25227847: 'DNA inhibitor',
#  44631912: 'Cell cycle',
#  24871506: 'Chromatin-related',
#  46236925: 'Apoptosis regulation',
#  11488320: 'EGFR signaling',
#  68289010: 'RTK signaling',
#  24866313: 'ERK MAPK signaling',
#  44259: 'RTK signaling',
#  51001932: 'PI3K/MTOR signaling',
#  10385095: 'Genome integrity',
#  452548: 'DNA inhibitor',
#  60700: 'DNA inhibitor',
#  11719003: 'ERK MAPK signaling',
#  58641927: 'ERK MAPK signaling',
#  992586: 'Apoptosis regulation',
#  51042438: 'PI3K/MTOR signaling',
#  59472121: 'Genome integrity',
#  51000408: 'Genome integrity',
#  49846579: 'Apoptosis regulation',
#  5978: 'Others',
#  71297207: 'Apoptosis regulation',
#  2984337: 'WNT signaling',
#  57519544: 'WNT signaling',
#  72200024: 'Others'}

# %% [markdown]
# ## CTRP2

# %%
drug_anno=[]
for idx in ctrp2_info_sel.index:
    name=ctrp2_info_sel.loc[idx,'cpd_name']
    target= ctrp2_info_sel.loc[idx,'target_or_activity_of_compound']
    gene=ctrp2_info_sel.loc[idx,'gene_symbol_of_protein_target']
    cid=gene=int(ctrp2_info_sel.loc[idx,'cid'])
    if cid in dict_cid_anno:
        drug_anno.append(dict_cid_anno[cid])
    elif 'platin' in name:
        drug_anno.append('Platinum')
    elif 'parib' in name:
        drug_anno.append('PARP inhibitor')
    elif 'topoisomerase' in target:
        drug_anno.append('Topoisomerase inhibitor')
    elif 'tubule' in target :
        drug_anno.append('Antimicrotubule')
    elif 'DNA alkylator' in target:
        drug_anno.append('DNA alkylator')
    elif 'inducer of DNA damage' in target:
        drug_anno.append('DNA inhibitor')
    elif 'DNA crosslinker' in target:
        drug_anno.append('DNA alkylator')
    elif 'inhibitor of DNA synthesis' in target:
        drug_anno.append('Antimetabolite')
    elif 'inhibitor of DNA replication' in target:
        drug_anno.append('DNA inhibitor')
    elif 'inhibitor of thymidylate synthase' in target:
        drug_anno.append('Antimetabolite')
    elif 'inhibitor of cyclin-dependent kinases' in target:
        drug_anno.append('Cell cycle')
    elif 'inhibitor of PI3K and mTOR kinase activity' in target:
        drug_anno.append('PI3K/MTOR signaling')
    elif 'inhibitor of mTOR and PI3K kinase acitivities' in target:
        drug_anno.append('PI3K/MTOR signaling')
    elif 'inhibitor of mTOR'  in target:
        drug_anno.append('PI3K/MTOR signaling')
    elif 'inhibitor of p53-MDM2 interaction' in target:
        drug_anno.append('p53 pathway')
    elif 'inhibitor of HDAC1, HDAC2, HDAC3, HDAC6, and HDAC8' in target:
        drug_anno.append('Chromatin-related')
    elif 'modulator of estrogen receptors'  in target:
        drug_anno.append('Hormone-related')
    else:
        drug_anno.append('Others')
Counter(drug_anno)
# Out:
# Counter({'Others': 91,
#          'DNA alkylator': 7,
#          'Antimetabolite': 2,
#          'Antimicrotubule': 4,
#          'Hormone-related': 2,
#          'Platinum': 2,
#          'DNA inhibitor': 9,
#          'Topoisomerase inhibitor': 2,
#          'Protein stability and degradation': 2,
#          'EGFR signaling': 3,
#          'Chromatin-related': 5,
#          'PI3K/MTOR signaling': 13,
#          'Cell cycle': 7,
#          'RTK signaling': 11,
#          'ERK MAPK signaling': 3,
#          'Apoptosis regulation': 4,
#          'p53 pathway': 2,
#          'PARP inhibitor': 2,
#          'Metabolism': 1,
#          'IGF1R signaling': 1})

# %%
ctrp2_info_sel['drug_anno']=drug_anno

# %% [markdown]
# ## CTRP1

# %%
ctrp1_info_sel
# Out:
#            cpd_name                                   cpd_synonym  \
# 8    2-deoxyglucose                                           NaN
# 21          ABT-737                                           NaN
# 22          ABT-751                                           NaN
# 30          aspirin                                           NaN
# 31             ATRA    all-trans retinoic acid;Tretinoin;Vesanoid
# ..              ...                                           ...
# 342       veliparib                                       ABT-888
# 344      vismodegib                  Vismodegib;Erivedge;GDC-0449
# 345      vorinostat  SAHA;suberoylanilide hydroxamic acid;Zolinza
# 350          YM-155                                           NaN
# 352        zileuton                                         Zyflo
#
#              cpd_status                     target_or_activity_of_compound  \
# 8    clinical candidate             inhibitor of glycolysis via hexokinase
# 21   clinical candidate                inhibitor of BCL2, BCL-xL and BCL-W
# 22   clinical candidate                          inhibitor of beta-tubulin
# 30         FDA-approved  inhibitor of cyclooxygenase 1 (COX1) and 2 (COX2)
# 31         FDA-approved  agonist of retinoid acid (RAR) receptors (RAR?...
# ..                  ...                                                ...
# 342  clinical candidate  inhibitor of poly (ADP-ribose) polymerase 1 (P...
# 344        FDA-approved                   inhibitor of smoothened receptor
# 345        FDA-approved     inhibitor of HDAC1, HDAC2, HDAC3, HDAC6, HDAC8
# 350  clinical candidate                   inhibitor of survivin expression
# 352        FDA-approved                        inhibitor of 5-lipoxygenase
#
#      gene_symbol_of_protein_target  top_test_conc_umol  percent_cpd_purity  \
# 8                              HK2               37.00                 NaN
# 21              BCL2;BCL2L1;BCL2L2               37.00               100.0
# 22                            TUBB               33.33               100.0
# 30                     PTGS1;PTGS2               33.33                 NaN
# 31                  RARA;RARB;RARG              133.33               100.0
# ..                             ...                 ...                 ...
# 342                    PARP1;PARP2               33.33                99.0
# 344                            SMO               33.33                 NaN
# 345  HDAC1;HDAC2;HDAC3;HDAC6;HDAC8               37.00               100.0
# 350                          BIRC5                1.00               100.0
# 352                          ALOX5              533.33                87.0
#
#                                             cpd_smiles  pubchem_cid  \
# 8                      OC[C@H]1OC(O)C[C@@H](O)[C@@H]1O     439268.0
# 21   CN(C)CC[C@H](CSc1ccccc1)Nc2ccc(cc2[N+](=O)[O-]...   11228183.0
# 22          COc1ccc(cc1)S(=O)(=O)Nc2cccnc2Nc3ccc(O)cc3    3035714.0
# 30                               CC(=O)Oc1ccccc1C(=O)O       2244.0
# 31     C\C(=C/C=C/C(=C/C(=O)O)/C)\C=C\C1=C(C)CCCC1(C)C     444795.0
# ..                                                 ...          ...
# 342             C[C@@]1(CCCN1)c2nc3c(cccc3[nH]2)C(=O)N   11960529.0
# 344  CS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(c2)c3ccccn3)c...   24776445.0
# 345                        ONC(=O)CCCCCCC(=O)Nc1ccccc1       5311.0
# 350   COCCn1c(C)[n+](Cc2cnccn2)c3C(=O)c4ccccc4C(=O)c13   10126189.0
# 352                        CC(N(O)C(=O)N)c1cc2ccccc2s1      60490.0
#
#       broad_cpd_id  master_cpd_id
# 8    BRD-A73690687         347781
# 21   BRD-K56301217         411738
# 22   BRD-K91623615         417983
# 30   BRD-K11433652          31336
# 31   BRD-K64634304         411870
# ..             ...            ...
# 342  BRD-K87142802         606034
# 344  BRD-K44827188         397704
# 345  BRD-K81418486          56554
# 350  BRD-K76703230         417979
# 352  BRD-A56359832         346974
#
# [90 rows x 11 columns]

# %%
drug_anno=[]
for idx in ctrp1_info_sel.index:
    name=ctrp1_info_sel.loc[idx,'cpd_name']
    target= ctrp1_info_sel.loc[idx,'target_or_activity_of_compound']
    gene=ctrp1_info_sel.loc[idx,'gene_symbol_of_protein_target']
    cid=gene=int(ctrp1_info_sel.loc[idx,'pubchem_cid'])
    if cid in dict_cid_anno:
        drug_anno.append(dict_cid_anno[cid])
    elif 'platin' in name:
        drug_anno.append('Platinum')
    elif 'parib' in name:
        drug_anno.append('PARP inhibitor')
    elif 'topoisomerase' in target:
        drug_anno.append('Topoisomerase inhibitor')
    elif 'tubule' in target :
        drug_anno.append('Antimicrotubule')
    elif 'tubulin' in target :
        drug_anno.append('Antimicrotubule')
    elif 'DNA alkylator' in target:
        drug_anno.append('DNA alkylator')
    elif 'inducer of DNA damage' in target:
        drug_anno.append('DNA inhibitor')
    elif 'DNA crosslinker' in target:
        drug_anno.append('DNA alkylator')
    elif 'inhibitor of DNA synthesis' in target:
        drug_anno.append('Antimetabolite')
    elif 'thymidylate' in target:
        drug_anno.append('Antimetabolite')
    elif 'inhibitor of DNA replication' in target:
        drug_anno.append('DNA inhibitor')
    elif 'inhibitor of thymidylate synthase' in target:
        drug_anno.append('Antimetabolite')
    elif 'inhibitor of cyclin-dependent kinases' in target:
        drug_anno.append('Cell cycle')
    elif 'inhibitor of PI3K and mTOR kinase activity' in target:
        drug_anno.append('PI3K/MTOR signaling')
    elif 'inhibitor of mTOR and PI3K kinase acitivities' in target:
        drug_anno.append('PI3K/MTOR signaling')
    elif 'inhibitor of mTOR'  in target:
        drug_anno.append('PI3K/MTOR signaling')
    elif 'inhibitor of p53-MDM2 interaction' in target:
        drug_anno.append('p53 pathway')
    elif 'inhibitor of HDAC1, HDAC2, HDAC3, HDAC6, and HDAC8' in target:
        drug_anno.append('Chromatin-related')
    elif 'modulator of estrogen receptors'  in target:
        drug_anno.append('Hormone-related')
    elif 'antagonist of androgen receptor'  in target:
        drug_anno.append('Hormone-related')
    else:
        drug_anno.append('Others')
Counter(drug_anno)
# Out:
# Counter({'Others': 61,
#          'Apoptosis regulation': 2,
#          'Antimicrotubule': 2,
#          'PI3K/MTOR signaling': 2,
#          'Cell cycle': 1,
#          'Hormone-related': 4,
#          'RTK signaling': 2,
#          'Protein stability and degradation': 3,
#          'DNA inhibitor': 2,
#          'Metabolism': 1,
#          'Antimetabolite': 2,
#          'Topoisomerase inhibitor': 1,
#          'IGF1R signaling': 1,
#          'DNA alkylator': 1,
#          'PARP inhibitor': 3,
#          'ERK MAPK signaling': 1,
#          'Chromatin-related': 1})

# %%
ctrp1_info_sel['drug_anno']=drug_anno

# %% [markdown]
# ## PRISM

# %%
prism_drug_sel=prism_anno_rc.reset_index()

# %%
prism_drug_sel['moa']=prism_drug_sel['moa'].fillna('NoData')

# %%
prism_drug_sel['cid']
# Out:
# 0          3385
# 1      46220502
# 2        132971
# 3          2123
# 4          2179
#          ...
# 167    42611257
# 168    49846579
# 169    49846579
# 170        5311
# 171        5311
# Name: cid, Length: 172, dtype: int64

# %%
drug_anno=[]
for idx in prism_drug_sel.index:
    name=prism_drug_sel.loc[idx,'PRISM.drugid']
    cid=int(prism_drug_sel.loc[idx,'cid'])
    moa=prism_drug_sel.loc[idx,'moa']
    if cid in dict_cid_anno:
        drug_anno.append(dict_cid_anno[cid])
    elif 'platin' in name:
        drug_anno.append('Platinum')
    elif 'parib' in name:
        drug_anno.append('PARP inhibitor')
    elif 'topoisomerase inhibitor' in moa:
        drug_anno.append('Topoisomerase inhibitor')
    elif 'tubul' in moa :
        drug_anno.append('Antimicrotubule')
    elif 'DNA alkylating agent' in moa:
        drug_anno.append('DNA alkylator')
    elif 'DNA synthesis inhibitor' in moa:
        drug_anno.append('Antimetabolite')
    elif 'ribonucleotide reductase inhibitor' in moa:
        drug_anno.append('Antimetabolite')
    elif 'thymidylate synthase inhibitor' in moa:
        drug_anno.append('Antimetabolite')
    elif 'adenosine deaminase inhibitor' in moa:
        drug_anno.append('Antimetabolite')
    elif 'dihydrofolate reductase inhibitor	DHFR' in moa:
        drug_anno.append('Antimetabolite')
    elif 'dihydrofolate reductase inhibitor' in moa:
        drug_anno.append('Antimetabolite')
    elif name in ['azacitidine']:
        drug_anno.append('Antimetabolite')
    elif 'PARP' in moa:
        drug_anno.append('PARP inhibitor')
    elif 'thymidylate synthase inhibitor' in moa:
        drug_anno.append('Antimetabolite')
    elif  'DNA intercalating agent' in moa:
        drug_anno.append('other DNA inhibitor')
    elif 'purine antagonist' in moa:
        drug_anno.append('Antimetabolite')
    elif 'dihydropyrimidine dehydrogenase inhibitor' in moa:
        drug_anno.append('Antimetabolite')
    elif 'DNA damage inducer' in moa:
        drug_anno.append('DNA inhibitor')
    elif 'DNA inhibitor' in moa:
        drug_anno.append('DNA inhibitor')
    elif moa in ['aromatase inhibitor','androgen receptor antagonist',
                'estrogen receptor antagonist, selective estrogen receptor modulator (SERM)',
                'androgen biosynthesis inhibitor']:
        drug_anno.append('Hormone-related')
    elif moa in ['EGFR inhibitor']:
        drug_anno.append('EGFR signaling')
    elif moa in ['proteasome inhibitor']:
        drug_anno.append('Protein stability and degradation')    
    elif moa in ['HDAC inhibitor']:
        drug_anno.append('Chromatin-related')    
    elif moa in ['CDK inhibitor']:
        drug_anno.append('Cell cycle') 
    elif moa in ['MEK inhibitor']:
        drug_anno.append('ERK MAPK signaling') 
    elif moa in ['mTOR inhibitor']:
        drug_anno.append('PI3K/MTOR signaling') 
    else:
        drug_anno.append('Others')
Counter(drug_anno).most_common()
# Out:
# [('Others', 43),
#  ('Antimetabolite', 23),
#  ('Hormone-related', 15),
#  ('DNA inhibitor', 12),
#  ('Antimicrotubule', 12),
#  ('Topoisomerase inhibitor', 10),
#  ('EGFR signaling', 10),
#  ('DNA alkylator', 8),
#  ('RTK signaling', 6),
#  ('Protein stability and degradation', 6),
#  ('Chromatin-related', 5),
#  ('ERK MAPK signaling', 5),
#  ('Cell cycle', 4),
#  ('PI3K/MTOR signaling', 4),
#  ('PARP inhibitor', 4),
#  ('Platinum', 3),
#  ('Apoptosis regulation', 2)]

# %%
prism_drug_sel['drug_anno']=drug_anno

# %% [markdown]
# ## gCSI

# %%
drug_anno=[]
for idx in gcsi_anno.index:
    name=gcsi_anno.loc[idx,'drugid']
    cid=int(gcsi_anno.loc[idx,'cid'])
    if cid in dict_cid_anno:
        drug_anno.append(dict_cid_anno[cid])
    elif 'platin' in name:
        drug_anno.append('Platinum')
    elif name in ['Vincristine','Vincaleukoblastine']:
        drug_anno.append('Antimicrotubule')
    elif name in ['5-Fluorouracil','Gemcitabine']:
        drug_anno.append('Antimetabolite')
    elif name in ['Erlotinib']:
        drug_anno.append('EGFR signaling')
    elif name in ['Crizotinib']:
        drug_anno.append('RTK signaling')
    else:
        drug_anno.append('Others')
Counter(drug_anno)
# Out:
# Counter({'Antimetabolite': 3,
#          'ERK MAPK signaling': 3,
#          'Others': 14,
#          'Cell cycle': 2,
#          'PI3K/MTOR signaling': 6,
#          'Protein stability and degradation': 3,
#          'WNT signaling': 1,
#          'Platinum': 1,
#          'RTK signaling': 1,
#          'Antimicrotubule': 3,
#          'EGFR signaling': 3,
#          'DNA inhibitor': 1,
#          'Genome integrity': 1,
#          'Chromatin-related': 1})

# %%
gcsi_anno['drug_anno']=drug_anno

# %% [markdown]
# ## Write out

# %%
gdsc1_drug_sel['drug_name_common']=['GDSC1_'+x+'_'+str(y) for x,y in zip(gdsc1_drug_sel['drug_name'],gdsc1_drug_sel['drug_id']) ]
gdsc2_drug_sel['drug_name_common']=['GDSC2_'+x+'_'+str(y) for x,y in zip(gdsc2_drug_sel['drug_name'],gdsc2_drug_sel['drug_id']) ]
ctrp1_info_sel['drug_name_common']=['CTRP1_'+x+'_'+str(y) for x,y in zip(ctrp1_info_sel['cpd_name'],ctrp1_info_sel['master_cpd_id']) ]
ctrp2_info_sel['drug_name_common']=['CTRP2_'+x+'_'+str(y) for x,y in zip(ctrp2_info_sel['cpd_name'],ctrp2_info_sel['master_cpd_id']) ]
prism_drug_sel['drug_name_common']=['PRISM_'+x+'_'+str(y) for x,y in zip(prism_drug_sel['PRISM.drugid'],prism_drug_sel['broad_id']) ]
gcsi_anno['drug_name_common']=['gCSI_'+x+'_CID'+str(y) for x,y in zip(gcsi_anno.index,gcsi_anno['cid']) ]
# Out:
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_13085/4096897270.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdsc1_drug_sel['drug_name_common']=['GDSC1_'+x+'_'+str(y) for x,y in zip(gdsc1_drug_sel['drug_name'],gdsc1_drug_sel['drug_id']) ]
# /var/folders/3g/5zyn6dld5rl1rc3t1fmh0t240000gn/T/ipykernel_13085/4096897270.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdsc2_drug_sel['drug_name_common']=['GDSC2_'+x+'_'+str(y) for x,y in zip(gdsc2_drug_sel['drug_name'],gdsc2_drug_sel['drug_id']) ]

# %%
gcsi_anno['drug_name_common']=['gCSI_'+x+'_CID'+str(y) for x,y in zip(gcsi_anno.index,gcsi_anno['cid']) ]

# %%
set(gcsi_anno['drug_name_common'])-set(gcsi_add.columns)
# Out:
# {'gCSI_Idelalisib_CID11625818', 'gCSI_Pictilisib_CID17755052'}

# %%
gdsc1_drug_sel.to_csv('../intermediate/GDSC1_drug_category.txt',sep='\t')
gdsc2_drug_sel.to_csv('../intermediate/GDSC2_drug_category.txt',sep='\t')
ctrp1_info_sel.to_csv('../intermediate/CTRP1_drug_category.txt',sep='\t')
ctrp2_info_sel.to_csv('../intermediate/CTRP2_drug_category.txt',sep='\t')
prism_drug_sel.to_csv('../intermediate/PRISM_drug_category.txt',sep='\t')
gcsi_anno.to_csv('../intermediate/gCSI_drug_category.txt',sep='\t')

# %%
ctrp1_info_sel
# Out:
#            cpd_name                                   cpd_synonym  \
# 8    2-deoxyglucose                                           NaN
# 21          ABT-737                                           NaN
# 22          ABT-751                                           NaN
# 30          aspirin                                           NaN
# 31             ATRA    all-trans retinoic acid;Tretinoin;Vesanoid
# ..              ...                                           ...
# 342       veliparib                                       ABT-888
# 344      vismodegib                  Vismodegib;Erivedge;GDC-0449
# 345      vorinostat  SAHA;suberoylanilide hydroxamic acid;Zolinza
# 350          YM-155                                           NaN
# 352        zileuton                                         Zyflo
#
#              cpd_status                     target_or_activity_of_compound  \
# 8    clinical candidate             inhibitor of glycolysis via hexokinase
# 21   clinical candidate                inhibitor of BCL2, BCL-xL and BCL-W
# 22   clinical candidate                          inhibitor of beta-tubulin
# 30         FDA-approved  inhibitor of cyclooxygenase 1 (COX1) and 2 (COX2)
# 31         FDA-approved  agonist of retinoid acid (RAR) receptors (RAR?...
# ..                  ...                                                ...
# 342  clinical candidate  inhibitor of poly (ADP-ribose) polymerase 1 (P...
# 344        FDA-approved                   inhibitor of smoothened receptor
# 345        FDA-approved     inhibitor of HDAC1, HDAC2, HDAC3, HDAC6, HDAC8
# 350  clinical candidate                   inhibitor of survivin expression
# 352        FDA-approved                        inhibitor of 5-lipoxygenase
#
#      gene_symbol_of_protein_target  top_test_conc_umol  percent_cpd_purity  \
# 8                              HK2               37.00                 NaN
# 21              BCL2;BCL2L1;BCL2L2               37.00               100.0
# 22                            TUBB               33.33               100.0
# 30                     PTGS1;PTGS2               33.33                 NaN
# 31                  RARA;RARB;RARG              133.33               100.0
# ..                             ...                 ...                 ...
# 342                    PARP1;PARP2               33.33                99.0
# 344                            SMO               33.33                 NaN
# 345  HDAC1;HDAC2;HDAC3;HDAC6;HDAC8               37.00               100.0
# 350                          BIRC5                1.00               100.0
# 352                          ALOX5              533.33                87.0
#
#                                             cpd_smiles  pubchem_cid  \
# 8                      OC[C@H]1OC(O)C[C@@H](O)[C@@H]1O     439268.0
# 21   CN(C)CC[C@H](CSc1ccccc1)Nc2ccc(cc2[N+](=O)[O-]...   11228183.0
# 22          COc1ccc(cc1)S(=O)(=O)Nc2cccnc2Nc3ccc(O)cc3    3035714.0
# 30                               CC(=O)Oc1ccccc1C(=O)O       2244.0
# 31     C\C(=C/C=C/C(=C/C(=O)O)/C)\C=C\C1=C(C)CCCC1(C)C     444795.0
# ..                                                 ...          ...
# 342             C[C@@]1(CCCN1)c2nc3c(cccc3[nH]2)C(=O)N   11960529.0
# 344  CS(=O)(=O)c1ccc(C(=O)Nc2ccc(Cl)c(c2)c3ccccn3)c...   24776445.0
# 345                        ONC(=O)CCCCCCC(=O)Nc1ccccc1       5311.0
# 350   COCCn1c(C)[n+](Cc2cnccn2)c3C(=O)c4ccccc4C(=O)c13   10126189.0
# 352                        CC(N(O)C(=O)N)c1cc2ccccc2s1      60490.0
#
#       broad_cpd_id  master_cpd_id             drug_anno  \
# 8    BRD-A73690687         347781                Others
# 21   BRD-K56301217         411738  Apoptosis regulation
# 22   BRD-K91623615         417983       Antimicrotubule
# 30   BRD-K11433652          31336                Others
# 31   BRD-K64634304         411870                Others
# ..             ...            ...                   ...
# 342  BRD-K87142802         606034        PARP inhibitor
# 344  BRD-K44827188         397704                Others
# 345  BRD-K81418486          56554     Chromatin-related
# 350  BRD-K76703230         417979                Others
# 352  BRD-A56359832         346974                Others
#
#                 drug_name_common
# 8    CTRP1_2-deoxyglucose_347781
# 21          CTRP1_ABT-737_411738
# 22          CTRP1_ABT-751_417983
# 30           CTRP1_aspirin_31336
# 31             CTRP1_ATRA_411870
# ..                           ...
# 342       CTRP1_veliparib_606034
# 344      CTRP1_vismodegib_397704
# 345       CTRP1_vorinostat_56554
# 350          CTRP1_YM-155_417979
# 352        CTRP1_zileuton_346974
#
# [90 rows x 13 columns]

# %%
add1=gdsc1_drug_sel[['drug_name_common','drug_anno','pubchem']].rename(columns={'pubchem':'cid'})
add2=gdsc2_drug_sel[['drug_name_common','drug_anno','pubchem']].rename(columns={'pubchem':'cid'})
add3=ctrp1_info_sel[['drug_name_common','drug_anno','pubchem_cid']].rename(columns={'pubchem_cid':'cid'})
add4=ctrp2_info_sel[['drug_name_common','drug_anno','cid']]
add5=prism_drug_sel[['drug_name_common','drug_anno','cid']]
add6=gcsi_anno[['drug_name_common','drug_anno','cid']]

# %%
dfw=pd.concat([add1,add2,add3,add4,add5,add6])

# %%
Counter(dfw['drug_anno']).most_common()
# Out:
# [('Others', 305),
#  ('PI3K/MTOR signaling', 69),
#  ('RTK signaling', 57),
#  ('Chromatin-related', 49),
#  ('DNA inhibitor', 45),
#  ('ERK MAPK signaling', 42),
#  ('Antimetabolite', 41),
#  ('Cell cycle', 36),
#  ('Protein stability and degradation', 31),
#  ('Antimicrotubule', 31),
#  ('EGFR signaling', 30),
#  ('Hormone-related', 29),
#  ('Apoptosis regulation', 26),
#  ('PARP inhibitor', 19),
#  ('DNA alkylator', 19),
#  ('WNT signaling', 14),
#  ('Topoisomerase inhibitor', 14),
#  ('Genome integrity', 12),
#  ('Metabolism', 11),
#  ('Platinum', 10),
#  ('IGF1R signaling', 9),
#  ('Cytoskeleton', 9),
#  ('p53 pathway', 9),
#  ('JNK and p38 signaling', 8)]

# %%
dfw.to_csv('../intermediate/Drug_annotaion_integrated.txt',sep='\t',index=False)

# %%
print(add1.shape)
print(add2.shape)
print(add3.shape)
print(add4.shape)
print(add5.shape)
print(add6.shape)
# Out:
# (241, 3)
# (206, 3)
# (90, 3)
# (173, 3)
# (172, 3)
# (43, 3)
